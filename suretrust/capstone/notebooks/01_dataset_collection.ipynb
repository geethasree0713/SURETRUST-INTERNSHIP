# %% [markdown]
# # TASK 6:Combine all 3 into one Knowledge Base

# %%
import sys
# !{sys.executable} -m pip install kagglehub pandas

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\famil\anaconda3\python.exe

# %%
import kagglehub
import pandas as pd
print("All good, ready to go!")
# Out:
# All good, ready to go!

# %%
import kagglehub

# Download the full dataset (it's small - ~72MB total)
path = kagglehub.dataset_download("saurabhshahane/long-lived-bug-prediction")
print("Dataset downloaded to:", path)

# %%
'''import pandas as pd
mozilla_df = pd.read_csv(".../AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/mozilla_bug_report_data.csv/mozilla_bug_report_data.csv")
eclipse_df = pd.read_csv(".../AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/eclipse_bug_report_data.csv/eclipse_bug_report_data.csv")
print(mozilla_df.shape)
print(eclipse_df.shape)

print(mozilla_df.head())

print( eclipse_df.head())'''




import pandas as pd
mozilla_df = pd.read_csv("C:/Users/famil/OneDrive/Desktop/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/mozilla_bug_report_data.csv/mozilla_bug_report_data.csv")
eclipse_df = pd.read_csv("C:/Users/famil/OneDrive/Desktop/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/eclipse_bug_report_data.csv/eclipse_bug_report_data.csv")
print(mozilla_df.shape)
print(eclipse_df.shape)

mozilla_df.head()
# Out:
# (9999, 19)
# (9776, 19)
#                        bug_id creation_date    component_name  \
# 0             BUGZILLA-294734    2005-05-18  Bugzilla-General
# 1   OTHER_APPLICATIONS-363323    2006-12-09     DOM Inspector
# 2  SUPPORT.MOZILLA.ORG-398246    2007-10-02           General
# 3  RELEASE_ENGINEERING-525991    2009-11-02           General
# 4   OTHER_APPLICATIONS-318859    2005-12-02         ChatZilla
#
#           product_name                                  short_description  \
# 0             BUGZILLA                          Emergency 2.16.10 Release
# 1   OTHER_APPLICATIONS  DOM View is really inefficient with setting wh...
# 2  SUPPORT.MOZILLA.ORG   Add support for custom cookies and cache headers
# 3  RELEASE_ENGINEERING           Create Major Update from 3.0.15 to 3.5.5
# 4   OTHER_APPLICATIONS   DCC functionality in ChatZilla isn't functional.
#
#                                     long_description        assignee_name  \
# ...

# %%
import pandas as pd
apache_df = pd.read_csv(r"D:/issues.csv", nrows=10000)
print(apache_df.shape)
apache_df.head()
apache_df.to_csv(r"D:/processed_issues.csv", index=False)

#apache_df.describe()
# Out:
# (10000, 37)

# %%
print(mozilla_df.columns)
print(eclipse_df.columns)
print(apache_df.columns)

print('\n\n\n')

mozilla_df.head(10)
# Out:
# Index(['bug_id', 'creation_date', 'component_name', 'product_name',
#        'short_description', 'long_description', 'assignee_name',
#        'reporter_name', 'resolution_category', 'resolution_code',
#        'status_category', 'status_code', 'update_date', 'quantity_of_votes',
#        'quantity_of_comments', 'resolution_date', 'bug_fix_time',
#        'severity_category', 'severity_code'],
#       dtype='str')
# Index(['bug_id', 'creation_date', 'component_name', 'product_name',
#        'short_description', 'long_description', 'assignee_name',
#        'reporter_name', 'resolution_category', 'resolution_code',
#        'status_category', 'status_code', 'update_date', 'quantity_of_votes',
#        'quantity_of_comments', 'resolution_date', 'bug_fix_time',
#        'severity_category', 'severity_code'],
#       dtype='str')
# Index(['id', 'key', 'summary', 'resolution.id', 'resolution.description',
#        'resolution.name', 'priority.id', 'priority.name', 'labels', 'assignee',
# ...

# %%
eclipse_df.head(10)
# Out:
#                       bug_id creation_date component_name        product_name  \
# 0        RECOMMENDERS-467951    2015-05-22           Core        RECOMMENDERS
# 1                QVTO-463396    2015-03-29         Engine                QVTO
# 2             EQUINOX-530069    2018-01-20     Compendium             EQUINOX
# 3            NATTABLE-422482    2013-11-25           Core            NATTABLE
# 4   WTP_JAVA_EE_TOOLS-116294    2005-11-14       jst.j2ee   WTP_JAVA_EE_TOOLS
# 5                 PDT-165702    2006-11-23    Code Assist                 PDT
# 6  WTP_SOURCE_EDITING-103608    2005-07-13       wst.html  WTP_SOURCE_EDITING
# 7                  JDT-84477    2005-02-04             UI                 JDT
# 8                BIRT-236012    2008-06-06  Report Engine                BIRT
# 9          SUBVERSIVE-264685    2009-02-12             UI          SUBVERSIVE
#
#                                    short_description  \
# 0  LogTraceException in ProposalUtils.toMethodNam...
# ...

# %%
apache_df.head(10)
# Out:
#          id           key                                            summary  \
# 0  12451174        WW-712  Update config browser to work with the new syntax
# 1     29159    XALANC-446  XALAN_C 1.9 or current do not build on Fedora ...
# 2  12420130       ROL-587        Problem with ADD new post, and DELETE post.
# 3     29222     AXIS-1741  LogHandler can only work in GlobalConfiguratio...
# 4     29233     AXIS-1745  Decoding of service is broken in org.apache.ax...
# 5     29171   DIRNAMING-9  XmlConfigurator should support namespaces othe...
# 6  12812725    GROOVY-686  GroovyServlet will crash if parameters are pas...
# 7     29239  DIRNAMING-10                  Port changes from tomcat-catalina
# 8  12812772    GROOVY-671           Groovy / Java Mismatch with simple class
# 9  12594252        XW-259  ActionContext should always have a TextProvide...
#
#    resolution.id                             resolution.description  \
# ...

# %%
mozilla_df.columns
mozilla_df['status_category']
# Out:
# 0       resolved
# 1       resolved
# 2       resolved
# 3       resolved
# 4       resolved
#           ...
# 9994    resolved
# 9995    resolved
# 9996    resolved
# 9997    resolved
# 9998    resolved
# Name: status_category, Length: 9999, dtype: object

# %%
print(mozilla_df.columns)
print(apache_df.columns)
apache_df[['resolution.id', 'resolution.description',
       'resolution.name','statusCategory.name']]
# Out:
# Index(['bug_id', 'creation_date', 'component_name', 'product_name',
#        'short_description', 'long_description', 'assignee_name',
#        'reporter_name', 'resolution_category', 'resolution_code',
#        'status_category', 'status_code', 'update_date', 'quantity_of_votes',
#        'quantity_of_comments', 'resolution_date', 'bug_fix_time',
#        'severity_category', 'severity_code'],
#       dtype='object')
# Index(['id', 'key', 'summary', 'resolution.id', 'resolution.description',
#        'resolution.name', 'priority.id', 'priority.name', 'labels', 'assignee',
#        'status.id', 'status.description', 'status.name', 'statusCategory.id',
#        'statusCategory.key', 'statusCategory.colorName', 'statusCategory.name',
#        'customfield_12310921', 'creator', 'subtasks', 'reporter',
#        'votes.votes', 'issuetype.id', 'issuetype.description',
#        'issuetype.name', 'issuetype.subtask', 'project.id', 'project.key',
# ...

# %%
mozilla_std = pd.DataFrame({
    'bug_id':mozilla_df['bug_id'],
    'title':mozilla_df['short_description'],
    'description':mozilla_df['long_description'],
    'severity':mozilla_df['severity_category'],
    'resolution':mozilla_df['resolution_category'],
    'status':mozilla_df['status_category'],
    'source_dataset':'Mozilla'
}
    
)

eclipse_std = pd.DataFrame({
    'bug_id':eclipse_df['bug_id'],
    'title':eclipse_df['short_description'],
    'description':eclipse_df['long_description'],
    'severity':eclipse_df ['severity_category'],
    'resolution':eclipse_df['resolution_category'],
    'status':eclipse_df['status_category'],
    'source_dataset':'Eclipse'
}
    
)

apache_std = pd.DataFrame({
    'bug_id':apache_df['key'],
    'title':apache_df['summary'],
    'description':apache_df['description'],
    'severity':apache_df ['priority.name'],
    'resolution':apache_df['resolution.name'],
    'status':apache_df['statusCategory.name'],
    'source_dataset':'Apache'
    
})

print('Mozilla:',mozilla_std.shape)
print('Eclipse:',eclipse_std.shape)
print('Apache:',apache_std.shape)
# Out:
# Mozilla: (9999, 7)
# Eclipse: (9776, 7)
# Apache: (10000, 7)

# %%
mozilla_std['stack_trace'] = None
eclipse_std['stack_trace'] = None
apache_std['stack_trace'] = None

mozilla_std['product_component'] = mozilla_df['product_name']
eclipse_std['product_component'] = eclipse_df['product_name']
apache_std['product_component'] = apache_df['project.name']


print(mozilla_std.shape)
print(eclipse_std.shape)
print(apache_std.shape)

mozilla_std.head()
# Out:
# (9999, 9)
# (9776, 9)
# (10000, 9)
#                        bug_id  \
# 0             BUGZILLA-294734
# 1   OTHER_APPLICATIONS-363323
# 2  SUPPORT.MOZILLA.ORG-398246
# 3  RELEASE_ENGINEERING-525991
# 4   OTHER_APPLICATIONS-318859
#
#                                                title  \
# 0                          Emergency 2.16.10 Release
# 1  DOM View is really inefficient with setting wh...
# 2   Add support for custom cookies and cache headers
# 3           Create Major Update from 3.0.15 to 3.5.5
# 4   DCC functionality in ChatZilla isn't functional.
#
#                                          description severity resolution  \
# 0  2.16.9 is broken -- many users can't enter bug...  blocker      fixed
# 1  From comment in url:\n\nCurrent code:\nmenuite...   normal      fixed
# 2  Adding support for custom headers and cookie n...  blocker      fixed
# 3                                                NaN   normal      fixed
# ...

# %%
knowledge_base_df = pd.concat([mozilla_std,eclipse_std,apache_std], ignore_index = True)
print("Comobo Size " , knowledge_base_df.shape)
knowledge_base_df['source_dataset'].value_counts()
# Out:
# Comobo Size  (29775, 9)
# source_dataset
# Apache     10000
# Mozilla     9999
# Eclipse     9776
# Name: count, dtype: int64

# %%
knowledge_base_df.to_csv("C:/Users/famil/OneDrive/Desktop/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/knowledge_basic_combined.csv" , index = False)
print("Saved Sucessfully")
# Out:
# Saved Sucessfully

# %% [markdown]
# # TASK 7:DATA CLEANING

# %%
print(knowledge_base_df.isnull().sum())
print("\n\nDuplicate id : ",knowledge_base_df['bug_id'].duplicated().sum())
print("\n\nShape before cleaning : ",knowledge_base_df.shape)
# Out:
# bug_id                   0
# title                    1
# description            613
# severity               354
# resolution            1036
# status                1036
# source_dataset           0
# stack_trace          29775
# product_component        0
# dtype: int64
#
#
# Duplicate id :  0
#
#
# Shape before cleaning :  (29775, 9)

# %%
knowledge_base_clean = knowledge_base_df.dropna(subset = ['title','description'])

knowledge_base_clean = knowledge_base_clean.fillna({
    'severity':'Unknown',
    'resolution':'Not Specificed',
    'status':'Unknown'
})

print("Shape after cleaning :",knowledge_base_clean.shape)
print("\nRemaining nulls : \n",knowledge_base_clean.isnull().sum())
# Out:
# Shape after cleaning : (29161, 9)
#
# Remaining nulls :
#  bug_id                   0
# title                    0
# description              0
# severity                 0
# resolution               0
# status                   0
# source_dataset           0
# stack_trace          29161
# product_component        0
# dtype: int64

# %%
import re

def clean_text(text):
    if pd.isna(text):
        return(text)
    text =  str(text)
    text = re.sub(r'<[^>]+>',' ',text)
    text = re.sub(r'\s+',' ',text)
    return text.strip()

knowledge_base_clean['title'] = knowledge_base_clean['title'].apply(clean_text)
knowledge_base_clean['description'] = knowledge_base_clean['description'].apply(clean_text)

print('Cleaning applied . A Sample of that :')
knowledge_base_clean[['title','description']].head(3)
# Out:
# Cleaning applied . A Sample of that :
#                                                title  \
# 0                          Emergency 2.16.10 Release
# 1  DOM View is really inefficient with setting wh...
# 2   Add support for custom cookies and cache headers
#
#                                          description
# 0  2.16.9 is broken -- many users can't enter bug...
# 1  From comment in url: Current code: menuitem ->...
# 2  Adding support for custom headers and cookie n...

# %%
knowledge_base_clean.to_csv("C:/Users/famil/OneDrive/Desktop/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/knowledge_base_cleaned.csv" , index = False)
print("Saved Cleaned knowledge Base")
# Out:
# Saved Cleaned knowledge Base

# %% [markdown]
# # TASK 8:Chunking with  Langchain

# %%
import sys
# !{sys.executable} -m pip install langchain langchain-text-splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=500 , chunk_overlap=50)

knowledge_base_clean['full_text'] = knowledge_base_clean['title'] + ". " + knowledge_base_clean['description']

sample_text = knowledge_base_clean['full_text'].iloc[0]
chunks = splitter.split_text(sample_text)

print("Original Text Length :",len(sample_text))
print("Numberof chunks :",len(chunks))
print("\nFirst Chunk:\n",chunks[0])
# Out:
# Original Text Length : 173
# Numberof chunks : 1
#
# First Chunk:
#  Emergency 2.16.10 Release. 2.16.9 is broken -- many users can't enter bugs on it particularly not from a fresh install. So we need to pull 2.16.9 and post a 2.16.10 instead.

# %%
longer_text = knowledge_base_clean['full_text'].iloc[1]
chunks = splitter.split_text(longer_text)

print("Original Text Length :",len(longer_text))
print("Numberof chunks :",len(chunks))
print("\n--- Chunk 1 ---\n",chunks[0])
print("\n--- Chunk 2 ---\n",chunks[1] if len(chunks)>1 else "(only 1 chunk)")
# Out:
# Original Text Length : 304
# Numberof chunks : 1
#
# --- Chunk 1 ---
#  DOM View is really inefficient with setting what is to be shown. From comment in url: Current code: menuitem -> command -> toggler -> setter -> pref -> observer -> setter -> pref Proposed code: menuitem -> command -> toggler -> pref -> observer -> setter arguably we should rebuild() in the observer too.
#
# --- Chunk 2 ---
#  (only 1 chunk)

# %%
longest_idx = knowledge_base_clean['full_text'].str.len().idxmax()
longest_text=knowledge_base_clean['full_text'].loc[longest_idx]

print("Length of longest text:", len(longest_text))  
chunks = splitter.split_text(longest_text)

print("Length of longest text:",len(chunks))
print("Number of chunks :",len(chunks))
print("\n--- Chunk 1 ---\n",chunks[0])
print("\n--- Chunk 2 ---\n",chunks[1] if len(chunks)>1 else "(only 1 chunk)")
# Out:
# Length of longest text: 64610
# Length of longest text: 171
# Number of chunks : 171
#
# --- Chunk 1 ---
#  [FIX]I am a beginner from China, and i can't work jetspeed with db2,please help me,ok?. As followed is my db2 ddl and populate file contents. CREATE TABLE TURBINE_USER ( USER_ID INTEGER NOT NULL, LOGIN_NAME VARCHAR (32) NOT NULL, PASSWORD_VALUE VARCHAR (32) NOT NULL, FIRST_NAME VARCHAR (99) NOT NULL, LAST_NAME VARCHAR (99) NOT NULL, EMAIL VARCHAR (99), CONFIRM_VALUE VARCHAR (99), MODIFIED TIMESTAMP, CREATED TIMESTAMP, LAST_LOGIN TIMESTAMP, DISABLED VARCHAR (1), OBJECTDATA CLOB(16777215),
#
# --- Chunk 2 ---
# ...

# %%
# Cap any single text at 3000 characters before chunking (keeps outliers from exploding chunk count)
knowledge_base_clean['full_text'] = knowledge_base_clean['full_text'].str[:3000]

# %%
all_chunks = []

for idx , row  in knowledge_base_clean.iterrows():
    text_chunks = splitter.split_text(row['full_text'])
    for i , chunk in enumerate(text_chunks):
        all_chunks.append({
            'chunk_id':f"{row['bug_id']}_chunk{i}",
            'bug_id':row['bug_id'],
            'chunk_text':chunk,
            'title':row['title'],
            'severity':row['severity'],
            'resolution':row['resolution'],
            'status':row['status'],
            'source_dataset':row['source_dataset']
        })

chunks_df = pd.DataFrame(all_chunks)
print("Total chunks created:",chunks_df.shape[0])
print("From original rows:", knowledge_base_clean.shape[0])
chunks_df.head(55)
# Out:
# Total chunks created: 56862
# From original rows: 29161
#                                       chunk_id  \
# 0                       BUGZILLA-294734_chunk0
# 1             OTHER_APPLICATIONS-363323_chunk0
# 2            SUPPORT.MOZILLA.ORG-398246_chunk0
# 3            SUPPORT.MOZILLA.ORG-398246_chunk1
# 4             OTHER_APPLICATIONS-318859_chunk0
# 5             OTHER_APPLICATIONS-318859_chunk1
# 6             OTHER_APPLICATIONS-318859_chunk2
# 7             OTHER_APPLICATIONS-318859_chunk3
# 8          DEVELOPER.MOZILLA.ORG-416840_chunk0
# 9          MARKETPLACE_GRAVEYARD-977729_chunk0
# 10                   THUNDERBIRD-339875_chunk0
# 11                       FIREFOX-420556_chunk0
# 12                       FIREFOX-420556_chunk1
# 13                       FIREFOX-420556_chunk2
# 14                       FIREFOX-420556_chunk3
# 15                       FIREFOX-420556_chunk4
# 16         MOZILLA_LOCALIZATIONS-415621_chunk0
# 17                          CORE-254510_chunk0
# ...

# %%
chunks_df.to_csv("C:/Users/famil/OneDrive/Desktop/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/chunks_df.csv",index=False)
print("Saved Chunks")
# Out:
# Saved Chunks

# %% [markdown]
# # Task 9:Embedding

# %%
#!pip install pandas
import pandas as pd

# Reload your progress instead of redoing Tasks 6-8
knowledge_base_clean = pd.read_csv("C:/Users/famil/OneDrive/Desktop/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/knowledge_base_cleaned.csv")
chunks_df = pd.read_csv("C:/Users/famil/OneDrive/Desktop/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/data/chunks_df.csv")

print("Knowledge base reloaded:", knowledge_base_clean.shape)
print("Chunks reloaded:", chunks_df.shape)
# Out:
# Knowledge base reloaded: (29161, 9)
# Chunks reloaded: (56862, 8)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

print("Model loaded successfully")
print("Embedding dimension:", model.get_sentence_embedding_dimension())
# Out:
# [transformers] Disabling PyTorch because PyTorch >= 2.4 is required but found 2.2.2+cpu
# [transformers] PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# [transformers] PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       3 model = SentenceTransformer('all-MiniLM-L6-v2')
#       5 print("Model loaded successfully")
#
# File ~\anaconda3\Lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
# ...

# %%
import sys
# !{sys.executable} -m pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

print("Model loaded succesfully")
print("Embedding dimension:",model.get_sentence_embedding_dimension())

# %%
import torch
print("Torch version:", torch.__version__)
print("Torch loaded fine, testing nn module...")
x = torch.nn.Linear(10, 5)
print("torch.nn works fine")
# Out:
# Torch version: 2.2.2+cpu
# Torch loaded fine, testing nn module...
# torch.nn works fine

# %%
import sys
# !{sys.executable} -m pip install --upgrade sentence-transformers transformers

# %%
import sys
# !{sys.executable} -m pip uninstall torch -y
# !{sys.executable} -m pip install torch==2.2.2 --index-url https://download.pytorch.org/whl/cpu

# %%
# !{sys.executable} -m pip install torch --index-url https://download.pytorch.org/whl/cpu

# %%
import sys
# !{sys.executable} -m pip install "sentence-transformers==2.7.0" "transformers==4.39.3" --force-reinstall

# %%
import sys
# !{sys.executable} -m pip install --upgrade --force-reinstall numpy pandas

# %%
import pandas as pd

knowledge_base_clean = pd.read_csv("../data/knowledge_base_cleaned.csv")
chunks_df = pd.read_csv("../data/chunks.csv")

print("Knowledge base reloaded:", knowledge_base_clean.shape)
print("Chunks reloaded:", chunks_df.shape)

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import pandas
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:58
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
#      55     UInt32Dtype,
#      56     UInt64Dtype,
#      57     Float32Dtype,
# ---> 58     Float64Dtype,
#      59     CategoricalDtype,
#      60     PeriodDtype,
#      61     IntervalDtype,
#      62     DatetimeTZDtype,
#      63     StringDtype,
#      64     BooleanDtype,
#      65     # missing
#      66     NA,
#      67     isna,
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\famil\anaconda3\python.exe

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.4.6

# %%
pip show numpy

# %%
pip show pandas

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.4.6

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=384, stop_words='english')

embeddings = vectorizer.fit_transform(chunks_df['chunk_text'])

print("Embeddings shape:", embeddings.shape)
# Out:
# Embeddings shape: (56862, 384)

# %% [markdown]
# # Task 10: Vector Database (ChromaDB)

# %%
import sys
# !{sys.executable} -m pip install chromadb

# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name="bug_knowledge_base")

# Convert TF-IDF sparse matrix to lists for ChromaDB
embeddings_list = embeddings.toarray().tolist()

# Add in batches (ChromaDB works better with reasonable batch sizes)
batch_size = 5000
for i in range(0, len(chunks_df), batch_size):
    batch_end = min(i + batch_size, len(chunks_df))
    collection.add(
        ids=chunks_df['chunk_id'].iloc[i:batch_end].tolist(),
        embeddings=embeddings_list[i:batch_end],
        documents=chunks_df['chunk_text'].iloc[i:batch_end].tolist(),
        metadatas=chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].iloc[i:batch_end].to_dict('records')
    )
    print(f"Added batch {i} to {batch_end}")

print("Total items in collection:", collection.count())
# Out:
# Added batch 0 to 5000
# Added batch 5000 to 10000
# Added batch 10000 to 15000
# Added batch 15000 to 20000
# Added batch 20000 to 25000
# Added batch 25000 to 30000
# Added batch 30000 to 35000
# Added batch 35000 to 40000
# Added batch 40000 to 45000
# Added batch 45000 to 50000
# Added batch 50000 to 55000
# Added batch 55000 to 56862
# Total items in collection: 56862

# %%
client.delete_collection(name="bug_knowledge_base")  # remove the broken one

collection = client.create_collection(
    name="bug_knowledge_base",
    metadata={"hnsw:space": "cosine"}
)

# %%
# Convert TF-IDF sparse matrix to lists for ChromaDB
embeddings_list = embeddings.toarray().tolist()

# Add in batches
batch_size = 5000
for i in range(0, len(chunks_df), batch_size):
    batch_end = min(i + batch_size, len(chunks_df))
    collection.add(
        ids=chunks_df['chunk_id'].iloc[i:batch_end].tolist(),
        embeddings=embeddings_list[i:batch_end],
        documents=chunks_df['chunk_text'].iloc[i:batch_end].tolist(),
        metadatas=chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].iloc[i:batch_end].to_dict('records')
    )
    print(f"Added batch {i} to {batch_end}")

print("Total items in collection:", collection.count())
# Out:
# Added batch 0 to 5000
# Added batch 5000 to 10000
# Added batch 10000 to 15000
# Added batch 15000 to 20000
# Added batch 20000 to 25000
# Added batch 25000 to 30000
# Added batch 30000 to 35000
# Added batch 35000 to 40000
# Added batch 40000 to 45000
# Added batch 45000 to 50000
# Added batch 50000 to 55000
# Added batch 55000 to 56862
# Total items in collection: 56862

# %%
import numpy as np

print("Non-zero values in query vector:", np.count_nonzero(query_vector))
print("Query vector shape:", np.array(query_vector).shape)

# Which of our query words actually made it into the vocabulary?
vocab = vectorizer.vocabulary_
for word in ["application", "crashes", "crash", "login", "special", "characters", "character", "password"]:
    print(word, "->", "IN VOCAB" if word in vocab else "NOT in vocab")
# Out:
# Non-zero values in query vector: 1
# Query vector shape: (1, 384)
# application -> IN VOCAB
# crashes -> NOT in vocab
# crash -> IN VOCAB
# login -> NOT in vocab
# special -> NOT in vocab
# characters -> NOT in vocab
# character -> NOT in vocab
# password -> NOT in vocab

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=3000, stop_words='english')
embeddings = vectorizer.fit_transform(chunks_df['chunk_text'])

print("Embeddings shape:", embeddings.shape)
# Out:
# Embeddings shape: (56862, 3000)

# %%
client.delete_collection(name="bug_knowledge_base")
collection = client.create_collection(
    name="bug_knowledge_base",
    metadata={"hnsw:space": "cosine"}
)

embeddings_list = embeddings.toarray().tolist()

batch_size = 5000
for i in range(0, len(chunks_df), batch_size):
    batch_end = min(i + batch_size, len(chunks_df))
    collection.add(
        ids=chunks_df['chunk_id'].iloc[i:batch_end].tolist(),
        embeddings=embeddings_list[i:batch_end],
        documents=chunks_df['chunk_text'].iloc[i:batch_end].tolist(),
        metadatas=chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].iloc[i:batch_end].to_dict('records')
    )
    print(f"Added batch {i} to {batch_end}")

print("Total items in collection:", collection.count())
# Out:
# Added batch 0 to 5000
# Added batch 5000 to 10000
# Added batch 10000 to 15000
# Added batch 15000 to 20000
# Added batch 20000 to 25000
# Added batch 25000 to 30000
# Added batch 30000 to 35000
# Added batch 35000 to 40000
# Added batch 40000 to 45000
# Added batch 45000 to 50000
# Added batch 50000 to 55000
# Added batch 55000 to 56862
# Total items in collection: 56862

# %%
embeddings_list = embeddings.toarray().tolist()
print("Done converting to list.")
# Out:
# Done converting to list.

# %%
embeddings_list = embeddings.toarray().tolist()
print("Done converting to list.")
# Out:
# Done converting to list.

# %%
import chromadb
print(chromadb.__version__)
# Out:
# 1.1.1

# %%
import pandas as pd

chunks_df = pd.read_csv("../data/chunks_df.csv")
print(chunks_df.shape)
# Out:
# (56862, 8)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=3000, stop_words='english')
embeddings = vectorizer.fit_transform(chunks_df['chunk_text'])

print("Embeddings shape:", embeddings.shape)
# Out:
# Embeddings shape: (56862, 3000)

# %%
embeddings_list = embeddings.toarray().tolist()
print("Done converting to list.")
# Out:
# Done converting to list.

# %%
# persistent_collection = persistent_client.create_collection(
#     name="bug_knowledge_base",
#     metadata={"hnsw:space": "cosine"}
# )


persistent_client = chromadb.PersistentClient(path="C:/temp/chroma_db")

persistent_collection = persistent_client.create_collection(
    name="bug_knowledge_base",
    metadata={"hnsw:space": "cosine"}
)

batch_size = 5000
for i in range(0, len(chunks_df), batch_size):
    batch_end = min(i + batch_size, len(chunks_df))
    persistent_collection.add(
        ids=chunks_df['chunk_id'].iloc[i:batch_end].tolist(),
        embeddings=embeddings_list[i:batch_end],
        documents=chunks_df['chunk_text'].iloc[i:batch_end].tolist(),
        metadatas=chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].iloc[i:batch_end].to_dict('records')
    )
    print(f"Added batch {i} to {batch_end}")

print("Total items in persistent collection:", persistent_collection.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 19
#       1 # persistent_collection = persistent_client.create_collection(
#       2 #     name="bug_knowledge_base",
#       3 #     metadata={"hnsw:space": "cosine"}
#    (...)     16
#      17 # print("Total items in persistent collection:", persistent_collection.count())
# ---> 19 persistent_client = chromadb.PersistentClient(path="C:/temp/chroma_db")
#      21 persistent_collection = persistent_client.create_collection(
#      22     name="bug_knowledge_base",
#      23     metadata={"hnsw:space": "cosine"}
#      24 )
#      26 batch_size = 5000
#
# NameError: name 'chromadb' is not defined

# %%
# persistent_collection = persistent_client.create_collection(
#     name="bug_knowledge_base",
#     metadata={"hnsw:space": "cosine"}
# )


persistent_client = chromadb.PersistentClient(path="C:/temp/chroma_db")

persistent_collection = persistent_client.create_collection(
    name="bug_knowledge_base",
    metadata={"hnsw:space": "cosine"}
)

batch_size = 5000
for i in range(0, len(chunks_df), batch_size):
    batch_end = min(i + batch_size, len(chunks_df))
    persistent_collection.add(
        ids=chunks_df['chunk_id'].iloc[i:batch_end].tolist(),
        embeddings=embeddings_list[i:batch_end],
        documents=chunks_df['chunk_text'].iloc[i:batch_end].tolist(),
        metadatas=chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].iloc[i:batch_end].to_dict('records')
    )
    print(f"Added batch {i} to {batch_end}")

print("Total items in persistent collection:", persistent_collection.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 19
#       1 # persistent_collection = persistent_client.create_collection(
#       2 #     name="bug_knowledge_base",
#       3 #     metadata={"hnsw:space": "cosine"}
#    (...)     16
#      17 # print("Total items in persistent collection:", persistent_collection.count())
# ---> 19 persistent_client = chromadb.PersistentClient(path="C:/temp/chroma_db")
#      21 persistent_collection = persistent_client.create_collection(
#      22     name="bug_knowledge_base",
#      23     metadata={"hnsw:space": "cosine"}
#      24 )
#      26 batch_size = 5000
#
# NameError: name 'chromadb' is not defined

# %%
persistent_client.delete_collection(name="bug_knowledge_base")
print("Deleted old collection.")
# Out:
# Deleted old collection.

# %%
existing = persistent_client.list_collections()
print(existing)
# Out:
# [Collection(name=bug_knowledge_base)]

# %%
existing_collection = persistent_client.get_collection(name="bug_knowledge_base")
print("Count:", existing_collection.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 existing_collection = persistent_client.get_collection(name="bug_knowledge_base")
#       2 print("Count:", existing_collection.count())
#
# NameError: name 'persistent_client' is not defined

# %%
persistent_collection = existing_collection

batch_size = 5000
for i in range(0, len(chunks_df), batch_size):
    batch_end = min(i + batch_size, len(chunks_df))
    persistent_collection.add(
        ids=chunks_df['chunk_id'].iloc[i:batch_end].tolist(),
        embeddings=embeddings_list[i:batch_end],
        documents=chunks_df['chunk_text'].iloc[i:batch_end].tolist(),
        metadatas=chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].iloc[i:batch_end].to_dict('records')
    )
    print(f"Added batch {i} to {batch_end}")

print("Total items in persistent collection:", persistent_collection.count())
# Out:
# Added batch 0 to 5000
# Added batch 5000 to 10000
# Added batch 10000 to 15000
# Added batch 15000 to 20000
# Added batch 20000 to 25000
# Added batch 25000 to 30000
# Added batch 30000 to 35000
# Added batch 35000 to 40000
# Added batch 40000 to 45000
# Added batch 45000 to 50000
# Added batch 50000 to 55000
# Added batch 55000 to 56862
# Total items in persistent collection: 56862

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.4.0

# %%
1+2
# Out:
# 3

# %%
import numpy as np

# Save the embeddings matrix
np.save("../src/embeddings.npy", embeddings.toarray())

# Save the metadata needed to display results (aligned by row index with embeddings)
chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].to_csv("../src/chunks_metadata.csv", index=False)

print("Saved embeddings and metadata.")
# Out:
# Saved embeddings and metadata.

# %%
import pandas as pd
chunks_df = pd.read_csv("../data/chunks_df.csv")
print(chunks_df.shape)
# Out:
# (56862, 8)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded")
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Model loaded

# %%
chunk_texts = chunks_df['chunk_text'].tolist()

embeddings = model.encode(
    chunk_texts,
    batch_size=64,
    show_progress_bar=True,
    convert_to_numpy=True
)

print("Embeddings shape:", embeddings.shape)

# %%
import time

start = time.time()
test_embeddings = model.encode(chunk_texts[:5], convert_to_numpy=True)
print("Took", time.time() - start, "seconds")
print(test_embeddings.shape)
# Out:
# Took 0.47360730171203613 seconds
# (5, 384)

# %%
import time

start = time.time()
test_embeddings_1000 = model.encode(
    chunk_texts[:1000],
    batch_size=64,
    convert_to_numpy=True
)
print("Took", time.time() - start, "seconds")
print(test_embeddings_1000.shape)
# Out:
# Took 43.57127594947815 seconds
# (1000, 384)

# %%
import numpy as np
import time

all_embeddings = []
chunk_size = 10000
total = len(chunk_texts)

for i in range(0, total, chunk_size):
    batch_texts = chunk_texts[i:i+chunk_size]
    start = time.time()
    batch_embeddings = model.encode(batch_texts, batch_size=64, convert_to_numpy=True)
    all_embeddings.append(batch_embeddings)
    print(f"Processed {i} to {min(i+chunk_size, total)} — took {time.time()-start:.1f}s")

embeddings = np.vstack(all_embeddings)
print("Final embeddings shape:", embeddings.shape)
# Out:
# Processed 0 to 10000 — took 487.7s
# Processed 10000 to 20000 — took 472.8s
# Processed 20000 to 30000 — took 457.5s
# Processed 30000 to 40000 — took 504.3s
# Processed 40000 to 50000 — took 457.9s
# Processed 50000 to 56862 — took 315.1s
# Final embeddings shape: (56862, 384)

# %%
import numpy as np

np.save("../src/embeddings_real.npy", embeddings)
print("Saved real embeddings:", embeddings.shape)
# Out:
# Saved real embeddings: (56862, 384)

# %%
print(chunks_df['source_dataset'].value_counts())
# Out:
# source_dataset
# Apache     20443
# Eclipse    19025
# Mozilla    17394
# Name: count, dtype: int64

# %% [markdown]
# # Task 11

# %%
query_text = "application crashes on login with special characters in password"
query_vector = vectorizer.transform([query_text]).toarray().tolist()

results = collection.query(
    query_embeddings=query_vector,
    n_results=5
)

for i in range(len(results['ids'][0])):
    print(f"Match {i+1}: {results['metadatas'][0][i]['title']}")
    print(f"  Severity: {results['metadatas'][0][i]['severity']} | Source: {results['metadatas'][0][i]['source_dataset']}")
    print()
# Out:
# Match 1: Special characters don't show up on config page
#   Severity: normal | Source: Mozilla
#
# Match 2: Java applet password field gains focus but cannot be typed in.
#   Severity: major | Source: Mozilla
#
# Match 3: Login Fails if token is reset while waiting for a password.
#   Severity: normal | Source: Mozilla
#
# Match 4: [pwd-mngr] Password incorrectly stored
#   Severity: minor | Source: Mozilla
#
# Match 5: [pwd-mngr] Password incorrectly stored
#   Severity: minor | Source: Mozilla

# %%
query_text = "application crashes on login with special characters in password"
query_vector = vectorizer.transform([query_text]).toarray().tolist()
results = persistent_collection.query(
    query_embeddings=query_vector,
    n_results=5
)
for i in range(len(results['ids'][0])):
    print(f"Match {i+1}: {results['metadatas'][0][i]['title']}")
    print(f"  Severity: {results['metadatas'][0][i]['severity']} | Source: {results['metadatas'][0][i]['source_dataset']}")
    print()
# Out:
# Match 1: Special characters don't show up on config page
#   Severity: normal | Source: Mozilla
#
# Match 2: Java applet password field gains focus but cannot be typed in.
#   Severity: major | Source: Mozilla
#
# Match 3: Login Fails if token is reset while waiting for a password.
#   Severity: normal | Source: Mozilla
#
# Match 4: [pwd-mngr] Password incorrectly stored
#   Severity: minor | Source: Mozilla
#
# Match 5: [pwd-mngr] Password incorrectly stored
#   Severity: minor | Source: Mozilla

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
test_queries = [
    "application crashes on login with special characters in password",
    "build fails with dependency resolution error",
    "editor freezes when opening large file",
    "null pointer exception on startup",
    "plugin fails to load after update",
    "server returns 500 error on deployment",
    "memory leak during long running session",
    "syntax highlighting broken in code editor",
    "authentication token expires too quickly",
    "unable to connect to database after timeout"
]

for q in test_queries:
    qvec = model.encode([q], convert_to_numpy=True)
    sims = cosine_similarity(qvec, embeddings)[0]
    best_idx = sims.argmax()
    row = chunks_df.iloc[best_idx]
    print(f"Query: {q}")
    print(f"  Best match: {row['title']}  |  Source: {row['source_dataset']}  |  Score: {sims[best_idx]:.3f}")
    print()
# Out:
# Query: application crashes on login with special characters in password
#   Best match: password manager files have Unix line endings on Windows  |  Source: Mozilla  |  Score: 0.582
#
# Query: build fails with dependency resolution error
#   Best match: AIX Compilation error for 3.7a1pre source js/src/jsvector.h line 677.21: 1540-0274 (S) The name lookup for PointerRangeSize did not find a declaration  |  Source: Mozilla  |  Score: 0.735
#
# Query: editor freezes when opening large file
#   Best match: Opening large files to compare freezes the UI thread.  |  Source: Eclipse  |  Score: 0.709
#
# Query: null pointer exception on startup
#   Best match: engineConfigFactoryMissing (for concurrent requests)  |  Source: Apache  |  Score: 0.631
#
# Query: plugin fails to load after update
#   Best match: Update must uninstall the bundle from the osgi layer before deleting the file from the disk  |  Source: Eclipse  |  Score: 0.526
#
# Query: server returns 500 error on deployment
# ...

# %% [markdown]
# # save file in pickle and other tests

# %%
import pickle

with open("vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)

print("Vectorizer saved.")
# Out:
# Vectorizer saved.

# %%
import os
print("Current working directory:", os.getcwd())
print("File exists:", os.path.exists("vectorizer.pkl"))
print("File size (KB):", os.path.getsize("vectorizer.pkl") / 1024)
# Out:
# Current working directory: C:\Users\famil\OneDrive\Desktop\AI_Smart_Bug_Analyzer_-_Fix-_Advisor-\notebooks
# File exists: True
# File size (KB): 107.6220703125

# %%
with open("../src/vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)

print("Saved to src/ as well.")
# Out:
# Saved to src/ as well.

# %%
import os
print("Exists in src/:", os.path.exists("../src/vectorizer.pkl"))
# Out:
# Exists in src/: True

# %%
import chromadb
print(chromadb.__version__)
# Out:
# 1.1.1

# %%
import pandas as pd

chunks_df = pd.read_csv("../data/chunks_df.csv")
print(chunks_df.shape)
# Out:
# (56862, 8)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=3000, stop_words='english')
embeddings = vectorizer.fit_transform(chunks_df['chunk_text'])

print("Embeddings shape:", embeddings.shape)
# Out:
# Embeddings shape: (56862, 3000)

# %%
embeddings_list = embeddings.toarray().tolist()
print("Done converting to list.")
# Out:
# Done converting to list.

# %%
persistent_client.delete_collection(name="bug_knowledge_base")
print("Deleted old collection.")
# Out:
# Deleted old collection.

# %%
existing = persistent_client.list_collections()
print(existing)
# Out:
# [Collection(name=bug_knowledge_base)]

# %%
existing_collection = persistent_client.get_collection(name="bug_knowledge_base")
print("Count:", existing_collection.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 existing_collection = persistent_client.get_collection(name="bug_knowledge_base")
#       2 print("Count:", existing_collection.count())
#
# NameError: name 'persistent_client' is not defined

# %%
persistent_collection = existing_collection

batch_size = 5000
for i in range(0, len(chunks_df), batch_size):
    batch_end = min(i + batch_size, len(chunks_df))
    persistent_collection.add(
        ids=chunks_df['chunk_id'].iloc[i:batch_end].tolist(),
        embeddings=embeddings_list[i:batch_end],
        documents=chunks_df['chunk_text'].iloc[i:batch_end].tolist(),
        metadatas=chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].iloc[i:batch_end].to_dict('records')
    )
    print(f"Added batch {i} to {batch_end}")

print("Total items in persistent collection:", persistent_collection.count())
# Out:
# Added batch 0 to 5000
# Added batch 5000 to 10000
# Added batch 10000 to 15000
# Added batch 15000 to 20000
# Added batch 20000 to 25000
# Added batch 25000 to 30000
# Added batch 30000 to 35000
# Added batch 35000 to 40000
# Added batch 40000 to 45000
# Added batch 45000 to 50000
# Added batch 50000 to 55000
# Added batch 55000 to 56862
# Total items in persistent collection: 56862

# %%
query_text = "application crashes on login with special characters in password"
query_vector = vectorizer.transform([query_text]).toarray().tolist()
results = persistent_collection.query(
    query_embeddings=query_vector,
    n_results=5
)
for i in range(len(results['ids'][0])):
    print(f"Match {i+1}: {results['metadatas'][0][i]['title']}")
    print(f"  Severity: {results['metadatas'][0][i]['severity']} | Source: {results['metadatas'][0][i]['source_dataset']}")
    print()
# Out:
# Match 1: Special characters don't show up on config page
#   Severity: normal | Source: Mozilla
#
# Match 2: Java applet password field gains focus but cannot be typed in.
#   Severity: major | Source: Mozilla
#
# Match 3: Login Fails if token is reset while waiting for a password.
#   Severity: normal | Source: Mozilla
#
# Match 4: [pwd-mngr] Password incorrectly stored
#   Severity: minor | Source: Mozilla
#
# Match 5: [pwd-mngr] Password incorrectly stored
#   Severity: minor | Source: Mozilla

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.4.0

# %%
1+2
# Out:
# 3

# %%
import numpy as np

# Save the embeddings matrix
np.save("../src/embeddings.npy", embeddings.toarray())

# Save the metadata needed to display results (aligned by row index with embeddings)
chunks_df[['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']].to_csv("../src/chunks_metadata.csv", index=False)

print("Saved embeddings and metadata.")
# Out:
# Saved embeddings and metadata.

# %%
import pandas as pd
chunks_df = pd.read_csv("../data/chunks_df.csv")
print(chunks_df.shape)
# Out:
# (56862, 8)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded")
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Model loaded

# %%
chunk_texts = chunks_df['chunk_text'].tolist()

embeddings = model.encode(
    chunk_texts,
    batch_size=64,
    show_progress_bar=True,
    convert_to_numpy=True
)

print("Embeddings shape:", embeddings.shape)

# %%
import time

start = time.time()
test_embeddings = model.encode(chunk_texts[:5], convert_to_numpy=True)
print("Took", time.time() - start, "seconds")
print(test_embeddings.shape)
# Out:
# Took 0.47360730171203613 seconds
# (5, 384)

# %%
import time

start = time.time()
test_embeddings_1000 = model.encode(
    chunk_texts[:1000],
    batch_size=64,
    convert_to_numpy=True
)
print("Took", time.time() - start, "seconds")
print(test_embeddings_1000.shape)
# Out:
# Took 43.57127594947815 seconds
# (1000, 384)

# %%
import numpy as np
import time

all_embeddings = []
chunk_size = 10000
total = len(chunk_texts)

for i in range(0, total, chunk_size):
    batch_texts = chunk_texts[i:i+chunk_size]
    start = time.time()
    batch_embeddings = model.encode(batch_texts, batch_size=64, convert_to_numpy=True)
    all_embeddings.append(batch_embeddings)
    print(f"Processed {i} to {min(i+chunk_size, total)} — took {time.time()-start:.1f}s")

embeddings = np.vstack(all_embeddings)
print("Final embeddings shape:", embeddings.shape)
# Out:
# Processed 0 to 10000 — took 487.7s
# Processed 10000 to 20000 — took 472.8s
# Processed 20000 to 30000 — took 457.5s
# Processed 30000 to 40000 — took 504.3s
# Processed 40000 to 50000 — took 457.9s
# Processed 50000 to 56862 — took 315.1s
# Final embeddings shape: (56862, 384)

# %%
import numpy as np

np.save("../src/embeddings_real.npy", embeddings)
print("Saved real embeddings:", embeddings.shape)
# Out:
# Saved real embeddings: (56862, 384)

# %%
print(chunks_df['source_dataset'].value_counts())
# Out:
# source_dataset
# Apache     20443
# Eclipse    19025
# Mozilla    17394
# Name: count, dtype: int64

# %%
query_vector = model.encode(["app crash on login"], convert_to_numpy=True)
similarities = cosine_similarity(query_vector, embeddings)[0]

# Add similarity scores to a copy of chunks_df for inspection
chunks_df['similarity'] = similarities

# Show top 5 per source_dataset separately
for source in ['Mozilla', 'Eclipse', 'Apache']:
    print(f"\n--- Top 3 in {source} ---")
    top = chunks_df[chunks_df['source_dataset'] == source].sort_values('similarity', ascending=False).head(3)
    for _, row in top.iterrows():
        print(f"{row['similarity']:.3f} | {row['title']}")
# Out:
# --- Top 3 in Mozilla ---
# 0.588 | [webgl] Null deref crash in gleRunVertexSubmitImmediate / mozilla::WebGLContext::DrawElements
# 0.547 | crash while doing nothing... [@ nsMsgCompose::OnSendNotPerformed]
# 0.545 | mozilla 0.8.1 crashes when I try to login into bugzilla
#
# --- Top 3 in Eclipse ---
# 0.486 | Crash at startup
# 0.457 | Invalid login message accessibility
# 0.453 | improve feedback on startup railure
#
# --- Top 3 in Apache ---
# 0.445 | Automation crashes player (a211) when repeatedly bouncing app
# 0.444 | DTD in sqlMapConfig doesn't get resolved when not connected to internet
# 0.413 | can't able to login to roller
