# %% [markdown]
# # Task 1 : Triage Agent

# %%
import pandas as pd 
import numpy as np

print("Lets  start")
# Out:
# Lets  start

# %%
knowledge_base_clean = pd.read_csv("../data/knowledge_base_cleaned.csv")

print("Shape:",knowledge_base_clean.shape)
print("\nSeverity value counts :\n")
print(knowledge_base_clean['severity'].value_counts())
# Out:
# Shape: (29161, 9)
#
# Severity value counts :
#
# severity
# normal      15110
# Major        5775
# Minor        2171
# major        1689
# critical      964
# minor         919
# Critical      575
# trivial       456
# blocker       408
# Trivial       403
# Unknown       353
# Blocker       338
# Name: count, dtype: int64

# %%
knowledge_base_clean.head()
# Out:
#                          bug_id  \
# 0               BUGZILLA-294734
# 1     OTHER_APPLICATIONS-363323
# 2    SUPPORT.MOZILLA.ORG-398246
# 3     OTHER_APPLICATIONS-318859
# 4  DEVELOPER.MOZILLA.ORG-416840
#
#                                                title  \
# 0                          Emergency 2.16.10 Release
# 1  DOM View is really inefficient with setting wh...
# 2   Add support for custom cookies and cache headers
# 3   DCC functionality in ChatZilla isn't functional.
# 4                                      Fix and cruft
#
#                                          description severity resolution  \
# 0  2.16.9 is broken -- many users can't enter bug...  blocker      fixed
# 1  From comment in url: Current code: menuitem ->...   normal      fixed
# 2  Adding support for custom headers and cookie n...  blocker      fixed
# 3  User-Agent: Mozilla/5.0 (Macintosh U PPC Mac O...   normal      fixed
# 4  Since we removed the breadcrumbs and title-ove...   normal      fixed
#
#      status source_dataset  stack_trace      product_component
# 0  resolved        Mozilla          NaN               BUGZILLA
# 1  resolved        Mozilla          NaN     OTHER_APPLICATIONS
# 2  resolved        Mozilla          NaN    SUPPORT.MOZILLA.ORG
# 3  resolved        Mozilla          NaN     OTHER_APPLICATIONS
# 4  resolved        Mozilla          NaN  DEVELOPER.MOZILLA.ORG

# %%
knowledge_base_clean['severity'] = knowledge_base_clean['severity'].str.lower()
print(knowledge_base_clean['severity'].value_counts())
# Out:
# severity
# normal      15110
# major        7464
# minor        3090
# critical     1539
# trivial       859
# blocker       746
# unknown       353
# Name: count, dtype: int64

# %%
severity_mapping = {
    'blocker':'Critical',
'critical':'Critical',
'major':'High',
'normal':'Medium',
'minor':'Low',
'trivial':'Low',
'unknown':'Medium',

}

knowledge_base_clean['severity_mapped'] = knowledge_base_clean['severity'].map(severity_mapping)
print(knowledge_base_clean['severity_mapped'].value_counts())
# Out:
# severity_mapped
# Medium      15463
# High         7464
# Low          3949
# Critical     2285
# Name: count, dtype: int64

# %%
knowledge_base_clean.to_csv("../data/knowledge_base_with_severity.csv", index = False)
print("Saved")
# Out:
# Saved

# %% [markdown]
# ## New plan

# %%
import sys
# !{sys.executable}  -m pip install groq python-dotenv

# %%
import os

print("Current notebook working directory:", os.getcwd())
print("\nLooking for .env in parent folder...")
print("Exists:", os.path.exists("../.env"))

# %%
env_content = "API_KEY_NAME= API_KEY"
with open  ("../.env",'w') as f:
    f.write(env_content)
print("Created .env file ")
# Out:
# Created .env file

# %%
import os
print("Exists:", os.path.exists("../.env"))
# Out:
# Exists: True

# %%
from dotenv import load_dotenv
import os 

load_dotenv("../.env",override=True)

api_key = os.getenv("bug-analyzer-triage")

if api_key:
    print("API loaded successfully . Starrts with :",api_key[:8] , "...")
else:
    print("API key not found - check your .env file location/content")
# Out:
# API loaded successfully . Starrts with : gsk_mpz3 ...

# %%
knowledge_base_clean = pd.read_csv("../data/knowledge_base_with_severity.csv")

print(knowledge_base_clean.columns.tolist())
# Out:
# ['bug_id', 'title', 'description', 'severity', 'resolution', 'status', 'source_dataset', 'stack_trace', 'product_component', 'severity_mapped']

# %%
from groq import Groq
import json

client  =  Groq (api_key=api_key)

# system_prompt ="""
# You are a bug triage assistant. You are given the title, description, and stack trace of a submitted bug, and you classify it by severity, priority, and affected component, with confidence scoring and reasoning.

# Reply ONLY in valid JSON, with this exact structure:
# {"bug_id": "...", "severity": "Critical", "confidence": 0.85, "reasoning": "...", "priority": "...", "component": "Login"}

# Field definitions:
# - bug_id: if provided, use it; otherwise use "unknown"
# - severity: must be exactly one of Critical, High, Medium, Low — no other words
# - confidence: a score from 0 to 1 representing how confident you are in this classification
# - reasoning: a brief explanation of why you classified it this way
# - priority: how urgently this needs to be addressed — Immediate, High, Medium, or Low (related to but different from severity: severity is impact, priority is urgency)
# - component: which part/module of the software seems affected, inferred from the content (e.g. "Login", "Database", "UI/Rendering") — do not restrict to a fixed list

# If you encounter other severity-like words, map them using this table:
# blocker/critical -> Critical, major -> High, normal/unknown -> Medium, minor/trivial -> Low


# """


system_prompt = """You are a bug triage assistant. You are given the title, description, and stack trace of a submitted bug, and you classify it by severity, priority, and affected component, with confidence scoring and reasoning.

IMPORTANT CALIBRATION: Most everyday bugs are Medium severity, not Critical or High. Reserve Critical/High for bugs that cause crashes, data loss, security issues, or completely block core functionality. Reserve Low for cosmetic issues, minor inconveniences, or feature requests. The MAJORITY of real-world bugs are routine Medium severity — do not over-classify ordinary bugs as urgent just because they mention words like "error" or "exception."

Examples for calibration:
- "App crashes on startup, no workaround" -> Critical
- "Login fails for all users" -> Critical  
- "Button text is misaligned by 2px" -> Low
- "Feature request: add dark mode" -> Low
- "Export function occasionally produces incorrect date format" -> Medium
- "Search results are slow to load under heavy traffic" -> Medium

Reply ONLY in valid JSON, with this exact structure:
{"bug_id": "...", "severity": "Critical", "confidence": 0.85, "reasoning": "...", "priority": "...", "component": "Login"}

Field definitions:
- bug_id: if provided, use it; otherwise use "unknown"
- severity: must be exactly one of Critical, High, Medium, Low — no other words
- confidence: a score from 0 to 1 representing how confident you are in this classification
- reasoning: a brief explanation of why you classified it this way
- priority: how urgently this needs to be addressed — Immediate, High, Medium, or Low (related to but different from severity: severity is impact, priority is urgency)
- component: which part/module of the software seems affected, inferred from the content (e.g. "Login", "Database", "UI/Rendering") — do not restrict to a fixed list

If you encounter other severity-like words, map them using this table:
blocker/critical -> Critical, major -> High, normal/unknown -> Medium, minor/trivial -> Low
"""


test_bug= knowledge_base_clean.iloc[0]
user_message = f"Title:{test_bug['title']} \nDescription:{test_bug['description']} "

response = client.chat.completions.create(
    model = 'llama-3.1-8b-instant',
    messages=[
        {"role":"system","content":system_prompt},
        {"role":"user","content":user_message}
    ],
    temperature=0.2
)

result = response.choices[0].message.content
print(result)
# Out:
# {"bug_id": "unknown", "severity": "Critical", "confidence": 0.95, "reasoning": "The issue prevents many users from entering bugs, which is a core functionality. This is a clear blocker for the current release.", "priority": "Immediate", "component": "Release Management"}

# %%
knowledge_base_clean.columns
# Out:
# Index(['bug_id', 'title', 'description', 'severity', 'resolution', 'status',
#        'source_dataset', 'stack_trace', 'product_component'],
#       dtype='str')

# %%
print("Actual bug title:", test_bug['title'])
print("Actual bug description:", test_bug['description'][:200])
print("\nActual historical severity (ground truth):", test_bug['severity'])
print("\nLLM's predicted severity:", "Critical")
# Out:
# Actual bug title: Emergency 2.16.10 Release
# Actual bug description: 2.16.9 is broken -- many users can't enter bugs on it particularly not from a fresh install. So we need to pull 2.16.9 and post a 2.16.10 instead.
#
# Actual historical severity (ground truth): blocker
#
# LLM's predicted severity: Critical

# %%
print("Actual bug title:", test_bug['title'])
print("Actual bug description:", test_bug['description'][:200])
print("\nActual historical severity (ground truth):", test_bug['severity_mapped'])
print("\nLLM's predicted severity:", "Critical")
# Out:
# Actual bug title: Emergency 2.16.10 Release
# Actual bug description: 2.16.9 is broken -- many users can't enter bugs on it particularly not from a fresh install. So we need to pull 2.16.9 and post a 2.16.10 instead.
#
# Actual historical severity (ground truth): Critical
#
# LLM's predicted severity: Critical

# %%
import time

severities = ['Critical', 'High', 'Medium', 'Low']
sample_bugs = pd.concat([
    knowledge_base_clean[knowledge_base_clean['severity_mapped'] == s].sample(1, random_state=42)
    for s in severities
]).reset_index(drop=True)

print("Testing on", len(sample_bugs), "sample bugs (one per severity level)\n")
print(sample_bugs[['title', 'severity_mapped']])
for idx, bug in sample_bugs.iterrows():
    user_message = f"Title: {bug['title']}\nDescription: {bug['description']}\nStack Trace: Not available"

    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message}
        ],
        temperature=0.2
    )

    result = response.choices[0].message.content

    print(f"--- Bug {idx+1} ---")
    print("Title:", bug['title'])
    print("Actual severity:", bug['severity_mapped'])
    print("LLM response:", result)
    print()

    time.sleep(1)  # small pause to avoid hitting rate limits
# Out:
# Testing on 4 sample bugs (one per severity level)
#
#                                                title severity_mapped
# 0  support project inheritence with flat project ...        Critical
# 1  Client use Axis-cpp, string array type not com...            High
# 2      [DND] Gtk ImageTransfer prefers JPEG over PNG          Medium
# 3                              IoSession.isClosing()             Low
# --- Bug 1 ---
# Title: support project inheritence with flat project layout
# Actual severity: Critical
# LLM response: {
#   "bug_id": "unknown",
#   "severity": "High",
#   "confidence": 0.9,
#   "reasoning": "The bug description mentions a specific limitation in project inheritance due to a flat directory structure, which suggests a significant impact on project functionality.",
#   "priority": "High",
#   "component": "Project Management"
# }
#
# --- Bug 2 ---
# Title: Client use Axis-cpp, string array type not compatible with Axic at server
# Actual severity: High
# LLM response: {
#   "bug_id": "unknown",
#   "severity": "Critical",
#   "confidence": 0.9,
#   "reasoning": "The bug description mentions a 'UserException' and 'SAXException' which indicates a critical error. The issue is also related to the compatibility of string array types between the client and server, which could lead to data corruption or loss.",
#   "priority": "High",
#   "component": "Web Services"
# }
#
# --- Bug 3 ---
# Title: [DND] Gtk ImageTransfer prefers JPEG over PNG
# Actual severity: Medium
# LLM response: {
#   "bug_id": "unknown",
#   "severity": "Medium",
#   "confidence": 0.9,
#   "reasoning": "The issue affects the user experience by importing fuzzy images, but it does not prevent the application from functioning. The description suggests a workaround (using PNG) and the problem seems to be related to the ImageTransfer component.",
#   "priority": "Medium",
#   "component": "ImageTransfer"
# }
#
# --- Bug 4 ---
# Title: IoSession.isClosing()
# Actual severity: Low
# LLM response: {
#   "bug_id": "unknown",
#   "severity": "Medium",
#   "confidence": 0.8,
#   "reasoning": "The bug report suggests a feature enhancement to provide a method to check if the connection close request is being processed. This does not indicate a critical issue but rather a useful addition to the existing functionality.",
#   "priority": "Medium",
#   "component": "IoSession"
# }

# %%
import random

random.seed(42)
test_sample = knowledge_base_clean.sample(30, random_state=42).reset_index(drop=True)

severity_order = {'Low': 0, 'Medium': 1, 'High': 2, 'Critical': 3}

exact_matches = 0
adjacent_matches = 0
results_log = []

for idx, bug in test_sample.iterrows():
    user_message = f"Title: {bug['title']}\nDescription: {bug['description']}\nStack Trace: Not available"

    try:
        response = client.chat.completions.create(
            model="llama-3.1-8b-instant",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_message}
            ],
            temperature=0.2
        )
        result = json.loads(response.choices[0].message.content)
        predicted = result.get('severity', 'Medium')
    except Exception as e:
        predicted = 'Medium'
        print(f"Error on bug {idx}: {e}")

    actual = bug['severity_mapped']

    is_exact = (predicted == actual)
    is_adjacent = abs(severity_order.get(predicted, 1) - severity_order.get(actual, 1)) <= 1

    if is_exact:
        exact_matches += 1
    if is_adjacent:
        adjacent_matches += 1

    results_log.append({'title': bug['title'], 'actual': actual, 'predicted': predicted, 'exact': is_exact})

    time.sleep(1)

print(f"\nExact match accuracy: {exact_matches}/{len(test_sample)} = {exact_matches/len(test_sample)*100:.1f}%")
print(f"Adjacent (±1 level) accuracy: {adjacent_matches}/{len(test_sample)} = {adjacent_matches/len(test_sample)*100:.1f}%")
# Out:
# Error on bug 24: Expecting value: line 1 column 1 (char 0)
# Error on bug 26: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama-3.1-8b-instant` in organization `org_01kxfy6ngtfr49wg8hhv46tepc` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Used 5245, Requested 768. Please try again in 130ms. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
#
# Exact match accuracy: 18/30 = 60.0%
# Adjacent (±1 level) accuracy: 25/30 = 83.3%

# %%
results_df = pd.DataFrame(results_log)
print("Prediction distribution:")
print(results_df['predicted'].value_counts())
print("\nActual distribution (in this sample):")
print(results_df['actual'].value_counts())

print("\n--- Biggest misses (predicted far from actual) ---")
severity_order = {'Low': 0, 'Medium': 1, 'High': 2, 'Critical': 3}
results_df['distance'] = results_df.apply(
    lambda r: abs(severity_order.get(r['predicted'], 1) - severity_order.get(r['actual'], 1)), axis=1
)
print(results_df[results_df['distance'] >= 2][['title', 'actual', 'predicted']])
# Out:
# Prediction distribution:
# predicted
# Medium      22
# Low          4
# Critical     4
# Name: count, dtype: int64
#
# Actual distribution (in this sample):
# actual
# Medium      19
# Low          5
# Critical     3
# High         3
# Name: count, dtype: int64
#
# --- Biggest misses (predicted far from actual) ---
#                                                 title    actual predicted
# 0          Add Mockito and AssertJ in target platform  Critical       Low
# 7   SWTException: Invalid thread access on disconn...       Low  Critical
# 10  Access Error trying to access vpg when creatin...    Medium  Critical
# 19  std::numeric_limits ::traps = false when integ...       Low  Critical
# 21             missing metadata errors on the console  Critical    Medium

# %%
from groq import Groq
import json
client = Groq(api_key=api_key)
import time

def call_llm_with_retry(system_prompt, user_message, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model="llama-3.1-8b-instant",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_message}
                ],
                temperature=0.2
            )
            return json.loads(response.choices[0].message.content)
        except Exception as e:
            if "rate_limit" in str(e).lower() or "429" in str(e):
                wait_time = (attempt + 1) * 3  # wait 3s, then 6s, then 9s
                print(f"Rate limited, waiting {wait_time}s...")
                time.sleep(wait_time)
            else:
                print(f"Non-rate-limit error: {e}")
                break
    return None  # all retries failed

# %%
def triage_agent(title, description, stack_trace="Not available", bug_id="unknown"):
    user_message = f"Title: {title}\nDescription: {description}\nStack Trace: {stack_trace}"
    
    result = call_llm_with_retry(system_prompt, user_message)
    
    if result is None:
        result = {"severity": "Medium", "confidence": 0.0, "reasoning": "LLM call failed after retries", "priority": "Medium", "component": "Unknown"}
    
    result['bug_id'] = bug_id
    return result

# Quick test
test_result = triage_agent(
    title="App crashes on login",
    description="Users report the app crashes immediately after entering valid credentials.",
    bug_id="TEST-001"
)
print(test_result)
# Out:
# {'bug_id': 'TEST-001', 'severity': 'Critical', 'confidence': 0.95, 'reasoning': 'The title explicitly states the app crashes, which is a clear indicator of a Critical severity issue. The description also confirms that the crash occurs after entering valid credentials, further supporting this classification.', 'priority': 'Immediate', 'component': 'Login'}

# %%
results_df.to_csv("../data/triage_validation_results.csv", index=False)
print("Saved validation results")
# Out:
# Saved validation results

# %% [markdown]
# # Task 2:Log Analysis Agent

# %%
import pandas as pd 
import glob

csv_files = glob.glob("../data/stack_traces/*.csv")
print("Found " , len(csv_files),"files :")
for f in csv_files:
    print("-",f)
# Out:
# Found  11 files :
# - ../data/stack_traces\cpp_smart_analyzer_dataset_500.csv
# - ../data/stack_traces\css_smart_analyzer_dataset_v2_500.csv
# - ../data/stack_traces\c_smart_analyzer_dataset_500.csv
# - ../data/stack_traces\go_smart_analyzer_dataset_500.csv
# - ../data/stack_traces\html_smart_analyzer_dataset_v2_500.csv
# - ../data/stack_traces\java_smart_analyzer_dataset_500.csv
# - ../data/stack_traces\js_smart_analyzer_dataset_500.csv
# - ../data/stack_traces\php_smart_analyzer_dataset_500.csv
# - ../data/stack_traces\python_10_out_of_10_dataset_500.csv
# - ../data/stack_traces\rust_smart_analyzer_dataset_v3_500.csv
# - ../data/stack_traces\ts_smart_analyzer_dataset_500.csv

# %%
all_dfs = [pd.read_csv(f)  for f in csv_files]
stack_trace_df = pd.concat(all_dfs , ignore_index = True)
print("Combined shape :",stack_trace_df.shape)
print("\nLanguages distribution :")
print(stack_trace_df['language'].value_counts())
# Out:
# Combined shape : (5500, 7)
#
# Languages distribution :
# language
# cpp           500
# css           500
# c             500
# go            500
# html          500
# java          500
# javascript    500
# php           500
# python        500
# rust          500
# typescript    500
# Name: count, dtype: int64

# %%
stack_trace_df.to_csv("../data/stack_trace_combined.csv",index=False)
print("Saved combined stack trace dataset")
# Out:
# Saved combined stack trace dataset

# %%
" parses stack traces and error messages, identifies exception type, failure point, and affected code path with structured output."
# Out:
# ' parses stack traces and error messages, identifies exception type, failure point, and affected code path with structured output.'

# %% [markdown]
# ## Prompt

# %%
'''Your job is extract the useful information for messy error text 
(like extracting  identifies exception type, failure point, and affected code path with structured output )

-  Input will be given to you  is  Raw Stack traces / messy error text / Traceback  or code 

-  What you have to do is :
    1) Cleans up the messy (Raw Stack traces / messy error text / Traceback  or code ) and you have to extract useful information like (like extracting  identifies exception type, failure point, and affected code path with structured output )

    2)Parses stack traces and error message  means converts raw, multi-line error logs into structured data objects containing individual frames with specific file names in jason format

     3) output should have these fields like :   
            error_type : what type of error is it , indexerror , syntaxerror , zerodivisionerror etc 
            
            failure_location, make it hold the actual line info from the traceback 
            
            code_path field describing the chain of function calls (even if it's short/simple for basic examples) 
            
            reasoning = a short sentence explaining why it concluded this. 
            
                Confidence here means something much simpler: "how sure am I that I read this correctly?".
                
                            What it actually means here: the Log Analysis Agent is just reading a messy error message and trying to extract facts from it (exception type, where it broke, etc.). 
                            
                            Sometimes the traceback is crystal clear, and sometimes it's messy/ambiguous. 
                            
                            "Confidence" is simply: "how certain am I that I extracted the right information from this specific error text?".
                            
                            if the stack trace is clean and obvious (like your IndexError example — very clear, exact line number given), confidence should be high (0.9+). 
                            
                            If the error text is vague or cut off, confidence would be lower — the AI is saying "I did my best to extract this, but the input wasn't fully clear."
                            
            

     
     examples for understanding:
1. Python
IndentationError

Input

Cell In[119], line 3
    return payload_2
    ^
IndentationError: unindent does not match any outer indentation level

Output

{
  "error_type": "IndentationError",
  "failure_location": "Cell In[119], line 3",
  "code_path": "return payload_2 executed directly within the current code block; indentation parsing failed before execution",
  "confidence": 0.99,
  "reasoning": "The 'return' statement has inconsistent indentation that does not align with the surrounding block, causing Python's parser to reject the code."
}

2. JavaScript
 TypeError

Input

/workspace/service_2.js:3
console.log(session_2[5].id);
                            ^

TypeError: Cannot read properties of undefined (reading 'id')
    at Object.<anonymous> (/workspace/service_2.js:3:15)
    at Module._compile (internal/modules/cjs/loader.js:1159:30)
    at Object.Module._extensions..js (internal/modules/cjs/loader.js:1195:10)

Output

{
  "error_type": "TypeError",
  "failure_location": "/workspace/service_2.js:3:15",
  "code_path": "Top-level execution → console.log(session_2[5].id)",
  "confidence": 0.99,
  "reasoning": "The expression 'session_2[5]' evaluated to undefined, so accessing its 'id' property caused a TypeError."
}

3. C
a. Invalid Initializer

Input

parser_4.c: In function ‘main’:
parser_4.c:3:15: error: invalid initializer / incompatible types when initializing type ‘int’ using type ‘char *’
    3 |     int val = str;
      |               ^~~

Output

{
  "error_type": "Compilation Error",
  "failure_location": "parser_4.c:3:15",
  "code_path": "main() → variable initialization: int val = str",
  "confidence": 0.85,
  "reasoning": "An integer variable was initialized using a character pointer, which is an incompatible type conversion in C."
}



4.C++
 No Matching Member Function

Input

session_2.cpp: In function ‘int main()’:
session_2.cpp:5:17: error: no matching member function for call to 'insert'
    5 |     ages.insert(10, "John");
      |     ~~~~~~~~~~~~^~~~~~~~~~~
In file included from /usr/include/c++/11/map:61:
/usr/include/c++/11/bits/stl_map.h:810:7: note: candidate function not viable: requires a single pair object

Output

{
  "error_type": "Compilation Error",
  "failure_location": "session_2.cpp:5:17",
  "code_path": "main() → std::map::insert(10, \"John\")",
  "confidence": 0.95,
  "reasoning": "The std::map::insert() function was called with arguments that do not match any valid overload. It expects a key-value pair or another supported insertion form."
}



5.Java
 NullPointerException

Input

Exception in thread "main" java.lang.NullPointerException: Cannot invoke "String.indexOf(String)" because "recordsList_2" is null
    at MetricsEngine_2.updateCache_2(Api_2.java:110)

Output

{
  "error_type": "NullPointerException",
  "failure_location": "Api_2.java:110",
  "code_path": "main thread → MetricsEngine_2.updateCache_2() → String.indexOf()",
  "confidence": 0.99,
  "reasoning": "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."
}



'''
# Out:
# 'Your job is extract the useful information for messy error text \n(like extracting  identifies exception type, failure point, and affected code path with structured output )\n\n-  Input will be given to you  is  Raw Stack traces / messy error text / Traceback  or code \n\n-  What you have to do is :\n    1) Cleans up the messy (Raw Stack traces / messy error text / Traceback  or code ) and you have to extract useful information like (like extracting  identifies exception type, failure point, and affected code path with structured output )\n\n    2)Parses stack traces and error message  means converts raw, multi-line error logs into structured data objects containing individual frames with specific file names in jason format\n\n     3) output should have these fields like :   \n     examples for understanding:\n1. Python\na. IndentationError\n\nInput\n\nCell In[119], line 3\n    return payload_2\n    ^\nIndentationError: unindent does not match any outer indentation level\n\nOutput\n\n{\n  "error_type": "IndentationError",\n  "failure_location": "Cell In[119], line 3",\n  "code_path": "return payload_2 executed directly within the current code block; indentation parsing failed before execution",\n  "confidence": 0.99,\n  "reasoning": "The \'return\' statement has inconsistent indentation that does not align with the surrounding block, causing Python\'s parser to reject the code."\n}\nb. NameError\n\nInput\n\nTraceback (most recent call last):\n  Cell In[92], line 4, in <module>\n    update_cache_4()\n  Cell In[92], line 2, in update_cache_4\n        1 def update_cache_4():\n----> 2     return config_4_missing + 10\n\nNameError: name \'config_4_missing\' is not defined\n\nOutput\n\n{\n  "error_type": "NameError",\n  "failure_location": "Cell In[92], line 2, in update_cache_4",\n  "code_path": "<module> → update_cache_4() → return config_4_missing + 10",\n  "confidence": 0.99,\n  "reasoning": "The variable \'config_4_missing\' was referenced inside the function before being defined or assigned."\n}\n2. JavaScript\na. TypeError\n\nInput\n\n/workspace/service_2.js:3\nconsole.log(session_2[5].id);\n                            ^\n\nTypeError: Cannot read properties of undefined (reading \'id\')\n    at Object.<anonymous> (/workspace/service_2.js:3:15)\n    at Module._compile (internal/modules/cjs/loader.js:1159:30)\n    at Object.Module._extensions..js (internal/modules/cjs/loader.js:1195:10)\n\nOutput\n\n{\n  "error_type": "TypeError",\n  "failure_location": "/workspace/service_2.js:3:15",\n  "code_path": "Top-level execution → console.log(session_2[5].id)",\n  "confidence": 0.99,\n  "reasoning": "The expression \'session_2[5]\' evaluated to undefined, so accessing its \'id\' property caused a TypeError."\n}\nb. SyntaxError\n\nInput\n\n/workspace/service_6.js:1\nconst values = [1, 2, 3;\n                       ^\n\nSyntaxError: Unexpected token \';\'\n\nOutput\n\n{\n  "error_type": "SyntaxError",\n  "failure_location": "/workspace/service_6.js:1",\n  "code_path": "Top-level variable declaration while parsing the JavaScript source",\n  "confidence": 0.99,\n  "reasoning": "The array literal was not closed with \']\', so the parser encountered an unexpected semicolon."\n}\n3. C\na. Invalid Initializer\n\nInput\n\nparser_4.c: In function ‘main’:\nparser_4.c:3:15: error: invalid initializer / incompatible types when initializing type ‘int’ using type ‘char *’\n    3 |     int val = str;\n      |               ^~~\n\nOutput\n\n{\n  "error_type": "Compilation Error",\n  "failure_location": "parser_4.c:3:15",\n  "code_path": "main() → variable initialization: int val = str",\n  "confidence": 0.99,\n  "reasoning": "An integer variable was initialized using a character pointer, which is an incompatible type conversion in C."\n}\nb. Double Free\n\nInput\n\ndouble free or corruption (out)\nAborted (core dumped)\n(gdb) bt\n#0  __GI_raise ...\n#1  __GI_abort ...\n#2  __libc_message ...\n#3  malloc_printerr ...\n#4  _int_free ...\n#5  main () at  ...

# %%
'''examples for understanding:
1. Python
a. IndentationError

Input

Cell In[119], line 3
    return payload_2
    ^
IndentationError: unindent does not match any outer indentation level

Output

{
  "error_type": "IndentationError",
  "failure_location": "Cell In[119], line 3",
  "code_path": "return payload_2 executed directly within the current code block; indentation parsing failed before execution",
  "confidence": 0.99,
  "reasoning": "The 'return' statement has inconsistent indentation that does not align with the surrounding block, causing Python's parser to reject the code."
}
b. NameError

Input

Traceback (most recent call last):
  Cell In[92], line 4, in <module>
    update_cache_4()
  Cell In[92], line 2, in update_cache_4
        1 def update_cache_4():
----> 2     return config_4_missing + 10

NameError: name 'config_4_missing' is not defined

Output

{
  "error_type": "NameError",
  "failure_location": "Cell In[92], line 2, in update_cache_4",
  "code_path": "<module> → update_cache_4() → return config_4_missing + 10",
  "confidence": 0.99,
  "reasoning": "The variable 'config_4_missing' was referenced inside the function before being defined or assigned."
}
2. JavaScript
a. TypeError

Input

/workspace/service_2.js:3
console.log(session_2[5].id);
                            ^

TypeError: Cannot read properties of undefined (reading 'id')
    at Object.<anonymous> (/workspace/service_2.js:3:15)
    at Module._compile (internal/modules/cjs/loader.js:1159:30)
    at Object.Module._extensions..js (internal/modules/cjs/loader.js:1195:10)

Output

{
  "error_type": "TypeError",
  "failure_location": "/workspace/service_2.js:3:15",
  "code_path": "Top-level execution → console.log(session_2[5].id)",
  "confidence": 0.99,
  "reasoning": "The expression 'session_2[5]' evaluated to undefined, so accessing its 'id' property caused a TypeError."
}
b. SyntaxError

Input

/workspace/service_6.js:1
const values = [1, 2, 3;
                       ^

SyntaxError: Unexpected token ';'

Output

{
  "error_type": "SyntaxError",
  "failure_location": "/workspace/service_6.js:1",
  "code_path": "Top-level variable declaration while parsing the JavaScript source",
  "confidence": 0.99,
  "reasoning": "The array literal was not closed with ']', so the parser encountered an unexpected semicolon."
}
3. C
a. Invalid Initializer

Input

parser_4.c: In function ‘main’:
parser_4.c:3:15: error: invalid initializer / incompatible types when initializing type ‘int’ using type ‘char *’
    3 |     int val = str;
      |               ^~~

Output

{
  "error_type": "Compilation Error",
  "failure_location": "parser_4.c:3:15",
  "code_path": "main() → variable initialization: int val = str",
  "confidence": 0.99,
  "reasoning": "An integer variable was initialized using a character pointer, which is an incompatible type conversion in C."
}
b. Double Free

Input

double free or corruption (out)
Aborted (core dumped)
(gdb) bt
#0  __GI_raise ...
#1  __GI_abort ...
#2  __libc_message ...
#3  malloc_printerr ...
#4  _int_free ...
#5  main () at matrix_12.c:5

Output

{
  "error_type": "Double Free / Memory Corruption",
  "failure_location": "matrix_12.c:5",
  "code_path": "main() → free() → _int_free() → malloc_printerr() → __libc_message() → __GI_abort()",
  "confidence": 0.98,
  "reasoning": "The program attempted to free the same memory block more than once (or corrupted heap metadata), causing the C runtime to abort execution."
}


4.CSS
a. CssSyntaxError

Input

CssSyntaxError: grid_2.css:20:1: Unclosed block
  18 |     background: #000;
  19 |     opacity: 0.9;
> 20 |
    | ^
  21 | .element-sibling_2 {

Output

{
  "error_type": "CssSyntaxError",
  "failure_location": "grid_2.css:20:1",
  "code_path": "CSS parser → grid_2.css → unclosed declaration block before '.element-sibling_2'",
  "confidence": 0.99,
  "reasoning": "A CSS block was not properly closed with '}', causing the parser to detect an unclosed block before the next selector."
}
b. Expected ';'

Input

Error: Expected ";".
  ╷
84 │     border-radius: 3px
  │                    ^
  ╵
  navigation_3.css 84:33  root stylesheet

Output

{
  "error_type": "CssSyntaxError",
  "failure_location": "navigation_3.css:84:33",
  "code_path": "CSS parser → root stylesheet → property declaration 'border-radius: 3px'",
  "confidence": 0.99,
  "reasoning": "The CSS declaration is missing a terminating semicolon, causing the parser to report a syntax error."
}
5.HTML
a. Stray End Tag

Input

Error: Stray end tag </span>.
From line 95, column 15; to line 95, column 22
item 1</p></span>\n</di

Output

{
  "error_type": "HTML Validation Error",
  "failure_location": "Line 95, columns 15-22",
  "code_path": "HTML parser → closing tags → unexpected </span>",
  "confidence": 0.99,
  "reasoning": "The closing </span> tag does not match any currently open <span> element, resulting in a stray end tag."
}
b. Missing alt Attribute

Input

Error: Element img is missing required attribute alt.
From line 45, column 1; to line 45, column 29
er_2.png"" class=""text-muted_2"">\n</bo

Output

{
  "error_type": "HTML Validation Error",
  "failure_location": "Line 45, columns 1-29",
  "code_path": "HTML parser → <img> element validation",
  "confidence": 0.99,
  "reasoning": "The <img> element is missing the required 'alt' attribute, which is required for accessibility and HTML validation."
}

6.C++
a. std::out_of_range

Input

terminate called after throwing an instance of 'std::out_of_range'
  what(): vector::_M_range_check: __n (which is 9) >= this->size() (which is 3)
Aborted (core dumped)
(gdb) bt
#0  __GI_raise
#1  __GI_abort
#2  __gnu_cxx::__verbose_terminate_handler()
#3  std::vector<int>::at(unsigned long)
#4  main() at session_1.cpp:5

Output

{
  "error_type": "std::out_of_range",
  "failure_location": "session_1.cpp:5",
  "code_path": "main() → std::vector<int>::at() → __gnu_cxx::__verbose_terminate_handler() → __GI_abort()",
  "confidence": 0.99,
  "reasoning": "The program attempted to access index 9 of a vector containing only 3 elements, causing std::vector::at() to throw a std::out_of_range exception."
}
b. No Matching Member Function

Input

session_2.cpp: In function ‘int main()’:
session_2.cpp:5:17: error: no matching member function for call to 'insert'
    5 |     ages.insert(10, "John");
      |     ~~~~~~~~~~~~^~~~~~~~~~~
In file included from /usr/include/c++/11/map:61:
/usr/include/c++/11/bits/stl_map.h:810:7: note: candidate function not viable: requires a single pair object

Output

{
  "error_type": "Compilation Error",
  "failure_location": "session_2.cpp:5:17",
  "code_path": "main() → std::map::insert(10, \"John\")",
  "confidence": 0.99,
  "reasoning": "The std::map::insert() function was called with arguments that do not match any valid overload. It expects a key-value pair or another supported insertion form."
}


7.TypeScript
a. TS2322 - Type Assignment Error

Input

app_1.ts:63:1 - error TS2322: Type 'string' is not assignable to type 'number'.

63 weightsTensor_1 = "invalid_assign_1";
  ~~~~~~~~~~~~~~~

Output

{
  "error_type": "TS2322",
  "failure_location": "app_1.ts:63:1",
  "code_path": "Top-level assignment → weightsTensor_1 = \"invalid_assign_1\"",
  "confidence": 0.99,
  "reasoning": "A string value was assigned to a variable that is declared with the type 'number', violating TypeScript's type checking rules."
}
b. TS2339 - Property Does Not Exist

Input

utils_2.ts:84:13 - error TS2339: Property 'value' does not exist on type 'object'.

84 console.log(metricsData_2.value);
                          ~~~~~

Output

{
  "error_type": "TS2339",
  "failure_location": "utils_2.ts:84:13",
  "code_path": "Top-level execution → console.log(metricsData_2.value)",
  "confidence": 0.99,
  "reasoning": "The code attempts to access the 'value' property on an object whose declared type does not define that property."
}
8.PHP
a. Parse Error

Input

PHP Parse error: syntax error, unexpected token "echo", expecting ";" in /var/www/html/index_1.php on line 64

Output

{
  "error_type": "PHP Parse Error",
  "failure_location": "/var/www/html/index_1.php:64",
  "code_path": "PHP parser → top-level script parsing near 'echo' statement",
  "confidence": 0.99,
  "reasoning": "The parser encountered an 'echo' statement where it expected a semicolon, indicating a missing statement terminator before this line."
}
b. Undefined Function

Input

PHP Fatal error: Uncaught Error: Call to undefined function json_ecnode_typo_$2() in /var/www/html/User_2.php:69
Stack trace:
#0 {main}
  thrown in /var/www/html/User_2.php on line 69

Output

{
  "error_type": "Call to Undefined Function",
  "failure_location": "/var/www/html/User_2.php:69",
  "code_path": "{main} → json_ecnode_typo_$2()",
  "confidence": 0.99,
  "reasoning": "The program attempted to call a function that is not defined or available in the current PHP environment."
}
9.Go
a. Runtime Panic - Index Out of Range

Input

panic: runtime error: index out of range [7] with length 3

goroutine 1 [running]:
main.main()
    /go/src/app/main_2.go:96 +0x3d

Output

{
  "error_type": "Runtime Panic",
  "failure_location": "/go/src/app/main_2.go:96",
  "code_path": "main.main() → slice/array index access",
  "confidence": 0.99,
  "reasoning": "The program attempted to access index 7 of a slice or array that contains only 3 elements, causing a runtime panic."
}
b. Unused Import

Input

./main_5.go:4:5: "math" imported and not used

Output

{
  "error_type": "Unused Import Error",
  "failure_location": "./main_5.go:4:5",
  "code_path": "Package import → import \"math\"",
  "confidence": 0.99,
  "reasoning": "The 'math' package was imported but never referenced in the program, which Go treats as a compilation error."
}

10.Rust
a. E0382 - Borrow of Moved Value

Input

error[E0382]: borrow of moved value: `cache_1`
 --> main_1.rs:99:20
  |
96 |     let cache_1 = String::from("data_3");
97 |     let config_alt_1 = cache_1;
99 |     println!("{}", cache_1);
  |                    ^ value borrowed here after move

Output

{
  "error_type": "E0382",
  "failure_location": "main_1.rs:99:20",
  "code_path": "main() → cache_1 moved to config_alt_1 → println!(cache_1)",
  "confidence": 0.99,
  "reasoning": "Ownership of 'cache_1' was moved to 'config_alt_1', so attempting to use 'cache_1' afterward violates Rust's ownership rules."
}
b. E0277 - Missing Debug Trait

Input

error[E0277]: `CustomStruct_3` doesn't implement `Debug`
 --> utils_3.rs:77:22
  |
77 |     println!("{:?}", instance_3);
  |                      ^ `CustomStruct_3` cannot be formatted using `{:?}` because it doesn't implement the trait

Output

{
  "error_type": "E0277",
  "failure_location": "utils_3.rs:77:22",
  "code_path": "println!(\"{:?}\", instance_3) → Debug trait check",
  "confidence": 0.99,
  "reasoning": "The code attempts to print 'instance_3' using the '{:?}' formatter, but its type does not implement the Debug trait required for formatted output."
}


11.Java
a. Cannot Find Symbol

Input

Api_1.java:29: error: cannot find symbol
        System.out.println(config_1_typo);
                           ^
  symbol:   variable config_1_typo
  location: class NetworkPacket_1

Output

{
  "error_type": "Cannot Find Symbol",
  "failure_location": "Api_1.java:29",
  "code_path": "NetworkPacket_1 → System.out.println(config_1_typo)",
  "confidence": 0.99,
  "reasoning": "The variable 'config_1_typo' is referenced but has not been declared or is not accessible within the current scope."
}
b. NullPointerException

Input

Exception in thread "main" java.lang.NullPointerException: Cannot invoke "String.indexOf(String)" because "recordsList_2" is null
    at MetricsEngine_2.updateCache_2(Api_2.java:110)

Output

{
  "error_type": "NullPointerException",
  "failure_location": "Api_2.java:110",
  "code_path": "main thread → MetricsEngine_2.updateCache_2() → String.indexOf()",
  "confidence": 0.99,
  "reasoning": "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."
}'''

# %% [markdown]
# ## Actual Prompt

# %%
# log_analysis_system_prompt = """You are a Log Analysis Agent. Your job is to extract structured information from messy error text — stack traces, tracebacks, or compiler error messages, sometimes alongside the relevant code.

# Extract:
# - error_type: the SPECIFIC error/exception name as it would appear in real compiler/runtime output — NOT a generic category. For example, prefer "Template Mismatch" or "Dereferencing Void Pointer" over generic terms like "Compilation Error" or "Compilation Warning". Look for the specific technical term the error message itself uses (e.g., a specific error code, exception class name, or named violation), not a broad summary category.
# - failure_location: the exact file/line/position where the error occurred, taken directly from the trace
# - code_path: the chain of function/method calls leading to the failure (e.g., "main() -> processData() -> validateInput()"); for simple top-level errors with no call chain, describe what was directly executed
# - confidence: a score from 0 to 1 representing how certain you are that you extracted this correctly. Vary this realistically — very clear, unambiguous traces should score 0.95-0.99, while vague, truncated, or ambiguous input should score lower (0.5-0.8). Do not default to 0.99 for everything.
# - reasoning: a brief, specific explanation of why the error occurred

# Reply ONLY in valid JSON with this exact structure:
# {"error_type": "...", "failure_location": "...", "code_path": "...", "confidence": 0.9, "reasoning": "..."}

# Examples:

# Input: Cell In[119], line 3
#     return payload_2
#     ^
# IndentationError: unindent does not match any outer indentation level

# Output: {"error_type": "IndentationError", "failure_location": "Cell In[119], line 3", "code_path": "return payload_2 executed directly within the current code block; indentation parsing failed before execution", "confidence": 0.99, "reasoning": "The 'return' statement has inconsistent indentation that does not align with the surrounding block, causing Python's parser to reject the code."}

# Input: /workspace/service_2.js:3
# console.log(session_2[5].id);
# TypeError: Cannot read properties of undefined (reading 'id')
#     at Object.<anonymous> (/workspace/service_2.js:3:15)

# Output: {"error_type": "TypeError", "failure_location": "/workspace/service_2.js:3:15", "code_path": "Top-level execution -> console.log(session_2[5].id)", "confidence": 0.99, "reasoning": "The expression 'session_2[5]' evaluated to undefined, so accessing its 'id' property caused a TypeError."}

# Input: parser_4.c: In function 'main':
# parser_4.c:3:15: error: invalid initializer / incompatible types when initializing type 'int' using type 'char *'
#     3 |     int val = str;

# Output: {"error_type": "Invalid Initializer (Incompatible Types)", "failure_location": "parser_4.c:3:15", "code_path": "main() -> variable initialization: int val = str", "confidence": 0.85, "reasoning": "An integer variable was initialized using a character pointer, which is an incompatible type conversion in C."}

# Input: session_2.cpp: In function 'int main()':
# session_2.cpp:5:17: error: no matching member function for call to 'insert'
#     5 |     ages.insert(10, "John");

# Output: {"error_type": "No Matching Member Function", "failure_location": "session_2.cpp:5:17", "code_path": "main() -> std::map::insert(10, \\"John\\")", "confidence": 0.95, "reasoning": "The std::map::insert() function was called with arguments that do not match any valid overload."}

# Input: Exception in thread "main" java.lang.NullPointerException: Cannot invoke "String.indexOf(String)" because "recordsList_2" is null
#     at MetricsEngine_2.updateCache_2(Api_2.java:110)

# Output: {"error_type": "NullPointerException", "failure_location": "Api_2.java:110", "code_path": "main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()", "confidence": 0.99, "reasoning": "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}
# """

# %%
# log_analysis_system_prompt = """You are a Log Analysis Agent. Your job is to extract structured information from messy error text — stack traces, tracebacks, or compiler error messages, sometimes alongside the relevant code.

# Extract:
# - error_type: the specific error/exception name (e.g., IndexError, NullPointerException, TS2322)
# - failure_location: the exact file/line/position where the error occurred, taken directly from the trace
# - code_path: the chain of function/method calls leading to the failure (e.g., "main() -> processData() -> validateInput()"); for simple top-level errors with no call chain, describe what was directly executed
# - confidence: a score from 0 to 1 representing how certain you are that you extracted this correctly. Vary this realistically — very clear, unambiguous traces should score 0.95-0.99, while vague, truncated, or ambiguous input should score lower (0.5-0.8). Do not default to 0.99 for everything.
# - reasoning: a brief, specific explanation of why the error occurred

# Reply ONLY in valid JSON with this exact structure:
# {"error_type": "...", "failure_location": "...", "code_path": "...", "confidence": 0.9, "reasoning": "..."}

# Examples:

# Input: Cell In[119], line 3
#     return payload_2
#     ^
# IndentationError: unindent does not match any outer indentation level

# Output: {"error_type": "IndentationError", "failure_location": "Cell In[119], line 3", "code_path": "return payload_2 executed directly within the current code block; indentation parsing failed before execution", "confidence": 0.99, "reasoning": "The 'return' statement has inconsistent indentation that does not align with the surrounding block, causing Python's parser to reject the code."}

# Input: /workspace/service_2.js:3
# console.log(session_2[5].id);
# TypeError: Cannot read properties of undefined (reading 'id')
#     at Object.<anonymous> (/workspace/service_2.js:3:15)

# Output: {"error_type": "TypeError", "failure_location": "/workspace/service_2.js:3:15", "code_path": "Top-level execution -> console.log(session_2[5].id)", "confidence": 0.99, "reasoning": "The expression 'session_2[5]' evaluated to undefined, so accessing its 'id' property caused a TypeError."}

# Input: parser_4.c: In function 'main':
# parser_4.c:3:15: error: invalid initializer / incompatible types when initializing type 'int' using type 'char *'
#     3 |     int val = str;

# Output: {"error_type": "Compilation Error", "failure_location": "parser_4.c:3:15", "code_path": "main() -> variable initialization: int val = str", "confidence": 0.85, "reasoning": "An integer variable was initialized using a character pointer, which is an incompatible type conversion in C."}

# Input: session_2.cpp: In function 'int main()':
# session_2.cpp:5:17: error: no matching member function for call to 'insert'
#     5 |     ages.insert(10, "John");

# Output: {"error_type": "Compilation Error", "failure_location": "session_2.cpp:5:17", "code_path": "main() -> std::map::insert(10, \\"John\\")", "confidence": 0.95, "reasoning": "The std::map::insert() function was called with arguments that do not match any valid overload."}

# Input: Exception in thread "main" java.lang.NullPointerException: Cannot invoke "String.indexOf(String)" because "recordsList_2" is null
#     at MetricsEngine_2.updateCache_2(Api_2.java:110)

# Output: {"error_type": "NullPointerException", "failure_location": "Api_2.java:110", "code_path": "main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()", "confidence": 0.99, "reasoning": "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}
# """

# print("Prompt length:", len(log_analysis_system_prompt), "characters")
# Out:
# Prompt length: 3568 characters

# %%
log_analysis_system_prompt = """You are a Log Analysis Agent. Your job is to extract structured information from messy error text — stack traces, tracebacks, or compiler error messages, sometimes alongside the relevant code.

Extract:
- error_type: the SPECIFIC error/exception name as it would appear in real compiler/runtime output — NOT a generic category. For example, prefer "Template Mismatch" or "Dereferencing Void Pointer" over generic terms like "Compilation Error" or "Compilation Warning". Look for the specific technical term the error message itself uses, not a broad summary category.
- failure_location: the exact file/line/position where the error occurred, taken directly from the trace
- code_path: the chain of function/method calls leading to the failure. IMPORTANT: if the code being described contains double quote characters (e.g. from println!, print statements, or string literals), you MUST escape them as \\" so the JSON stays valid. Never include an unescaped " inside any field value.
- confidence: a score from 0 to 1 representing how certain you are that you extracted this correctly. Vary this realistically — very clear, unambiguous traces should score 0.95-0.99, while vague, truncated, or ambiguous input should score lower (0.5-0.8). Do not default to 0.99 for everything.
- reasoning: a brief, specific explanation of why the error occurred

Reply ONLY in valid JSON with this exact structure. Every field value must be a properly escaped JSON string — double quotes inside any value must be written as \\":
{"error_type": "...", "failure_location": "...", "code_path": "...", "confidence": 0.9, "reasoning": "..."}

Examples:

Input: Cell In[119], line 3
    return payload_2
    ^
IndentationError: unindent does not match any outer indentation level

Output: {"error_type": "IndentationError", "failure_location": "Cell In[119], line 3", "code_path": "return payload_2 executed directly within the current code block; indentation parsing failed before execution", "confidence": 0.99, "reasoning": "The 'return' statement has inconsistent indentation that does not align with the surrounding block, causing Python's parser to reject the code."}

Input: /workspace/service_2.js:3
console.log(session_2[5].id);
TypeError: Cannot read properties of undefined (reading 'id')
    at Object.<anonymous> (/workspace/service_2.js:3:15)

Output: {"error_type": "TypeError", "failure_location": "/workspace/service_2.js:3:15", "code_path": "Top-level execution -> console.log(session_2[5].id)", "confidence": 0.99, "reasoning": "The expression 'session_2[5]' evaluated to undefined, so accessing its 'id' property caused a TypeError."}

Input: parser_4.c: In function 'main':
parser_4.c:3:15: error: invalid initializer / incompatible types when initializing type 'int' using type 'char *'
    3 |     int val = str;

Output: {"error_type": "Invalid Initializer (Incompatible Types)", "failure_location": "parser_4.c:3:15", "code_path": "main() -> variable initialization: int val = str", "confidence": 0.85, "reasoning": "An integer variable was initialized using a character pointer, which is an incompatible type conversion in C."}

Input: session_2.cpp: In function 'int main()':
session_2.cpp:5:17: error: no matching member function for call to 'insert'
    5 |     ages.insert(10, "John");

Output: {"error_type": "No Matching Member Function", "failure_location": "session_2.cpp:5:17", "code_path": "main() -> std::map::insert(10, \\"John\\")", "confidence": 0.95, "reasoning": "The std::map::insert() function was called with arguments that do not match any valid overload."}

Input: Exception in thread "main" java.lang.NullPointerException: Cannot invoke "String.indexOf(String)" because "recordsList_2" is null
    at MetricsEngine_2.updateCache_2(Api_2.java:110)

Output: {"error_type": "NullPointerException", "failure_location": "Api_2.java:110", "code_path": "main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()", "confidence": 0.99, "reasoning": "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}

Input: CssSyntaxError: grid_2.css:20:1: Unclosed block
  18 |     background: #000;
  19 |     opacity: 0.9;
> 20 |
    | ^
  21 | .element-sibling_2 {

Output: {"error_type": "PostCSS Parser Error: Unclosed Block", "failure_location": "grid_2.css:20:1", "code_path": "CSS parser -> grid_2.css -> unclosed declaration block before '.element-sibling_2'", "confidence": 0.99, "reasoning": "A CSS block was not properly closed with '}', causing the parser to detect an unclosed block before the next selector."}

Input: Error: Stray end tag </span>.
From line 95, column 15; to line 95, column 22
item 1</p></span>\n</di

Output: {"error_type": "W3C Validator Error: Stray End Tag", "failure_location": "Line 95, columns 15-22", "code_path": "HTML parser -> closing tags -> unexpected </span>", "confidence": 0.99, "reasoning": "The closing </span> tag does not match any currently open <span> element, resulting in a stray end tag."}

Input: app_1.ts:63:1 - error TS2322: Type 'string' is not assignable to type 'number'.
63 weightsTensor_1 = "invalid_assign_1";
  ~~~~~~~~~~~~~~~

Output: {"error_type": "TypeScript Error: TS2322 (Type Assignment Error)", "failure_location": "app_1.ts:63:1", "code_path": "Top-level assignment -> weightsTensor_1 = \\"invalid_assign_1\\"", "confidence": 0.99, "reasoning": "A string value was assigned to a variable that is declared with the type 'number', violating TypeScript's type checking rules."}

Input: panic: runtime error: index out of range [7] with length 3
goroutine 1 [running]:
main.main()
    /go/src/app/main_2.go:96 +0x3d

Output: {"error_type": "Go Runtime Panic: Index Out of Range", "failure_location": "/go/src/app/main_2.go:96", "code_path": "main.main() -> slice/array index access", "confidence": 0.99, "reasoning": "The program attempted to access index 7 of a slice or array that contains only 3 elements, causing a runtime panic."}


"""

# %% [markdown]
# ## validation

# %%
import time
def call_llm_with_retry(system_prompt, user_message, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_message}
                ],
                temperature=0.2
            )
            return json.loads(response.choices[0].message.content)
        except Exception as e:
            if "rate_limit" in str(e).lower() or "429" in str(e):
                wait_time = (attempt + 1) * 3
                print(f"Rate limited, waiting {wait_time}s...")
                time.sleep(wait_time)
            else:
                print(f"Non-rate-limit error: {e}")
                break
    return None

# %%
weak_test = validation_sample_large[validation_sample_large['language'].isin(['css', 'html', 'c', 'cpp'])]

for idx, row in weak_test.iterrows():
    predicted = log_analysis_agent(row['stack_trace'], code_context=row['code'])
    print(f"Language: {row['language']}")
    print(f"Actual: {row['error_type']}")
    print(f"Predicted: {predicted.get('error_type')}")
    print()
# Out:
# Language: cpp
# Actual: g++ Compiler Error: Template Mismatch
# Predicted: No Matching Member Function
#
# Language: cpp
# Actual: std::bad_alloc Exception
# Predicted: std::bad_alloc
#
# Language: cpp
# Actual: g++ Compiler Warning: Safe Comparison Mismatch (Signed/Unsigned)
# Predicted: Comparison Of Integer Expressions Of Different Signedness
#
# Language: cpp
# Actual: g++ Compiler Error: No Matching Constructor
# Predicted: No Matching Function
#
# Language: cpp
# Actual: g++ Compiler Warning: Safe Comparison Mismatch (Signed/Unsigned)
# Predicted: Comparison Of Integer Expressions Of Different Signedness
#
# Language: css
# Actual: PostCSS Parser Error: Unclosed Block
# Predicted: CssSyntaxError
#
# Language: css
# Actual: Stylelint Error: Invalid Hex Color
# Predicted: Unexpected invalid hex color
#
# Language: css
# Actual: Stylelint Error: Duplicate Property
# Predicted: Unexpected duplicate "display" property
#
# Language: css
# Actual: Sass Compiler Error: Malformed calc()
# Predicted: Expected Expression
#
# Language: css
# Actual: Stylelint Error: Duplicate Property
# Predicted: Unexpected duplicate "display" property
#
# Language: c
# Actual: GCC Compiler Error: Syntax Error
# Predicted: Expected ';' Before 'printf'
#
# Language: c
# Actual: GCC Compiler Error: Dereferencing Void Pointer
# Predicted: Dereferencing ‘void *’ Pointer
#
# Language: c
# Actual: GCC Compiler Error: Incompatible Pointer Type
# Predicted: Incompatible Pointer Types
#
# Language: c
# Actual: GCC Compiler Warning: Format Mismatch
# Predicted: Format Specifies Type ‘int’ But Argument Has Type ‘char *’
#
# Language: c
# Actual: GCC Compiler Error: Incompatible Pointer Type
# Predicted: Incompatible Pointer Types
#
# Language: html
# Actual: W3C Validator Error: Missing Required Attribute
# Predicted: Element img is missing required attribute alt
#
# Language: html
# Actual: W3C Validator Error: Element Not Allowed Here
# Predicted: Element div not allowed as child of element ul
#
# Language: html
# Actual: W3C Validator Error: Duplicate Attribute
# Predicted: Duplicate Attribute
#
# Language: html
# Actual: W3C Validator Error: End Tag Seen With Unclosed Elements
# Predicted: End tag seen, but there were unclosed elements
#
# Language: html
# Actual: W3C Validator Error: Duplicate Attribute
# Predicted: Duplicate Attribute

# %%
import re

def is_match_v2(predicted, actual):
    def normalize(text):
        text = text.lower()
        text = re.sub(r'[^a-z0-9\s]', '', text)  # remove punctuation like quotes, colons
        text = re.sub(r'\bs\b|s$', '', text)      # rough plural stripping (very simple)
        words = set(text.split())
        return words

    pred_words = normalize(predicted)
    actual_words = normalize(actual)

    # Remove common "noise" words that aren't the actual error concept
    noise_words = {'error', 'warning', 'exception', 'compiler', 'parser', 'validator', 'runtime'}
    pred_core = pred_words - noise_words
    actual_core = actual_words - noise_words

    # Check meaningful word overlap
    overlap = pred_core & actual_core
    return len(overlap) >= 2  # at least 2 shared meaningful words

# %%
def is_match_v3(predicted, actual):
    def normalize(text):
        text = text.lower()
        text = re.sub(r'[^a-z0-9\s]', '', text)
        return set(text.split())

    pred_words = normalize(predicted)
    actual_words = normalize(actual)

    noise_words = {'error', 'warning', 'exception', 'compiler', 'parser', 'validator', 'runtime', 'gcc', 'g'}
    pred_core = pred_words - noise_words
    actual_core = actual_words - noise_words

    if len(pred_core) == 0 or len(actual_core) == 0:
        return False

    overlap = pred_core & actual_core
    # Require at least half of the SHORTER answer's words to match, minimum 1
    smaller_set_size = min(len(pred_core), len(actual_core))
    required = max(1, smaller_set_size // 2)
    return len(overlap) >= required

# %%
results_df_large['fair_match_v3'] = results_df_large.apply(
    lambda r: is_match_v3(r['predicted_error_type'], r['actual_error_type']), axis=1
)
fair_accuracy_v3 = results_df_large['fair_match_v3'].sum() / len(results_df_large) * 100
print(f"Fair match v3 accuracy: {results_df_large['fair_match_v3'].sum()}/{len(results_df_large)} = {fair_accuracy_v3:.1f}%")
print("\nPer-language fair match v3 accuracy:")
print(results_df_large.groupby('language')['fair_match_v3'].mean().sort_values() * 100)
# Out:
# Fair match v3 accuracy: 45/55 = 81.8%
#
# Per-language fair match v3 accuracy:
# language
# cpp            40.0
# typescript     60.0
# css            80.0
# c              80.0
# javascript     80.0
# go             80.0
# rust           80.0
# html          100.0
# php           100.0
# java          100.0
# python        100.0
# Name: fair_match_v3, dtype: float64

# %%
weak_test2 = validation_sample_large[validation_sample_large['language'].isin(['cpp', 'typescript'])]

spot_results = []
for idx, row in weak_test2.iterrows():
    predicted = log_analysis_agent(row['stack_trace'], code_context=row['code'])
    predicted_type = predicted.get('error_type', 'Unknown')
    actual_type = row['error_type']
    match = is_match_v3(predicted_type, actual_type)
    spot_results.append({'language': row['language'], 'actual': actual_type, 'predicted': predicted_type, 'match': match})
    print(f"{row['language']}: actual='{actual_type}' | predicted='{predicted_type}' | match={match}")

spot_df = pd.DataFrame(spot_results)
print(f"\nSpot-test accuracy: {spot_df['match'].sum()}/{len(spot_df)} = {spot_df['match'].mean()*100:.1f}%")
# Out:
# cpp: actual='g++ Compiler Error: Template Mismatch' | predicted='No Matching Member Function' | match=False
# cpp: actual='std::bad_alloc Exception' | predicted='std::bad_alloc' | match=True
# cpp: actual='g++ Compiler Warning: Safe Comparison Mismatch (Signed/Unsigned)' | predicted='Comparison Of Integer Expressions Of Different Signedness' | match=False
# cpp: actual='g++ Compiler Error: No Matching Constructor' | predicted='No Matching Function' | match=True
# cpp: actual='g++ Compiler Warning: Safe Comparison Mismatch (Signed/Unsigned)' | predicted='Comparison Of Integer Expressions Of Different Signedness' | match=False
# typescript: actual='TypeScript Error: TS2339 (Property Does Not Exist)' | predicted='TS2339: Property 'value' does not exist on type 'object'' | match=True
# typescript: actual='TypeScript Error: TS2564 (Uninitialized Property)' | predicted='TS2564' | match=True
# typescript: actual='TypeScript Error: TS2531 (Object is Possibly Null)' | predicted='TS2531: Object is possibly 'null'' | match=True
# typescript: actual='TypeScript Error: TS2307 (Cannot Find Module)' | predicted='TS2307: Cannot find module' | match=True
# typescript: actual='TypeScript Error: TS2531 (Object is Possibly Null)' | predicted='TS2531: Object is possibly 'null'' | match=True
#
# Spot-test accuracy: 7/10 = 70.0%

# %% [markdown]
# ## samples c

# %%
results_df_large['fair_match_v2'] = results_df_large.apply(
    lambda r: is_match_v2(r['predicted_error_type'], r['actual_error_type']), axis=1
)

fair_accuracy_v2 = results_df_large['fair_match_v2'].sum() / len(results_df_large) * 100
print(f"Fair match v2 accuracy: {results_df_large['fair_match_v2'].sum()}/{len(results_df_large)} = {fair_accuracy_v2:.1f}%")

print("\nPer-language fair match v2 accuracy:")
print(results_df_large.groupby('language')['fair_match_v2'].mean().sort_values() * 100)
# Out:
# Fair match v2 accuracy: 29/55 = 52.7%
#
# Per-language fair match v2 accuracy:
# language
# javascript      0.0
# python          0.0
# cpp            20.0
# java           40.0
# php            40.0
# c              60.0
# typescript     60.0
# css            80.0
# rust           80.0
# go            100.0
# html          100.0
# Name: fair_match_v2, dtype: float64

# %%
def log_analysis_agent(error_text, code_context=""):
    if code_context:
        user_message = f"Code:\n{code_context}\n\nError:\n{error_text}"
    else:
        user_message = f"Error:\n{error_text}"
    
    result = call_llm_with_retry(log_analysis_system_prompt, user_message)
    0
    if result is None:
        result = {
            "error_type": "Unknown",
            "failure_location": "Not determined",
            "code_path": "Not determined",
            "confidence": 0.0,
            "reasoning": "LLM call failed after retries"
        }
    
    return result

# %%
test_error = """Cell In[13], line 2
      1 loooo= [1,2]
----> 2 loooo[5]

IndexError: list index out of range"""

result = log_analysis_agent(test_error)
print(result)
# Out:
# {'error_type': 'IndexError', 'failure_location': 'Cell In[13], line 2', 'code_path': 'list indexing: loooo[5] executed directly within the current code block; list length exceeded index', 'confidence': 0.99, 'reasoning': "The list 'loooo' has a length of 2, which is less than the index 5, causing an IndexError when trying to access the element at that position."}

# %%
stack_trace_df = pd.read_csv("../data/stack_trace_combined.csv")

print("Shape :",stack_trace_df.shape)
print("\nColumns : ",stack_trace_df.columns.tolist())
print("\nSample row : ")
print(stack_trace_df.iloc[0])
# Out:
# Shape : (5500, 7)
#
# Columns :  ['s.no', 'language', 'error_type', 'code', 'stack_trace', 'fix_brief', 'fix_solution']
#
# Sample row :
# s.no                                                            1
# language                                                      cpp
# error_type                            std::out_of_range Exception
# code            #include <vector>\n#include <iostream>\nint ma...
# stack_trace     terminate called after throwing an instance of...
# fix_brief       Ensure requested indexes sit cleanly inside th...
# fix_solution    #include <vector>\n#include <iostream>\nint ma...
# Name: 0, dtype: object

# %%
validation_sample = stack_trace_df.groupby('language',group_keys = False).apply(
    lambda x:x.sample(3,random_state = 42).reset_index(drop=True))

print("Validation sample size :",len(validation_sample))
print('\nPer-language breakdown : ')
print(validation_sample["language"].value_counts())

# %%
languages = stack_trace_df['language'].unique()

validation_sample = pd.concat([
    stack_trace_df[stack_trace_df['language'] == lang].sample(3,random_state=42)
    for lang in languages 
]).reset_index(drop = True)

print("Validation sample size : ",len(validation_sample))
print("\nPer-language breakdown :")
print(validation_sample['language'].value_counts())
# Out:
# Validation sample size :  33
#
# Per-language breakdown :
# language
# cpp           3
# css           3
# c             3
# go            3
# html          3
# java          3
# javascript    3
# php           3
# python        3
# rust          3
# typescript    3
# Name: count, dtype: int64

# %%
import time

exact_matches = 0
results_log = []

for idx,row in validation_sample.iterrows():
    predicted = log_analysis_agent(row['stack_trace'],code_context = row['code'])
    predicted_type = predicted.get('error_type','Unknown')
    actual_type = row['error_type']

    is_exact = (predicted_type.strip().lower()== actual_type.strip().lower())
    if is_exact:
        exact_matches += 1 
    results_log.append({
        'language':row['language'],
        'actual_error_type': actual_type,
        'predicted_error_type': predicted_type,
        'confidence':predicted.get('confidence' , None),
        'exact_match':is_exact
        
    })
    time.sleep(2)

print(f"\nExact match accuracy : {exact_matches}/{len(validation_sample)} = {exact_matches/len(validation_sample)*100:.1f}%")
# Out:
# Non-rate-limit error: Expecting ',' delimiter: line 1 column 116 (char 115)
#
# Exact match accuracy : 5/33 = 15.2%

# %%
results_df = pd.DataFrame(results_log)
pd.set_option('display.max_colwidth', 60)
print(results_df[['language', 'actual_error_type', 'predicted_error_type', 'exact_match']].to_string())
# Out:
#       language                                                 actual_error_type                                   predicted_error_type  exact_match
# 0          cpp                             g++ Compiler Error: Template Mismatch                                      Compilation Error        False
# 1          cpp                                          std::bad_alloc Exception                                         std::bad_alloc        False
# 2          cpp  g++ Compiler Warning: Safe Comparison Mismatch (Signed/Unsigned)                                                Warning        False
# 3          css                              PostCSS Parser Error: Unclosed Block                                         CssSyntaxError        False
# 4          css                                Stylelint Error: Invalid Hex Color                                      Invalid Hex Color        False
# 5          css                               Stylelint Error: Duplicate Property                         Unexpected duplicate "display"        False
# 6            c                                  GCC Compiler Error: Syntax Error                                      Compilation Error        False
# 7            c                    GCC Compiler Error: Dereferencing Void Pointer                                      Compilation Error        False
# 8            c                     GCC Compiler Error: Incompatible Pointer Type                                    Compilation Warning        False
# 9           go                              Go Runtime Panic: Index Out of Range               panic: runtime error: index out of range        False
# 10          go                                Go Compiler Error: Unused Variable                                    UnusedVariableError        False
# 11          go                                  Go Compiler Error: Unused Import                                      UnusedImportError        False
# 12        html                   W3C Validator Error: Missing Required Attribute  Error: Element img is missing required attribute alt.        False
# 13        html                     W3C Validator Error: Element Not Allowed Here                                  HTML Validation Error        False
# 14        html                          W3C Validator Error: Duplicate Attribute                                                  Error        False
# 15        java                      Java Runtime Exception: NullPointerException                                   NullPointerException        False
# 16        java                           Java Compiler Error: Incompatible Types                                      Compilation Error        False
# 17        java                        Java Runtime Exception: ClassCastException                                     ClassCastException        False
# 18  javascript                                                         TypeError                                              TypeError         True
# 19  javascript                                                         TypeError                                              TypeError         True
# 20  javascript                                                       SyntaxError                                            SyntaxError         True
# 21         php                       PHP Fatal Error: Call to Undefined Function                                         Uncaught Error        False
# 22         php                                                     PHP TypeError                                              TypeError        False
# 23         php                                            PHP ArgumentCountError                                     ArgumentCountError        False
# 24      python                                                   PermissionError                                        PermissionError         True
# 25      python                                                    AttributeError                                         AttributeError         True
# 26      python                                                        ValueError                                             ValueError         True
# 27        rust             Rust Compiler Error: E0502 (Borrow Checker Violation)                                                Unknown        False
# 28        rust                     Rust Compiler Error: E0308 (Mismatched Types)                                           error[E0308]        False
# 29        rust                           Rust Runtime Panic: Index Out of Bounds                                                Unknown        False
# 30  typescript                TypeScript Error: TS2339 (Property Does Not Exist)                                                 TS2339        False
# 31  typescript                 TypeScript Error: TS2564 (Uninitialized Property)                                                 TS2564        False
# 32  typescript                TypeScript Error: TS2531 (Object is Possibly Null)                                                 TS2531        False

# %%
results_df = pd.DataFrame(results_log)

def is_match(predicted, actual):
    predicted_clean = predicted.strip().lower()
    actual_clean = actual.strip().lower()
    return predicted_clean in actual_clean or actual_clean in predicted_clean

results_df['fair_match'] = results_df.apply(
    lambda r: is_match(r['predicted_error_type'], r['actual_error_type']), axis=1
)

fair_accuracy = results_df['fair_match'].sum() / len(results_df) * 100
print(f"Fair match accuracy: {results_df['fair_match'].sum()}/{len(results_df)} = {fair_accuracy:.1f}%")
# Out:
# Fair match accuracy: 18/33 = 54.5%

# %%
print(results_df[results_df['fair_match'] == False][['language', 'actual_error_type', 'predicted_error_type']].to_string())
# Out:
#    language                                      actual_error_type                                   predicted_error_type
# 0       cpp                  g++ Compiler Error: Template Mismatch                                      Compilation Error
# 3       css                   PostCSS Parser Error: Unclosed Block                                         CssSyntaxError
# 5       css                    Stylelint Error: Duplicate Property                         Unexpected duplicate "display"
# 6         c                       GCC Compiler Error: Syntax Error                                      Compilation Error
# 7         c         GCC Compiler Error: Dereferencing Void Pointer                                      Compilation Error
# 8         c          GCC Compiler Error: Incompatible Pointer Type                                    Compilation Warning
# 9        go                   Go Runtime Panic: Index Out of Range               panic: runtime error: index out of range
# 10       go                     Go Compiler Error: Unused Variable                                    UnusedVariableError
# 11       go                       Go Compiler Error: Unused Import                                      UnusedImportError
# 12     html        W3C Validator Error: Missing Required Attribute  Error: Element img is missing required attribute alt.
# 13     html          W3C Validator Error: Element Not Allowed Here                                  HTML Validation Error
# 16     java                Java Compiler Error: Incompatible Types                                      Compilation Error
# 21      php            PHP Fatal Error: Call to Undefined Function                                         Uncaught Error
# 27     rust  Rust Compiler Error: E0502 (Borrow Checker Violation)                                                Unknown
# 28     rust          Rust Compiler Error: E0308 (Mismatched Types)                                           error[E0308]
# 29     rust                Rust Runtime Panic: Index Out of Bounds                                                Unknown

# %%
row_29 = validation_sample.loc[29]

call_llm_debug(log_analysis_system_prompt, f"Code:\n{row_29['code']}\n\nError:\n{row_29['stack_trace']}")
# Out:
# RAW RESPONSE:
# {"error_type": "Index Out of Bounds", "failure_location": "config_375.rs:36:20", "code_path": "main() -> println!(\"{}\", profile_375[378])", "confidence": 0.99, "reasoning": "The vector 'profile_375' has a length of 3, but the index 378 is out of bounds, as indices must be less than the vector's length."}
#
# --- Attempting to parse ---
# SUCCESS: {'error_type': 'Index Out of Bounds', 'failure_location': 'config_375.rs:36:20', 'code_path': 'main() -> println!("{}", profile_375[378])', 'confidence': 0.99, 'reasoning': "The vector 'profile_375' has a length of 3, but the index 378 is out of bounds, as indices must be less than the vector's length."}
# '{"error_type": "Index Out of Bounds", "failure_location": "config_375.rs:36:20", "code_path": "main() -> println!(\\"{}\\", profile_375[378])", "confidence": 0.99, "reasoning": "The vector \'profile_375\' has a length of 3, but the index 378 is out of bounds, as indices must be less than the vector\'s length."}'

# %%
languages = stack_trace_df['language'].unique()

validation_sample_large = pd.concat([
    stack_trace_df[stack_trace_df['language'] == lang].sample(5, random_state=42)
    for lang in languages
]).reset_index(drop=True)

print("Validation sample size:", len(validation_sample_large))
print(validation_sample_large['language'].value_counts())
# Out:
# Validation sample size: 55
# language
# cpp           5
# css           5
# c             5
# go            5
# html          5
# java          5
# javascript    5
# php           5
# python        5
# rust          5
# typescript    5
# Name: count, dtype: int64

# %%
import time

exact_matches = 0
fair_matches = 0
results_log_large = []

def is_match(predicted, actual):
    predicted_clean = predicted.strip().lower()
    actual_clean = actual.strip().lower()
    return predicted_clean in actual_clean or actual_clean in predicted_clean

for idx, row in validation_sample_large.iterrows():
    predicted = log_analysis_agent(row['stack_trace'], code_context=row['code'])
    predicted_type = predicted.get('error_type', 'Unknown')
    actual_type = row['error_type']

    is_exact = (predicted_type.strip().lower() == actual_type.strip().lower())
    is_fair = is_match(predicted_type, actual_type)

    if is_exact:
        exact_matches += 1
    if is_fair:
        fair_matches += 1

    results_log_large.append({
        'language': row['language'],
        'actual_error_type': actual_type,
        'predicted_error_type': predicted_type,
        'confidence': predicted.get('confidence', None),
        'exact_match': is_exact,
        'fair_match': is_fair
    })

    if idx % 20 == 0:
        print(f"Progress: {idx}/{len(validation_sample_large)}")

    time.sleep(1.5)

print(f"\nExact match accuracy: {exact_matches}/{len(validation_sample_large)} = {exact_matches/len(validation_sample_large)*100:.1f}%")
print(f"Fair match accuracy: {fair_matches}/{len(validation_sample_large)} = {fair_matches/len(validation_sample_large)*100:.1f}%")
# Out:
# Progress: 0/55
# Progress: 20/55
# Progress: 40/55
# Non-rate-limit error: Expecting ',' delimiter: line 1 column 219 (char 218)
# Non-rate-limit error: Expecting ',' delimiter: line 1 column 147 (char 146)
#
# Exact match accuracy: 5/55 = 9.1%
# Fair match accuracy: 32/55 = 58.2%

# %%
results_df_large = pd.DataFrame(results_log_large)

print("Per-language fair match accuracy:")
print(results_df_large.groupby('language')['fair_match'].mean().sort_values() * 100)
# Out:
# Per-language fair match accuracy:
# language
# typescript      0.0
# c              20.0
# css            20.0
# cpp            40.0
# html           40.0
# go             60.0
# rust           80.0
# javascript     80.0
# php           100.0
# java          100.0
# python        100.0
# Name: fair_match, dtype: float64

# %%
results_df_large = pd.DataFrame(results_log_large)

print("Per-language fair match accuracy:")
print(results_df_large.groupby('language')['fair_match'].mean().sort_values() * 100)
# Out:
# Per-language fair match accuracy:
# language
# css            10.0
# typescript     10.0
# html           20.0
# c              20.0
# cpp            50.0
# rust           60.0
# go             70.0
# java           90.0
# php            90.0
# javascript     90.0
# python        100.0
# Name: fair_match, dtype: float64

# %%
css_fails = results_df_large[(results_df_large['language'] == 'css') & (results_df_large['fair_match'] == False)]
print(css_fails[['actual_error_type', 'predicted_error_type']].to_string())
# Out:
#                             actual_error_type                     predicted_error_type
# 11         Stylelint Error: Invalid Hex Color             Unexpected invalid hex color
# 12        Stylelint Error: Duplicate Property           Unexpected duplicate "display"
# 13      Sass Compiler Error: Malformed calc()                      Expected Expression
# 14        Stylelint Error: Duplicate Property  Unexpected duplicate "display" property
# 15        Stylelint Error: Duplicate Property  Unexpected duplicate "display" property
# 16        PostCSS Parser Error: Missing Colon                             Missed Colon
# 17        Stylelint Error: Duplicate Property  Unexpected duplicate "display" property
# 18  DevTools CSS Warning: Invalid Media Query         Invalid Media Query Length Value
# 19          Stylelint Error: Unknown Property              Unexpected unknown property

# %%
results_df_large.to_csv("../data/log_analysis_validation_results.csv", index=False)
print("Saved")
# Out:
# Saved

# %% [markdown]
# #  Task 3 : Combined Result

# %%
def run_orchestration(title,description , stack_trace , bug_id = "unknown"):
    triage_result = triage_agent(title , description , stack_trace , bug_id=bug_id)
    log_result = log_analysis_agent(stack_trace)
    combined_result= {
        "bug_id" : bug_id,
        "triage" : triage_result,
        "log_analysis" : log_result
    }

    return combined_result

def build_simple_view (combined_result):
    triage = combined_result['triage']
    log = combined_result['log_analysis']

    actual_result = {
        'bug_id':combined_result['bug_id'],
        'severity':triage['severity'],
        'priority':triage['priority'],
        'component' : triage['component'],
        'error_type':log['error_type'],
        'failure_location':log['failure_location'],
        'code_path':log['code_path'],
        'confidence':log['confidence'],
        'reasoning':log['reasoning']
    }

    return actual_result

# %%
result = run_orchestration(test_title,test_description , test_stack_trace ,bug_id = "TEST-001")
print("Combined Result (save , sent to Milestone 3 ) :")
print(result)
 

print()

simple = build_simple_view(result)
print("Simple View (for UI default disply) ")
print(simple)
# Out:
# Combined Result (save , sent to Milestone 3 ) :
# {'bug_id': 'TEST-001', 'triage': {'bug_id': 'TEST-001', 'severity': 'Critical', 'confidence': 0.9, 'reasoning': 'The app crashes immediately after a critical action (login) with a NullPointerException, indicating a significant issue that completely blocks core functionality.', 'priority': 'Immediate', 'component': 'Login'}, 'log_analysis': {'error_type': 'NullPointerException', 'failure_location': 'Api_2.java:110', 'code_path': 'main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()', 'confidence': 0.99, 'reasoning': "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}}
#
# Simple View (for UI default disply)
# {'bug_id': 'TEST-001', 'severity': 'Critical', 'priority': 'Immediate', 'component': 'Login', 'error_type': 'NullPointerException', 'failure_location': 'Api_2.java:110', 'code_path': 'main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()', 'confidence': 0.99, 'reasoning': "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}

# %% [markdown]
# # ERROR MAKING AND TESTING

# %%
import json

def call_llm_debug(system_prompt, user_message):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message}
        ],
        temperature=0.2
    )
    raw = response.choices[0].message.content
    print("RAW RESPONSE:")
    print(raw)
    print("\n--- Attempting to parse ---")
    try:
        parsed = json.loads(raw)
        print("SUCCESS:", parsed)
    except Exception as e:
        print("FAILED:", e)
    return raw

# Test on the Rust rows specifically, since those failed before
rust_rows = validation_sample[validation_sample['language'] == 'rust']

for idx, row in rust_rows.iterrows():
    print(f"\n=== Row {idx} ===")
    call_llm_debug(log_analysis_system_prompt, f"Code:\n{row['code']}\n\nError:\n{row['stack_trace']}")
    print("=" * 50)
# Out:
# === Row 27 ===
# RAW RESPONSE:
# {"error_type": "Cannot Borrow As Mutable Because It Is Also Borrowed As Immutable", "failure_location": "config_362.rs:23:5", "code_path": "main() -> let r_362 = &records_362[0]; -> records_362.push(365)", "confidence": 0.99, "reasoning": "The vector 'records_362' is immutably borrowed when 'r_362' is created, and this borrow is still active when 'records_362.push(365)' is called, which attempts a mutable borrow, causing a conflict."}
#
# --- Attempting to parse ---
# SUCCESS: {'error_type': 'Cannot Borrow As Mutable Because It Is Also Borrowed As Immutable', 'failure_location': 'config_362.rs:23:5', 'code_path': 'main() -> let r_362 = &records_362[0]; -> records_362.push(365)', 'confidence': 0.99, 'reasoning': "The vector 'records_362' is immutably borrowed when 'r_362' is created, and this borrow is still active when 'records_362.push(365)' is called, which attempts a mutable borrow, causing a conflict."}
# ==================================================
#
# === Row 28 ===
# RAW RESPONSE:
# {"error_type": "Mismatched Types", "failure_location": "config_74.rs:46:21", "code_path": "compute_val_74(x: i32) -> i32", "confidence": 0.99, "reasoning": "The function 'compute_val_74' is declared to return an 'i32', but its body implicitly returns '()' because it lacks a tail expression, causing a type mismatch error."}
#
# --- Attempting to parse ---
# SUCCESS: {'error_type': 'Mismatched Types', 'failure_location': 'config_74.rs:46:21', 'code_path': 'compute_val_74(x: i32) -> i32', 'confidence': 0.99, 'reasoning': "The function 'compute_val_74' is declared to return an 'i32', but its body implicitly returns '()' because it lacks a tail expression, causing a type mismatch error."}
# ==================================================
#
# === Row 29 ===
# RAW RESPONSE:
# {"error_type": "Index Out Of Bounds", "failure_location": "config_375.rs:36:20", "code_path": "main() -> println!(\"{}\", profile_375[378])", "confidence": 0.99, "reasoning": "The vector 'profile_375' has a length of 3, but an attempt was made to access the element at index 378, which is beyond its bounds."}
#
# --- Attempting to parse ---
# SUCCESS: {'error_type': 'Index Out Of Bounds', 'failure_location': 'config_375.rs:36:20', 'code_path': 'main() -> println!("{}", profile_375[378])', 'confidence': 0.99, 'reasoning': "The vector 'profile_375' has a length of 3, but an attempt was made to access the element at index 378, which is beyond its bounds."}
# ==================================================

# %%
list[]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 loooo= [1,2]
# ----> 2 loooo[5]
#
# IndexError: list index out of range

# %%
'''1. Python

a. NameError

Input

Traceback (most recent call last):
  Cell In[92], line 4, in <module>
    update_cache_4()
  Cell In[92], line 2, in update_cache_4
        1 def update_cache_4():
----> 2     return config_4_missing + 10

NameError: name 'config_4_missing' is not defined

Output

{
  "error_type": "NameError",
  "failure_location": "Cell In[92], line 2, in update_cache_4",
  "code_path": "<module> → update_cache_4() → return config_4_missing + 10",
  "confidence": 0.99,
  "reasoning": "The variable 'config_4_missing' was referenced inside the function before being defined or assigned."
}
2. JavaScript
a. SyntaxError

Input

/workspace/service_6.js:1
const values = [1, 2, 3;
                       ^

SyntaxError: Unexpected token ';'

Output

{
  "error_type": "SyntaxError",
  "failure_location": "/workspace/service_6.js:1",
  "code_path": "Top-level variable declaration while parsing the JavaScript source",
  "confidence": 0.99,
  "reasoning": "The array literal was not closed with ']', so the parser encountered an unexpected semicolon."
}
3. C
a. Double Free

Input

double free or corruption (out)
Aborted (core dumped)
(gdb) bt
#0  __GI_raise ...
#1  __GI_abort ...
#2  __libc_message ...
#3  malloc_printerr ...
#4  _int_free ...
#5  main () at matrix_12.c:5

Output

{
  "error_type": "Double Free / Memory Corruption",
  "failure_location": "matrix_12.c:5",
  "code_path": "main() → free() → _int_free() → malloc_printerr() → __libc_message() → __GI_abort()",
  "confidence": 0.98,
  "reasoning": "The program attempted to free the same memory block more than once (or corrupted heap metadata), causing the C runtime to abort execution."
}


4.CSS
a. CssSyntaxError

Input

CssSyntaxError: grid_2.css:20:1: Unclosed block
  18 |     background: #000;
  19 |     opacity: 0.9;
> 20 |
    | ^
  21 | .element-sibling_2 {

Output

{
  "error_type": "CssSyntaxError",
  "failure_location": "grid_2.css:20:1",
  "code_path": "CSS parser → grid_2.css → unclosed declaration block before '.element-sibling_2'",
  "confidence": 0.99,
  "reasoning": "A CSS block was not properly closed with '}', causing the parser to detect an unclosed block before the next selector."
}
b. Expected ';'

Input

Error: Expected ";".
  ╷
84 │     border-radius: 3px
  │                    ^
  ╵
  navigation_3.css 84:33  root stylesheet

Output

{
  "error_type": "CssSyntaxError",
  "failure_location": "navigation_3.css:84:33",
  "code_path": "CSS parser → root stylesheet → property declaration 'border-radius: 3px'",
  "confidence": 0.99,
  "reasoning": "The CSS declaration is missing a terminating semicolon, causing the parser to report a syntax error."
}
5.HTML
a. Stray End Tag

Input

Error: Stray end tag </span>.
From line 95, column 15; to line 95, column 22
item 1</p></span>\n</di

Output

{
  "error_type": "HTML Validation Error",
  "failure_location": "Line 95, columns 15-22",
  "code_path": "HTML parser → closing tags → unexpected </span>",
  "confidence": 0.99,
  "reasoning": "The closing </span> tag does not match any currently open <span> element, resulting in a stray end tag."
}
b. Missing alt Attribute

Input

Error: Element img is missing required attribute alt.
From line 45, column 1; to line 45, column 29
er_2.png"" class=""text-muted_2"">\n</bo

Output

{
  "error_type": "HTML Validation Error",
  "failure_location": "Line 45, columns 1-29",
  "code_path": "HTML parser → <img> element validation",
  "confidence": 0.99,
  "reasoning": "The <img> element is missing the required 'alt' attribute, which is required for accessibility and HTML validation."
}

6.C++
a. std::out_of_range

Input

terminate called after throwing an instance of 'std::out_of_range'
  what(): vector::_M_range_check: __n (which is 9) >= this->size() (which is 3)
Aborted (core dumped)
(gdb) bt
#0  __GI_raise
#1  __GI_abort
#2  __gnu_cxx::__verbose_terminate_handler()
#3  std::vector<int>::at(unsigned long)
#4  main() at session_1.cpp:5

Output

{
  "error_type": "std::out_of_range",
  "failure_location": "session_1.cpp:5",
  "code_path": "main() → std::vector<int>::at() → __gnu_cxx::__verbose_terminate_handler() → __GI_abort()",
  "confidence": 0.99,
  "reasoning": "The program attempted to access index 9 of a vector containing only 3 elements, causing std::vector::at() to throw a std::out_of_range exception."
}



7.TypeScript
a. TS2322 - Type Assignment Error

Input

app_1.ts:63:1 - error TS2322: Type 'string' is not assignable to type 'number'.

63 weightsTensor_1 = "invalid_assign_1";
  ~~~~~~~~~~~~~~~

Output

{
  "error_type": "TS2322",
  "failure_location": "app_1.ts:63:1",
  "code_path": "Top-level assignment → weightsTensor_1 = \"invalid_assign_1\"",
  "confidence": 0.99,
  "reasoning": "A string value was assigned to a variable that is declared with the type 'number', violating TypeScript's type checking rules."
}
b. TS2339 - Property Does Not Exist

Input

utils_2.ts:84:13 - error TS2339: Property 'value' does not exist on type 'object'.

84 console.log(metricsData_2.value);
                          ~~~~~

Output

{
  "error_type": "TS2339",
  "failure_location": "utils_2.ts:84:13",
  "code_path": "Top-level execution → console.log(metricsData_2.value)",
  "confidence": 0.99,
  "reasoning": "The code attempts to access the 'value' property on an object whose declared type does not define that property."
}
8.PHP
a. Parse Error

Input

PHP Parse error: syntax error, unexpected token "echo", expecting ";" in /var/www/html/index_1.php on line 64

Output

{
  "error_type": "PHP Parse Error",
  "failure_location": "/var/www/html/index_1.php:64",
  "code_path": "PHP parser → top-level script parsing near 'echo' statement",
  "confidence": 0.99,
  "reasoning": "The parser encountered an 'echo' statement where it expected a semicolon, indicating a missing statement terminator before this line."
}
b. Undefined Function

Input

PHP Fatal error: Uncaught Error: Call to undefined function json_ecnode_typo_$2() in /var/www/html/User_2.php:69
Stack trace:
#0 {main}
  thrown in /var/www/html/User_2.php on line 69

Output

{
  "error_type": "Call to Undefined Function",
  "failure_location": "/var/www/html/User_2.php:69",
  "code_path": "{main} → json_ecnode_typo_$2()",
  "confidence": 0.99,
  "reasoning": "The program attempted to call a function that is not defined or available in the current PHP environment."
}
9.Go
a. Runtime Panic - Index Out of Range

Input

panic: runtime error: index out of range [7] with length 3

goroutine 1 [running]:
main.main()
    /go/src/app/main_2.go:96 +0x3d

Output

{
  "error_type": "Runtime Panic",
  "failure_location": "/go/src/app/main_2.go:96",
  "code_path": "main.main() → slice/array index access",
  "confidence": 0.99,
  "reasoning": "The program attempted to access index 7 of a slice or array that contains only 3 elements, causing a runtime panic."
}
b. Unused Import

Input

./main_5.go:4:5: "math" imported and not used

Output

{
  "error_type": "Unused Import Error",
  "failure_location": "./main_5.go:4:5",
  "code_path": "Package import → import \"math\"",
  "confidence": 0.99,
  "reasoning": "The 'math' package was imported but never referenced in the program, which Go treats as a compilation error."
}

10.Rust
a. E0382 - Borrow of Moved Value

Input

error[E0382]: borrow of moved value: `cache_1`
 --> main_1.rs:99:20
  |
96 |     let cache_1 = String::from("data_3");
97 |     let config_alt_1 = cache_1;
99 |     println!("{}", cache_1);
  |                    ^ value borrowed here after move

Output

{
  "error_type": "E0382",
  "failure_location": "main_1.rs:99:20",
  "code_path": "main() → cache_1 moved to config_alt_1 → println!(cache_1)",
  "confidence": 0.99,
  "reasoning": "Ownership of 'cache_1' was moved to 'config_alt_1', so attempting to use 'cache_1' afterward violates Rust's ownership rules."
}
b. E0277 - Missing Debug Trait

Input

error[E0277]: `CustomStruct_3` doesn't implement `Debug`
 --> utils_3.rs:77:22
  |
77 |     println!("{:?}", instance_3);
  |                      ^ `CustomStruct_3` cannot be formatted using `{:?}` because it doesn't implement the trait

Output

{
  "error_type": "E0277",
  "failure_location": "utils_3.rs:77:22",
  "code_path": "println!(\"{:?}\", instance_3) → Debug trait check",
  "confidence": 0.99,
  "reasoning": "The code attempts to print 'instance_3' using the '{:?}' formatter, but its type does not implement the Debug trait required for formatted output."
}


11.Java
a. Cannot Find Symbol

Input

Api_1.java:29: error: cannot find symbol
        System.out.println(config_1_typo);
                           ^
  symbol:   variable config_1_typo
  location: class NetworkPacket_1

Output

{
  "error_type": "Cannot Find Symbol",
  "failure_location": "Api_1.java:29",
  "code_path": "NetworkPacket_1 → System.out.println(config_1_typo)",
  "confidence": 0.99,
  "reasoning": "The variable 'config_1_typo' is referenced but has not been declared or is not accessible within the current scope."
}



'''

# %% [markdown]
# # Re-Run Codes

# %%
import os
print("Current working directory:", os.getcwd())
print("Looking for .env at ../.env — exists:", os.path.exists("../.env"))
# Out:
# Current working directory: C:\Users\famil\OneDrive\Desktop\AI_Smart_Bug_Analyzer_-_Fix-_Advisor-\notebooks
# Looking for .env at ../.env — exists: True

# %%
if os.path.exists("../.env"):
    with open("../.env", "r") as f:
        content = f.read()
    print("File has content:", len(content) > 0)
    print("Contains 'GROQ_API_KEY':", "GROQ_API_KEY" in content)

# %%
with open("../.env", "r") as f:
    content = f.read()

print("Content length:", len(content))
print("First 20 characters:", content[:20])
print("Number of lines:", len(content.splitlines()))

# %%
env_content = "GROQ_API_KEY=Api_key_pated _here"

with open("../.env", "w") as f:
    f.write(env_content)

print("Rewrote .env file")
# Out:
# Rewrote .env file

# %%
from dotenv import load_dotenv
load_dotenv("../.env", override=True)
api_key = os.getenv("GROQ_API_KEY")
print("API key loaded:", api_key[:8] if api_key else "NOT FOUND")
# Out:
# API key loaded: gsk_Dcbl

# %%
# from dotenv import load_dotenv
# load_dotenv("../.env", override=True)
# api_key = os.getenv("GROQ_API_KEY")
# print("API key loaded:", api_key[:8] if api_key else "NOT FOUND")

from dotenv import load_dotenv
load_dotenv("../.env", override=True)
api_key = os.getenv("GROQ_API_KEY")
print("API key loaded:", api_key[:8] if api_key else "NOT FOUND")

# %%
from groq import Groq
import json
client = Groq(api_key=api_key)
print("Client created successfully")
# Out:
# Client created successfully

# %%
def call_llm_with_retry(system_prompt, user_message, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_message}
                ],
                temperature=0.2
            )
            return json.loads(response.choices[0].message.content)
        except Exception as e:
            if "rate_limit" in str(e).lower() or "429" in str(e):
                wait_time = (attempt + 1) * 3
                print(f"Rate limited, waiting {wait_time}s...")
                time.sleep(wait_time)
            else:
                print(f"Non-rate-limit error: {e}")
                break
    return None

# %%
system_prompt = """You are a bug triage assistant. You are given the title, description, and stack trace of a submitted bug, and you classify it by severity, priority, and affected component, with confidence scoring and reasoning.

IMPORTANT CALIBRATION: Most everyday bugs are Medium severity, not Critical or High. Reserve Critical/High for bugs that cause crashes, data loss, security issues, or completely block core functionality. Reserve Low for cosmetic issues, minor inconveniences, or feature requests. The MAJORITY of real-world bugs are routine Medium severity - do not over-classify ordinary bugs as urgent just because they mention words like "error" or "exception."

Examples for calibration:
Examples for calibration:
- "App crashes on startup, no workaround" -> Critical
- "Login fails for all users" -> Critical  
- "Payment fails for some users but not others, blocking checkout for that group" -> High
- "File upload crashes for large files, though smaller files work fine" -> High
- "Button text is misaligned by 2px" -> Low
- "Feature request: add dark mode" -> Low
- "Export function occasionally produces incorrect date format" -> Medium
- "Search results are slow to load under heavy traffic" -> Medium

Reply ONLY in valid JSON, with this exact structure:
{"bug_id": "...", "severity": "Critical", "confidence": 0.85, "reasoning": "...", "priority": "...", "component": "Login"}

Field definitions:
- bug_id: if provided, use it; otherwise use "unknown"
- severity: must be exactly one of Critical, High, Medium, Low - no other words
- confidence: a score from 0 to 1 representing how confident you are in this classification
- reasoning: a brief explanation of why you classified it this way
- priority: how urgently this needs to be addressed - Immediate, High, Medium, or Low (related to but different from severity: severity is impact, priority is urgency)
- component: which part/module of the software seems affected, inferred from the content (e.g. "Login", "Database", "UI/Rendering") - do not restrict to a fixed list

If you encounter other severity-like words, map them using this table:
blocker/critical -> Critical, major -> High, normal/unknown -> Medium, minor/trivial -> Low
"""

log_analysis_system_prompt = """You are a Log Analysis Agent. Your job is to extract structured information from messy error text - stack traces, tracebacks, or compiler error messages, sometimes alongside the relevant code.

Extract:
- error_type: the SPECIFIC error/exception name as it would appear in real compiler/runtime output - NOT a generic category. For example, prefer "Template Mismatch" or "Dereferencing Void Pointer" over generic terms like "Compilation Error" or "Compilation Warning". Look for the specific technical term the error message itself uses, not a broad summary category.
- failure_location: the exact file/line/position where the error occurred, taken directly from the trace
- code_path: the chain of function/method calls leading to the failure. IMPORTANT: if the code being described contains double quote characters (e.g. from println!, print statements, or string literals), you MUST escape them as \\" so the JSON stays valid. Never include an unescaped " inside any field value.
- confidence: a score from 0 to 1 representing how certain you are that you extracted this correctly. Vary this realistically - very clear, unambiguous traces should score 0.95-0.99, while vague, truncated, or ambiguous input should score lower (0.5-0.8). Do not default to 0.99 for everything.
- reasoning: a brief, specific explanation of why the error occurred

Reply ONLY in valid JSON with this exact structure. Every field value must be a properly escaped JSON string - double quotes inside any value must be written as \\":
{"error_type": "...", "failure_location": "...", "code_path": "...", "confidence": 0.9, "reasoning": "..."}

Examples:

Input: Cell In[119], line 3
    return payload_2
    ^
IndentationError: unindent does not match any outer indentation level

Output: {"error_type": "IndentationError", "failure_location": "Cell In[119], line 3", "code_path": "return payload_2 executed directly within the current code block; indentation parsing failed before execution", "confidence": 0.99, "reasoning": "The 'return' statement has inconsistent indentation that does not align with the surrounding block, causing Python's parser to reject the code."}

Input: /workspace/service_2.js:3
console.log(session_2[5].id);
TypeError: Cannot read properties of undefined (reading 'id')
    at Object.<anonymous> (/workspace/service_2.js:3:15)

Output: {"error_type": "TypeError", "failure_location": "/workspace/service_2.js:3:15", "code_path": "Top-level execution -> console.log(session_2[5].id)", "confidence": 0.99, "reasoning": "The expression 'session_2[5]' evaluated to undefined, so accessing its 'id' property caused a TypeError."}

Input: parser_4.c: In function 'main':
parser_4.c:3:15: error: invalid initializer / incompatible types when initializing type 'int' using type 'char *'
    3 |     int val = str;

Output: {"error_type": "Invalid Initializer (Incompatible Types)", "failure_location": "parser_4.c:3:15", "code_path": "main() -> variable initialization: int val = str", "confidence": 0.85, "reasoning": "An integer variable was initialized using a character pointer, which is an incompatible type conversion in C."}

Input: session_2.cpp: In function 'int main()':
session_2.cpp:5:17: error: no matching member function for call to 'insert'
    5 |     ages.insert(10, "John");

Output: {"error_type": "No Matching Member Function", "failure_location": "session_2.cpp:5:17", "code_path": "main() -> std::map::insert(10, \\"John\\")", "confidence": 0.95, "reasoning": "The std::map::insert() function was called with arguments that do not match any valid overload."}

Input: Exception in thread "main" java.lang.NullPointerException: Cannot invoke "String.indexOf(String)" because "recordsList_2" is null
    at MetricsEngine_2.updateCache_2(Api_2.java:110)

Output: {"error_type": "NullPointerException", "failure_location": "Api_2.java:110", "code_path": "main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()", "confidence": 0.99, "reasoning": "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}

Input: CssSyntaxError: grid_2.css:20:1: Unclosed block
  18 |     background: #000;
  19 |     opacity: 0.9;
> 20 |
    | ^
  21 | .element-sibling_2 {

Output: {"error_type": "PostCSS Parser Error: Unclosed Block", "failure_location": "grid_2.css:20:1", "code_path": "CSS parser -> grid_2.css -> unclosed declaration block before '.element-sibling_2'", "confidence": 0.99, "reasoning": "A CSS block was not properly closed with '}', causing the parser to detect an unclosed block before the next selector."}

Input: Error: Stray end tag </span>.
From line 95, column 15; to line 95, column 22
item 1</p></span>\n</di

Output: {"error_type": "W3C Validator Error: Stray End Tag", "failure_location": "Line 95, columns 15-22", "code_path": "HTML parser -> closing tags -> unexpected </span>", "confidence": 0.99, "reasoning": "The closing </span> tag does not match any currently open <span> element, resulting in a stray end tag."}

Input: app_1.ts:63:1 - error TS2322: Type 'string' is not assignable to type 'number'.
63 weightsTensor_1 = "invalid_assign_1";
  ~~~~~~~~~~~~~~~

Output: {"error_type": "TypeScript Error: TS2322 (Type Assignment Error)", "failure_location": "app_1.ts:63:1", "code_path": "Top-level assignment -> weightsTensor_1 = \\"invalid_assign_1\\"", "confidence": 0.99, "reasoning": "A string value was assigned to a variable that is declared with the type 'number', violating TypeScript's type checking rules."}

Input: panic: runtime error: index out of range [7] with length 3
goroutine 1 [running]:
main.main()
    /go/src/app/main_2.go:96 +0x3d

Output: {"error_type": "Go Runtime Panic: Index Out of Range", "failure_location": "/go/src/app/main_2.go:96", "code_path": "main.main() -> slice/array index access", "confidence": 0.99, "reasoning": "The program attempted to access index 7 of a slice or array that contains only 3 elements, causing a runtime panic."}
"""

def triage_agent(title, description, stack_trace="Not available", bug_id="unknown"):
    user_message = f"Title: {title}\nDescription: {description}\nStack Trace: {stack_trace}"
    result = call_llm_with_retry(system_prompt, user_message)
    if result is None:
        result = {"severity": "Medium", "confidence": 0.0, "reasoning": "LLM call failed after retries", "priority": "Medium", "component": "Unknown"}
    result['bug_id'] = bug_id
    return result

def log_analysis_agent(error_text, code_context=""):
    if code_context:
        user_message = f"Code:\n{code_context}\n\nError:\n{error_text}"
    else:
        user_message = f"Error:\n{error_text}"
    result = call_llm_with_retry(log_analysis_system_prompt, user_message)
    if result is None:
        result = {
            "error_type": "Unknown",
            "failure_location": "Not determined",
            "code_path": "Not determined",
            "confidence": 0.0,
            "reasoning": "LLM call failed after retries"
        }
    return result

print("Both agents ready")
# Out:
# Both agents ready

# %%
test_title = "App crashes on login"
test_description = "Users report the app crashes immediately after entering valid credentials."
test_stack_trace = """Exception in thread "main" java.lang.NullPointerException: Cannot invoke "String.indexOf(String)" because "recordsList_2" is null
    at MetricsEngine_2.updateCache_2(Api_2.java:110)"""

triage_result = triage_agent(test_title, test_description, test_stack_trace, bug_id="TEST-001")
print("TRIAGE RESULT:")
print(triage_result)

print()

log_result = log_analysis_agent(test_stack_trace)
print("LOG ANALYSIS RESULT:")
print(log_result)
# Out:
# TRIAGE RESULT:
# {'bug_id': 'TEST-001', 'severity': 'Critical', 'confidence': 0.9, 'reasoning': 'The app crashes immediately after a critical action (login) with a NullPointerException, indicating a severe issue that prevents users from accessing the app', 'priority': 'Immediate', 'component': 'Login'}
#
# LOG ANALYSIS RESULT:
# {'error_type': 'NullPointerException', 'failure_location': 'Api_2.java:110', 'code_path': 'main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()', 'confidence': 0.99, 'reasoning': "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}

# %%
def run_orchestration(title,description , stack_trace , bug_id = "unknown"):
    triage_result = triage_agent(title , description , stack_trace , bug_id=bug_id)
    log_result = log_analysis_agent(stack_trace)
    combined_result= {
        "bug_id" : bug_id,
        "triage" : triage_result,
        "log_analysis" : log_result
    }

    return combined_result

def build_simple_view (combined_result):
    triage = combined_result['triage']
    log = combined_result['log_analysis']

    actual_result = {
        'bug_id':combined_result['bug_id'],
        'severity':triage['severity'],
        'priority':triage['priority'],
        'component' : triage['component'],
        'error_type':log['error_type'],
        'failure_location':log['failure_location'],
        'code_path':log['code_path'],
        'confidence':log['confidence'],
        'reasoning':log['reasoning']
    }

    return actual_result

# %%
result = run_orchestration(test_title,test_description , test_stack_trace ,bug_id = "TEST-001")
print("Combined Result (save , sent to Milestone 3 ) :")
print(result)
 

print()

simple = build_simple_view(result)
print("Simple View (for UI default disply) ")
print(simple)
# Out:
# Combined Result (save , sent to Milestone 3 ) :
# {'bug_id': 'TEST-001', 'triage': {'bug_id': 'TEST-001', 'severity': 'Critical', 'confidence': 0.9, 'reasoning': 'The app crashes immediately after a critical action (login) with a NullPointerException, indicating a severe issue that prevents users from accessing the app.', 'priority': 'Immediate', 'component': 'Login'}, 'log_analysis': {'error_type': 'NullPointerException', 'failure_location': 'Api_2.java:110', 'code_path': 'main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()', 'confidence': 0.99, 'reasoning': "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}}
#
# Simple View (for UI default disply)
# {'bug_id': 'TEST-001', 'severity': 'Critical', 'priority': 'Immediate', 'component': 'Login', 'error_type': 'NullPointerException', 'failure_location': 'Api_2.java:110', 'code_path': 'main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()', 'confidence': 0.99, 'reasoning': "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}

# %%
# import pandas as pd
# import json
# import time
# import re
# from groq import Groq
# from dotenv import load_dotenv
# import os

# load_dotenv("../.env", override=True)
# api_key = os.getenv("GROQ_API_KEY")
# client = Groq(api_key=api_key)

# print("Setup complete. API key loaded:", api_key[:8] if api_key else "NOT FOUND")import os
# print("Current working directory:", os.getcwd())
# print("Looking for .env at ../.env — exists:", os.path.exists("../.env"))

# %%
# Run this in a new cell - it searches your OWN notebook file for the key prefix
with open("02_triage_agent.ipynb", "r", encoding="utf-8") as f:
    content = f.read()

import re
matches = re.findall(r'gsk_[a-zA-Z0-9]+', content)
print("Number of matches found:", len(matches))
for m in set(matches):
    print(m[:10] + "..." + m[-4:])

# %%
import sys
sys.path.append("../src")

from agents import run_orchestration, build_simple_view

print("Import successful")
# Out:
# Import successful

# %%
result = run_orchestration(
    "App crashes on login",
    "Users report the app crashes immediately after entering valid credentials.",
    """Exception in thread "main" java.lang.NullPointerException: Cannot invoke "String.indexOf(String)" because "recordsList_2" is null
    at MetricsEngine_2.updateCache_2(Api_2.java:110)""",
    bug_id="TEST-002"
)
print(result)
# Out:
# {'bug_id': 'TEST-002', 'triage': {'bug_id': 'TEST-002', 'severity': 'Critical', 'confidence': 0.9, 'reasoning': 'The app crashes immediately after a user attempts to log in, which is a core functionality. The presence of a NullPointerException in the stack trace suggests a significant issue that needs immediate attention.', 'priority': 'Immediate', 'component': 'Login'}, 'log_analysis': {'error_type': 'NullPointerException', 'failure_location': 'Api_2.java:110', 'code_path': 'main thread -> MetricsEngine_2.updateCache_2() -> String.indexOf()', 'confidence': 0.99, 'reasoning': "The object 'recordsList_2' is null, so calling the 'indexOf()' method on it causes a NullPointerException."}}

# %% [markdown]
# # Sample And Temp Work Cells

# %% [markdown]
# ## Test

# %%
print(system_prompt)
# Out:
# You are a bug triage assistant. You are given the title, description, and stack trace of a submitted bug, and you classify it by severity, priority, and affected component, with confidence scoring and reasoning.
#
# IMPORTANT CALIBRATION: Most everyday bugs are Medium severity, not Critical or High. Reserve Critical/High for bugs that cause crashes, data loss, security issues, or completely block core functionality. Reserve Low for cosmetic issues, minor inconveniences, or feature requests. The MAJORITY of real-world bugs are routine Medium severity - do not over-classify ordinary bugs as urgent just because they mention words like "error" or "exception."
#
# Examples for calibration:
# - "App crashes on startup, no workaround" -> Critical
# - "Login fails for all users" -> Critical
# - "Button text is misaligned by 2px" -> Low
# - "Feature request: add dark mode" -> Low
# - "Export function occasionally produces incorrect date format" -> Medium
# - "Search results are slow to load under heavy traffic" -> Medium
#
# Reply ONLY in valid JSON, with this exact structure:
# {"bug_id": "...", "severity": "Critical", "confidence": 0.85, "reasoning": "...", "priority": "...", "component": "Login"}
#
# Field definitions:
# - bug_id: if provided, use it; otherwise use "unknown"
# - severity: must be exactly one of Critical, High, Medium, Low - no other words
# - confidence: a score from 0 to 1 representing how confident you are in this classification
# - reasoning: a brief explanation of why you classified it this way
# - priority: how urgently this needs to be addressed - Immediate, High, Medium, or Low (related to but different from severity: severity is impact, priority is urgency)
# - component: which part/module of the software seems affected, inferred from the content (e.g. "Login", "Database", "UI/Rendering") - do not restrict to a fixed list
#
# If you encounter other severity-like words, map them using this table:
# blocker/critical -> Critical, major -> High, normal/unknown -> Medium, minor/trivial -> Low

# %% [markdown]
# ## DataBase

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../data/bug_submissions.db")
df = pd.read_sql("SELECT * FROM bug_submissions", conn)
conn.close()

print("Rows in database:", len(df))
df
# Out:
# Rows in database: 5
#          bug_id  severity   priority           component  \
# 0  BUG-3b0fe790  Critical  Immediate      Initialization
# 1  BUG-f25343c8  Critical  Immediate            Database
# 2  BUG-b216f3db      High       High  Payment Processing
# 3  BUG-fabe5064    Medium     Medium    Search/Filtering
# 4  BUG-173ed07b       Low        Low        UI/Rendering
#
#              error_type failure_location  \
# 0  NullPointerException     Init.java:22
# 1       ConnectionError  db_handler.py:8
# 2       ValidationError    payment.py:44
# 3  Incorrect Sort Order          Unknown
# 4         Cosmetic Typo    Settings page
#
#                                            code_path  confidence  \
# 0           main thread -> Init class initialization        0.99
# 1  Application startup -> Database connection ini...        0.95
# 2  Payment processing -> checkout -> currency cod...        0.95
# 3     Search results filtering -> date-based sorting        0.60
# 4    Settings page rendering -> button label display        0.80
#
#                                            reasoning  \
# 0  The program attempts to access or manipulate a...
# 1  The application is unable to establish a conne...
# 2  The currency code provided for an internationa...
# 3  The sorting algorithm or data processing pipel...
# 4  A minor typo exists in the button label text, ...
#
#                                          description  \
# 0  App crashes immediately on startup for all use...
# 1  Database connection fails on every request, en...
# 2  Payment processing occasionally fails for inte...
# 3  Search results occasionally show incorrect sor...
# 4  Button label says "Sumbit" instead of "Submit"...
#
#                     timestamp
# 0  2026-07-21T13:38:56.382019
# 1  2026-07-21T13:52:09.843454
# 2  2026-07-21T13:52:51.340602
# 3  2026-07-21T13:53:10.866122
# 4  2026-07-21T13:53:33.789648

# %% [markdown]
# # Retrival agents

# %% [markdown]
# ## Root cause agent

# %%
import pandas as pd
kb_metadata_check = pd.read_csv("../src/chunks_metadata.csv")
print(kb_metadata_check.columns.tolist())
# Out:
# ['bug_id', 'title', 'severity', 'resolution', 'status', 'source_dataset']

# %%
import sys
import os

# Option A: Using the absolute (full) path to folder_c
sys.path.append(r"rootpath/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/src")

# %%
import importlib
import agents
importlib.reload(agents)
from agents import retrieve_similar_bugs

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import pandas as pd

model = SentenceTransformer('all-MiniLM-L6-v2')
kb_embeddings = np.load("../src/embeddings_real.npy")
kb_metadata = pd.read_csv("../src/chunks_metadata.csv")

print("Model loaded")
print("Embeddings shape:", kb_embeddings.shape)
print("Metadata shape:", kb_metadata.shape)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Model loaded
# Embeddings shape: (56862, 384)
# Metadata shape: (56862, 6)

# %%
results = retrieve_similar_bugs(
    """Traceback (most recent call last):

Cell In[92], line 4, in <module>

update_cache_40)

Cell In[92], line 2, in update_cache_4

1 def update_cache_40):

->2 return config_4_missing + 10



NameError: name 'config_4_missing' is not defined """, #"App crashes on login with NullPointerException",
    model, kb_embeddings, kb_metadata, top_n=5
)

for r in results:
    print(r)
    print()
# Out:
# {'bug_id': 'ROL-454', 'title': 'Exception creating a new user upon installation (even adminUser)', 'severity': 'Major', 'resolution': "Won't Fix", 'source_dataset': 'Apache', 'similarity': 0.46756795048713684}
#
# {'bug_id': 'IBATISNET-36', 'title': '"embedded" spelled wrong in SqlMapConfig.xsd in SVN', 'severity': 'Major', 'resolution': 'Fixed', 'source_dataset': 'Apache', 'similarity': 0.4539636969566345}
#
# {'bug_id': 'IVY-108', 'title': 'cachefileset returns all cache files for empty conf', 'severity': 'Major', 'resolution': 'Fixed', 'source_dataset': 'Apache', 'similarity': 0.44339457154273987}
#
# {'bug_id': 'SNIPPETS-900528', 'title': 'IndexError in template code for main snippets view', 'severity': 'normal', 'resolution': 'fixed', 'source_dataset': 'Mozilla', 'similarity': 0.43261614441871643}
#
# {'bug_id': 'COCOON-1698', 'title': '[PATCH] caching-global-use-attributes does not work', 'severity': 'Major', 'resolution': 'Fixed', 'source_dataset': 'Apache', 'similarity': 0.4291034936904907}

# %%
root_cause_prompt = """ You are job is to Retrieve Relevant Historical Bugs and Generate Root Cause Analysis

and identifies the most probable root cause of a submitted bug using RAG-based retrieval from the historical defect knowledge base. Output(Reply ONLY in valid JSON) - Root cause hypothesis, confidence score, and supporting historical evidence 

input will be the 

 { 

bug_id , severity , component , error_type ,failure_location , code_path , {plus the 5 retrieved similar historical bugs (with their resolutions)}       

}

You must reason about why this new bug likely happened, using patterns from those historical bugs as support.

Output:
{
  "root_cause_hypothesis": "...",   
  "confidence": 0.85,
  "supporting_evidence": [
    {"bug_id": "...", "summary": "..."},
    {"bug_id": "...", "summary": "..."}
  ]
}

 

 Root cause hypothesis - It is the explanation of why the bug happened — e.g., "The NullPointerException likely occurred because the recordsList object was never initialized before being accessed, similar to patterns seen in [historical bug].

confidence score - a score from 0 to 1 representing how certain you are that you extracted this correctly. Vary this realistically - very clear, unambiguous traces should score 0.95-0.99, while vague, truncated, or ambiguous input should score lower (0.5-0.8). Do not default to 0.99 for everything.

supporting historical evidence - evidence should include both a traceable bug_id AND a short 5-15 word summary ( this should be a list of small objects, not a single string.)



Example 1:
Input: {"error_type": "NullPointerException", "component": "Login", "failure_location": "Api_2.java:110", "code_path": "main thread -> updateCache_2() -> String.indexOf()", "retrieved_bugs": [{"bug_id": "GMF-RUNTIME-282380", "title": "DefaultProvider#getRelevantConnections may throw a NPE", "resolution": "fixed"}, {"bug_id": "JCR-71", "title": "WorkspaceConfig.init() throws NullPointerException if Search configuration is missing", "resolution": "Fixed"}]}

Output: {"root_cause_hypothesis": "The NullPointerException likely occurred because an object (recordsList) was accessed before being properly initialized, a pattern consistent with similar historical NPEs caused by missing configuration or setup steps.", "confidence": 0.82, "supporting_evidence": [{"bug_id": "GMF-RUNTIME-282380", "summary": "NPE from missing null check before method call"}, {"bug_id": "JCR-71", "summary": "NPE from missing required configuration on init"}]}

Example 2:
Input: {"error_type": "IndexError", "component": "Search/Filtering", "failure_location": "sort_handler.py:22", "code_path": "apply_filter() -> sort_results()", "retrieved_bugs": [{"bug_id": "PY-1002", "title": "List index out of range when filter returns empty results", "resolution": "fixed"}]}

Output: {"root_cause_hypothesis": "The IndexError likely occurred because the sorting function assumed the filtered list would always contain at least one item, but did not handle the case of an empty result set.", "confidence": 0.75, "supporting_evidence": [{"bug_id": "PY-1002", "summary": "Empty list not handled before indexing"}]}

Example 3:
Input: {"error_type": "ConnectionError", "component": "Database", "failure_location": "db_handler.py:8", "code_path": "startup() -> connect_db()", "retrieved_bugs": [{"bug_id": "APACHE-990", "title": "Database connection pool exhausted under load", "resolution": "fixed"}, {"bug_id": "APACHE-1103", "title": "Connection timeout not configured, hangs indefinitely", "resolution": "fixed"}, {"bug_id": "APACHE-1204", "title": "Retry logic missing on transient connection failures", "resolution": "wontfix"}]}

Output: {"root_cause_hypothesis": "The connection failure is likely caused by either exhausted connection pool capacity or a missing timeout/retry mechanism, both common causes of database connection failures under load in similar historical cases.", "confidence": 0.68, "supporting_evidence": [{"bug_id": "APACHE-990", "summary": "Connection pool exhausted under high load"}, {"bug_id": "APACHE-1103", "summary": "Missing timeout caused indefinite hang"}]}

Example 4:
Input: {"error_type": "TypeError", "component": "UI/Rendering", "failure_location": "render.js:15", "code_path": "renderComponent() -> formatDate()", "retrieved_bugs": []}

Output: {"root_cause_hypothesis": "No closely related historical bugs were found, but based on the error itself, this likely occurred because a date value was undefined or in an unexpected format when passed into the formatting function.", "confidence": 0.55, "supporting_evidence": []}

Example 5:
Input: {"error_type": "ValidationError", "component": "Payment Processing", "failure_location": "payment.py:44", "code_path": "checkout() -> validate_currency()", "retrieved_bugs": [{"bug_id": "TVT35-297", "title": "incorrect default placement of currency symbol", "resolution": "fixed"}]}

Output: {"root_cause_hypothesis": "This is likely a currency-code validation gap rather than the same issue as the retrieved bug, since that historical case involved display formatting, not validation logic - the connection is only loosely related.", "confidence": 0.6, "supporting_evidence": [{"bug_id": "TVT35-297", "summary": "Related currency-handling bug, but different root cause"}]}

Example 6:
Input: {"error_type": "MemoryError", "component": "File Upload", "failure_location": "upload_handler.js:67", "code_path": "uploadFile() -> allocateBuffer()", "retrieved_bugs": [{"bug_id": "AXIS-1741", "title": "LogHandler can only work in GlobalConfiguration", "resolution": "fixed"}]}

Output: {"root_cause_hypothesis": "No strongly related historical bug was found; the retrieved bug shares only superficial similarity (both are configuration-related) but does not explain a memory allocation failure on large file uploads.", "confidence": 0.5, "supporting_evidence": [{"bug_id": "AXIS-1741", "summary": "Unrelated configuration bug, weak match only"}]}

Example 7:
Input: {"error_type": "SyntaxError", "component": "Build System", "failure_location": "config.css:20", "code_path": "CSS parser -> block parsing", "retrieved_bugs": [{"bug_id": "CSS-501", "title": "Unclosed declaration block causes parser failure", "resolution": "fixed"}, {"bug_id": "CSS-512", "title": "Missing semicolon triggers cascading syntax errors", "resolution": "fixed"}]}

Output: {"root_cause_hypothesis": "The syntax error is almost certainly caused by an unclosed block or missing terminator in the CSS source, a very common and well-documented pattern matching both retrieved historical bugs closely.", "confidence": 0.93, "supporting_evidence": [{"bug_id": "CSS-501", "summary": "Unclosed block caused identical parser failure"}, {"bug_id": "CSS-512", "summary": "Missing semicolon caused cascading syntax error"}]}



"""

# %%
import importlib
import agents
importlib.reload(agents)
from agents import retrieve_similar_bugs, root_cause_agent

# Step 1: retrieve similar historical bugs (already proven working)
retrieved = retrieve_similar_bugs(
    """Traceback (most recent call last):

Cell In[92], line 4, in <module>

update_cache_40)

Cell In[92], line 2, in update_cache_4

1 def update_cache_40):

->2 return config_4_missing + 10



NameError: name 'config_4_missing' is not defined """, #"App crashes on login with NullPointerException",
    model, kb_embeddings, kb_metadata, top_n=5
)

# Step 2: feed into root cause agent
result = root_cause_agent(
    bug_id="BUG-30550c39",
    severity="Medium",
    component="Cache Management",
    error_type="NameError",
    failure_location="Cell In [92], line 2",
    code_path="update_cache_4() -> return statement: config_4_missing + 10",
    retrieved_bugs=retrieved
)

print(result)
# Out:
# {'root_cause_hypothesis': 'The NameError likely occurred because a variable or function was referenced before being defined, possibly due to a missing import statement or a typo in the variable name, similar to patterns seen in historical bugs related to configuration and caching issues.', 'confidence': 0.62, 'supporting_evidence': [{'bug_id': 'IVY-108', 'summary': 'Cache configuration issue caused unexpected behavior'}, {'bug_id': 'COCOON-1698', 'summary': 'Caching attribute issue caused functionality failure'}]}

# %%
retrieved = retrieve_similar_bugs(
    "App crashes on login with NullPointerException",
    model, kb_embeddings, kb_metadata, top_n=5
)
for r in retrieved:
    print(r['bug_id'])
# Out:
# GMF-RUNTIME-282380
# AXIS-1261
# FIREFOX_FOR_ANDROID-804926
# JCR-71
# IBATIS-114

# %% [markdown]
# ## Duplicate detection agent

# %%
.+











































































































0# d.+
.+












+.upl
    
+
icate_detection_agent_prompt = """  Your job is to performs semantic similarity search over past bug submissions(Stored in Sqlite3 Data Base), surfaces top matching resolved issues with similarity scores and historical resolution summaries.

# input will be :

# { description ,  error_type , component , reasoning }


# - description :  information given to you about bug or error 

# - error_type: the SPECIFIC error/exception name as it would appear in real compiler/runtime output - NOT a generic category. For example, prefer "Template Mismatch" or "Dereferencing Void Pointer" over generic terms like "Compilation Error" or "Compilation Warning". Look for the specific technical term the error message itself uses, not a broad summary category.

# - component: which part/module of the software seems affected, inferred from the content (e.g. "Login", "Database", "UI/Rendering") - do not restrict to a fixed list

# - reasoning: a brief explanation of why you classified it this way

# what is process is :


# "    
# Say a new bug comes in: "App crashes on login with NullPointerException". You have 3 bugs already stored in SQLite from earlier testing. Here's what happens, step by step:

# Stored bug in SQLite	Cosine similarity to new bug
# "App crashes on login with NullPointerException" (literally identical wording)	0.99
# "Login fails, NullPointerException thrown" (same meaning, different words)	0.87
# "Button color looks wrong on settings page" (totally unrelated)	0.12

# That similarity number — 0.99, 0.87, 0.12 — comes from math (cosine_similarity), the exact same function you already used in Root Cause Agent's retrieval. No LLM involved in producing that number, ever.
# It's calculated, not guessed.
# if the number is above 0.90, call it same; between 0.75 and 0.90, call it similar; below that, ignore it
# Here's the new bug and the old matching one — write one short sentence explaining why they look like the same issue

# "



# """

# %%
duplicate_detection_agent_prompt = """You are given a new bug report and a previously submitted bug that has already been mathematically determined to be a likely duplicate, along with its similarity label ("same" or "similar").

Your only job is to write one short, clear sentence (15-25 words) explaining why these two bugs likely describe the same underlying issue, based on their description, error_type, and component.

Do not assign or change the similarity score or label - those are already fixed and provided to you. Do not question or override the label.

Reply ONLY in valid JSON with this exact structure:
{"explanation": "..."}

Example:
Input: {"new_bug": {"description": "App crashes on login with NullPointerException", "error_type": "NullPointerException", "component": "Login"}, "matched_bug": {"description": "Login fails, NullPointerException thrown", "error_type": "NullPointerException", "component": "Login"}, "label": "similar", "similarity": 0.87}

Output: {"explanation": "Both reports describe a NullPointerException occurring during login, indicating the same underlying failure in the Login component."}
"""

# %%
# --- Imports ---
import os
import json
import time
import sqlite3
import pandas as` pd
import numpy as np
from groq import Groq
from dotenv import load_dotenv
from sklearn.metrics.pairwise import cosine_similarity

# --- API client setup ---
load_dotenv("../.env", override=True)
api_key = os.getenv("GROQ_API_KEY")
client = Groq(api_key=api_key)

# --- Retry wrapper ---
def call_llm_with_retry(system_prompt, user_message, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_message}
                ],
                temperature=0.2
            )
            return json.loads(response.choices[0].message.content)
        except Exception as e:
            if "rate_limit" in str(e).lower() or "429" in str(e):
                wait_time = (attempt + 1) * 3
                print(f"Rate limited, waiting {wait_time}s...")
                time.sleep(wait_time)
            else:
                print(f"Non-rate-limit error: {e}")
                break
    return None

print("Setup complete. API key loaded:", api_key[:8] if api_key else "NOT FOUND")

# %%
print(duplicate_detection_agent_prompt[:50])
# Out:
# You are given a new bug report and a previously su

# %%
from sklearn.metrics.pairwise import cosine_similarity
import json

def find_duplicate_candidates(new_description, model, top_n=5):
    import sqlite3
    base_dir = os.path.dirname(os.path.abspath(__file__)) if "__file__" in dir() else ".."
    db_path = os.path.join(base_dir, "..", "data", "bug_submissions.db") if "__file__" in dir() else "../data/bug_submissions.db"
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT bug_id, description, error_type, component, reasoning FROM bug_submissions")
    rows = cursor.fetchall()
    conn.close()
    if not rows:
        return []
    stored_descriptions = [row[1] for row in rows]
    new_vector = model.encode([new_description], convert_to_numpy=True)
    stored_vectors = model.encode(stored_descriptions, convert_to_numpy=True)
    similarities = cosine_similarity(new_vector, stored_vectors)[0]
    candidates = []
    for i, sim in enumerate(similarities):
        if sim >= 0.75:
            label = "same" if sim >= 0.90 else "similar"
            candidates.append({
                "bug_id": rows[i][0],
                "description": rows[i][1],
                "error_type": rows[i][2],
                "similarity": float(sim),
                "label": label
            })
    candidates.sort(key=lambda x: x["similarity"], reverse=True)
    return candidates[:top_n]

# %%
def duplicate_detection_agent(new_description, error_type, component, reasoning, model, top_n=5):
    candidates =find_duplicate_candidates(new_description, model, top_n=top_n)

    results = []
    for c in candidates:
        input_data = {
            "new_bug": {"description": new_description, "error_type": error_type, "component": component},
            "matched_bug": {"description": c["description"], "error_type": c["error_type"]},
            "label": c["label"],
            "similarity": c["similarity"]
        }
        user_message = json.dumps(input_data)
        explanation_result = call_llm_with_retry(duplicate_detection_agent_prompt, user_message)

        results.append({
            "bug_id": c["bug_id"],
            "similarity": c["similarity"],
            "label": c["label"],
            "explanation": explanation_result["explanation"] if explanation_result else "No explanation available."
        })

    return results

# %%
import sqlite3
import pandas as pd

base_dir = os.path.dirname(os.path.abspath("__file__"))
db_path = "../data/bug_submissions.db"
conn = sqlite3.connect(db_path)
df = pd.read_sql("SELECT bug_id, description, error_type, component FROM bug_submissions", conn)
conn.close()

print(df)
# Out:
#           bug_id                                        description  \
# 0   BUG-3b0fe790  App crashes immediately on startup for all use...
# 1   BUG-f25343c8  Database connection fails on every request, en...
# 2   BUG-b216f3db  Payment processing occasionally fails for inte...
# 3   BUG-fabe5064  Search results occasionally show incorrect sor...
# 4   BUG-173ed07b  Button label says "Sumbit" instead of "Submit"...
# 5   BUG-1f12378b  App crashes immediately on startup for all use...
# 6   BUG-f5b5592a  Payment processing occasionally fails for inte...
# 7   BUG-4f3ac660  Traceback (most recent call last): Cell In[92]...
# 8   BUG-c1a805a2  Traceback (most recent call last): Cell In[92]...
# 9   BUG-c53ac751  App crashes immediately on startup for all use...
# 10  BUG-cf3508db  Button label says "Sumbit" instead of "Submit"...
# 11  BUG-09e0269c  App crashes immediately on startup for all use...
# 12  BUG-a5336770  App crashes immediately on startup for all use...
# 13  BUG-da34fe7f  Traceback (most recent call last): \nCell In[9...
# 14  BUG-daad1134  Traceback (most recent call last): \nCell In[9...
# 15  BUG-6353d916  Database connection fails on every request, en...
# 16  BUG-f6c01d15  4. Payment processing occasionally fails for i...
# 17  BUG-9eecb4d1  Export to PDF function produces slightly misfo...
# 18  BUG-1a9af3a8  Feature request: add a dark mode toggle to the...
# 19  BUG-54657785  Notification emails are sometimes delayed by 1...
#
#                             error_type                  component
# 0                 NullPointerException             Initialization
# 1                      ConnectionError                   Database
# 2                      ValidationError         Payment Processing
# 3                 Incorrect Sort Order           Search/Filtering
# 4                        Cosmetic Typo               UI/Rendering
# 5                 NullPointerException             Initialization
# 6                      ValidationError         Payment Processing
# 7                            NameError           Cache Management
# 8                            NameError           Cache Management
# 9                 NullPointerException     Startup/Initialization
# 10                 Typographical Error               UI/Rendering
# 11                NullPointerException     Startup/Initialization
# 12                NullPointerException             Initialization
# 13                           NameError           Cache Management
# 14                           NameError           Cache Management
# 15                     ConnectionError                   Database
# 16                     ValidationError         Payment Processing
# 17  Misformatted Headers in PDF Export       Export/PDF Rendering
# 18                Not an Error Message             UI/Preferences
# 19                   EmailQueueWarning  Email/Notification System

# %%
results = duplicate_detection_agent(
    new_description="App crashes on login with NullPointerException",  # match this to something real from your table
    error_type="NullPointerException",   # match accordingly
    component="Login",                   # match accordingly
    reasoning="Object accessed before initialization",
    model=model,
    top_n=5
)

for r in results:
    print(r)
    print()
# Out:
# {'bug_id': 'BUG-3b0fe790', 'similarity': 0.7651175856590271, 'label': 'similar', 'explanation': 'Both reports involve a NullPointerException, suggesting a similar underlying issue with null object references.'}
#
# {'bug_id': 'BUG-1f12378b', 'similarity': 0.7651175260543823, 'label': 'similar', 'explanation': 'Both reports involve a NullPointerException, suggesting a similar underlying issue with null object references.'}

# %%
results = duplicate_detection_agent(
    new_description=  """
Traceback (most recent call last):

Cell In[92], line 4, in <module>

update_cache_40)

Cell In[92], line 2, in update_cache_4

1 def update_cache_40):

->2 return config_4_missing + 10



NameError: name 'config_4_missing' is not defined """, #"App crashes immediately on startup for all users",
    error_type="NameError",
    component="Cache Management",
    reasoning="The variable 'config_4_missing is used in the return statement but has no t been defined anywhere in the code, causing a NameError." ,
    model=model,
    top_n=5
)

for r in results:
    print(r)
    print()

# %%
"""
Traceback (most recent call last):

Cell In[92], line 4, in <module>

update_cache_40)

Cell In[92], line 2, in update_cache_4

1 def update_cache_40):

->2 return config_4_missing + 10



NameError: name 'config_4_missing' is not defined """, #"App crashes on login with NullPointerException",
    model, kb_embeddings, kb_metadata, top_n=5
)

# Step 2: feed into root cause agent
result = root_cause_agent(
    bug_id="BUG-30550c39",
    severity="Medium",
    component="Cache Management",
    error_type="NameError",
    failure_location="Cell In [92], line 2",
    code_path="update_cache_4() -> return statement: config_4_missing + 10",
    retrieved_bugs=retrieved 

"""

# %%
import sqlite3

conn = sqlite3.connect("../data/bug_submissions.db")
cursor = conn.cursor()
cursor.execute("SELECT bug_id, description FROM bug_submissions WHERE bug_id = 'BUG-3b0fe790'")
row = cursor.fetchone()
conn.close()

print(repr(row[1]))
# Out:
# 'App crashes immediately on startup for all users. No workaround available. Exception in thread "main" java.lang.NullPointerException at Init.java:22'

# %%
results = duplicate_detection_agent(
    """
Traceback (most recent call last):

Cell In[92], line 4, in <module>

update_cache_40)

Cell In[92], line 2, in update_cache_4

1 def update_cache_40):

->2 return config_4_missing + 10



NameError: name 'config_4_missing' is not defined """, #"App crashes immediately on startup for all users",
    error_type="NameError",
    component="Cache Management",
    reasoning="The variable 'config_4_missing is used in the return statement but has no t been defined anywhere in the code, causing a NameError." ,
    model=model,
    top_n=5
)

for r in results:
    print(r)
    print()

# %% [markdown]
# # Remediation Agent

# %%
# root_cause_prompt = """ You are job is to Retrieve Relevant Historical Bugs and Generate Root Cause Analysis
"""
and identifies the most probable root cause of a submitted bug using RAG-based retrieval from the historical defect knowledge base. Output(Reply ONLY in valid JSON) - Root cause hypothesis, confidence score, and supporting historical evidence 

input will be the 

 { 

bug_id , severity , component , error_type ,failure_location , code_path , {plus the 5 retrieved similar historical bugs (with their resolutions)}       

}

You must reason about why this new bug likely happened, using patterns from those historical bugs as support.

Output:
{
  "root_cause_hypothesis": "...",   
  "confidence": 0.85,
  "supporting_evidence": [
    {"bug_id": "...", "summary": "..."},
    {"bug_id": "...", "summary": "..."}
  ]
}

 

 Root cause hypothesis - It is the explanation of why the bug happened — e.g., "The NullPointerException likely occurred because the recordsList object was never initialized before being accessed, similar to patterns seen in [historical bug].

confidence score - a score from 0 to 1 representing how certain you are that you extracted this correctly. Vary this realistically - very clear, unambiguous traces should score 0.95-0.99, while vague, truncated, or ambiguous input should score lower (0.5-0.8). Do not default to 0.99 for everything.

supporting historical evidence - evidence should include both a traceable bug_id AND a short 5-15 word summary ( this should be a list of small objects, not a single string.)



Example 1:
Input: {"error_type": "NullPointerException", "component": "Login", "failure_location": "Api_2.java:110", "code_path": "main thread -> updateCache_2() -> String.indexOf()", "retrieved_bugs": [{"bug_id": "GMF-RUNTIME-282380", "title": "DefaultProvider#getRelevantConnections may throw a NPE", "resolution": "fixed"}, {"bug_id": "JCR-71", "title": "WorkspaceConfig.init() throws NullPointerException if Search configuration is missing", "resolution": "Fixed"}]}

Output: {"root_cause_hypothesis": "The NullPointerException likely occurred because an object (recordsList) was accessed before being properly initialized, a pattern consistent with similar historical NPEs caused by missing configuration or setup steps.", "confidence": 0.82, "supporting_evidence": [{"bug_id": "GMF-RUNTIME-282380", "summary": "NPE from missing null check before method call"}, {"bug_id": "JCR-71", "summary": "NPE from missing required configuration on init"}]}

Example 2:
Input: {"error_type": "IndexError", "component": "Search/Filtering", "failure_location": "sort_handler.py:22", "code_path": "apply_filter() -> sort_results()", "retrieved_bugs": [{"bug_id": "PY-1002", "title": "List index out of range when filter returns empty results", "resolution": "fixed"}]}

Output: {"root_cause_hypothesis": "The IndexError likely occurred because the sorting function assumed the filtered list would always contain at least one item, but did not handle the case of an empty result set.", "confidence": 0.75, "supporting_evidence": [{"bug_id": "PY-1002", "summary": "Empty list not handled before indexing"}]}

Example 3:
Input: {"error_type": "ConnectionError", "component": "Database", "failure_location": "db_handler.py:8", "code_path": "startup() -> connect_db()", "retrieved_bugs": [{"bug_id": "APACHE-990", "title": "Database connection pool exhausted under load", "resolution": "fixed"}, {"bug_id": "APACHE-1103", "title": "Connection timeout not configured, hangs indefinitely", "resolution": "fixed"}, {"bug_id": "APACHE-1204", "title": "Retry logic missing on transient connection failures", "resolution": "wontfix"}]}

Output: {"root_cause_hypothesis": "The connection failure is likely caused by either exhausted connection pool capacity or a missing timeout/retry mechanism, both common causes of database connection failures under load in similar historical cases.", "confidence": 0.68, "supporting_evidence": [{"bug_id": "APACHE-990", "summary": "Connection pool exhausted under high load"}, {"bug_id": "APACHE-1103", "summary": "Missing timeout caused indefinite hang"}]}

Example 4:
Input: {"error_type": "TypeError", "component": "UI/Rendering", "failure_location": "render.js:15", "code_path": "renderComponent() -> formatDate()", "retrieved_bugs": []}

Output: {"root_cause_hypothesis": "No closely related historical bugs were found, but based on the error itself, this likely occurred because a date value was undefined or in an unexpected format when passed into the formatting function.", "confidence": 0.55, "supporting_evidence": []}

Example 5:
Input: {"error_type": "ValidationError", "component": "Payment Processing", "failure_location": "payment.py:44", "code_path": "checkout() -> validate_currency()", "retrieved_bugs": [{"bug_id": "TVT35-297", "title": "incorrect default placement of currency symbol", "resolution": "fixed"}]}

Output: {"root_cause_hypothesis": "This is likely a currency-code validation gap rather than the same issue as the retrieved bug, since that historical case involved display formatting, not validation logic - the connection is only loosely related.", "confidence": 0.6, "supporting_evidence": [{"bug_id": "TVT35-297", "summary": "Related currency-handling bug, but different root cause"}]}

Example 6:
Input: {"error_type": "MemoryError", "component": "File Upload", "failure_location": "upload_handler.js:67", "code_path": "uploadFile() -> allocateBuffer()", "retrieved_bugs": [{"bug_id": "AXIS-1741", "title": "LogHandler can only work in GlobalConfiguration", "resolution": "fixed"}]}

Output: {"root_cause_hypothesis": "No strongly related historical bug was found; the retrieved bug shares only superficial similarity (both are configuration-related) but does not explain a memory allocation failure on large file uploads.", "confidence": 0.5, "supporting_evidence": [{"bug_id": "AXIS-1741", "summary": "Unrelated configuration bug, weak match only"}]}

Example 7:
Input: {"error_type": "SyntaxError", "component": "Build System", "failure_location": "config.css:20", "code_path": "CSS parser -> block parsing", "retrieved_bugs": [{"bug_id": "CSS-501", "title": "Unclosed declaration block causes parser failure", "resolution": "fixed"}, {"bug_id": "CSS-512", "title": "Missing semicolon triggers cascading syntax errors", "resolution": "fixed"}]}

Output: {"root_cause_hypothesis": "The syntax error is almost certainly caused by an unclosed block or missing terminator in the CSS source, a very common and well-documented pattern matching both retrieved historical bugs closely.", "confidence": 0.93, "supporting_evidence": [{"bug_id": "CSS-501", "summary": "Unclosed block caused identical parser failure"}, {"bug_id": "CSS-512", "summary": "Missing semicolon caused cascading syntax error"}]}



"""

# %%
remediation_agent_prompt = """ You are an agent  and you job is  to generates specific fix recommendations grounded in historical resolutions, root cause findings, and best practice guidelines and Reply ONLY in valid JSON.

input you will get are : bug_id, severity , component , error_type ,failure_location , code_path ,  description , root_cause , historical_references , duplicate_bug

bug_id → to identify which bug it's fixing.
severity → to decide how urgent or cautious the fix should be.
component → to understand which module or subsystem is affected.
error_type → to know the category of error (e.g., NameError, NullPointerException).
failure_location → to know where the bug occurred.
code_path → to understand the execution path leading to the error.
description → a concise explanation of what failed (this can come from the Log Analysis Agent's reasoning).
root_cause → the Root Cause Agent's hypothesis about why the bug occurred.
historical_references → previous similar bugs or fixes to ground the recommendation.
duplicate_bug → if a duplicate exists, the Remediation Agent may simply recommend the existing fix instead of generating a new one.
match: Indicates how closely the historical bug matches the current bug (e.g., "same" for nearly identical, "similar" for related but not identical).
similarity: A numeric score (0 to 1) representing how similar the current bug is to the historical bug, where 1.0 means an almost identical match and 0.0 means completely different.




output : 
bug_id	: A unique ID used to identify this specific bug.
recommended_fix : 	The main solution that should be applied to fix the bug.
fix_steps : 	A list of simple steps the developer should follow to fix the problem.
code_example : 	Shows the incorrect code ("before") and the corrected code ("after") as an example.
validation_steps : 	Steps to check whether the bug has been fixed successfully after applying the solution.
prevention : 	A best practice or tip to help prevent the same type of bug in the future.
confidence : 	A score showing how confident the agent is that the suggested fix is the correct one.
reasoning : 	A short explanation of why the agent chose this particular fix based on the available information.
references_used : 	The historical bugs, documentation, or best-practice sources that helped the agent decide on the fix.
Field : 	Simple Explanation
type : 	The kind of source used, such as a historical bug or documentation.
bug_id : 	The ID of the similar historical bug that was used as a reference.
summary : 	A short description of what that historical bug was about.





example :


example 1:


input :
{
  "bug_id": "BUG-30550c39",
  "severity": "Medium",
  "component": "Cache Management",
  "error_type": "NameError",
  "failure_location": "Cell In[92], line 2",
  "code_path": "update_cache_4() -> return statement: config_4_missing + 10",
  "description": "The variable 'config_4_missing' is referenced in the return statement but has not been defined, resulting in a NameError.",
  "root_cause": "The NameError likely occurred because a variable was referenced before being defined, possibly due to a missing import or incorrect variable naming.",
  "historical_references": [
    {
      "bug_id": "IVY-108",
      "summary": "Cache fileset issue with empty configuration"
    },
    {
      "bug_id": "COCOON-1698",
      "summary": "Caching attribute issue with global use"
    }
  ],
  "duplicate_bug": [
  {
    "bug_id": "IVY-108",
    "similarity": 0.91,
    "label": "same",
    "explanation": "Both reports involve cache configuration code where an undefined or missing configuration value causes execution to fail. The affected component and root cause are highly consistent."
  },
  {
    "bug_id": "COCOON-1698",
    "similarity": 0.78,
    "label": "similar",
    "explanation": "Both reports are related to cache management and configuration handling. Although the exact exception differs, both stem from configuration-related issues affecting cache behavior."
  }
]
}


ouptut:
{
  "bug_id": "BUG-30550c39",
  "recommended_fix": "Define the variable 'config_4_missing' before it is referenced, or replace it with the correct configuration variable if the current name is a typo.",
  "fix_steps": [
    "Locate the 'update_cache_4()' function and identify where 'config_4_missing' is referenced.",
    "Check whether 'config_4_missing' was intended to be another existing configuration variable.",
    "If the variable is missing, initialize it with a valid value before the return statement.",
    "If the value should come from another module or configuration file, import or retrieve it correctly.",
    "Run the function again to confirm that the NameError no longer occurs."
  ],
  "code_example": {
    "before": "return config_4_missing + 10",
    "after": "config_4_missing = 5\nreturn config_4_missing + 10"
  },
  "validation_steps": [
    "Execute update_cache_4() after applying the fix.",
    "Verify that no NameError is raised.",
    "Run all cache management unit tests.",
    "Test cache initialization using different configuration values.",
    "Confirm that no new errors are introduced in dependent modules."
  ],
  "prevention": "Use static analysis tools such as pylint or pyright to detect undefined variables before execution, and adopt consistent variable naming conventions for configuration values.",
  "confidence": 0.97,
  "reasoning": "The Log Analysis identified a NameError caused by an undefined variable, while the Root Cause analysis indicates that the variable was likely referenced before being defined or imported. Duplicate detection found a highly similar historical bug (IVY-108) involving cache configuration issues, whose successful resolution supports defining or correcting the missing configuration variable as the appropriate remediation.",
  "references_used": [
    {
      "type": "historical_bug",
      "bug_id": "IVY-108",
      "summary": "Cache fileset issue with empty configuration",
      "match": "same",
      "similarity": 0.91
    },
    {
      "type": "historical_bug",
      "bug_id": "COCOON-1698",
      "summary": "Caching attribute issue with global use",
      "match": "similar",
      "similarity": 0.78
    }
  ]
}



example 2:

Input: {"bug_id": "BUG-f5b5592a", "severity": "High", "component": "Payment Processing", "error_type": "ValidationError", "failure_location": "payment.py:44", "code_path": "checkout() -> validate_currency()", "description": "Payment processing occasionally fails for international transactions due to a currency validation error.", "root_cause": "Likely a validation gap in currency-code handling for non-default locales, based on similar historical payment validation bugs.", "historical_references": [{"bug_id": "TVT35-297", "summary": "Incorrect default placement of currency symbol"}], "duplicate_bug": [{"bug_id": "BUG-b216f3db", "similarity": 1.0, "label": "same", "explanation": "Both reports describe identical international payment validation failures with the same error type and component."}]}

Output: {"bug_id": "BUG-f5b5592a", "recommended_fix": "This is a duplicate of BUG-b216f3db, already identified. Apply the same fix: extend currency validation to explicitly support all supported international currency codes, not just default-locale ones.", "fix_steps": ["Confirm this matches the already-tracked issue BUG-b216f3db.", "Review the currency validation function for locale-specific assumptions.", "Add explicit handling for international currency codes.", "Apply the same fix already scoped for BUG-b216f3db rather than duplicating engineering effort."], "code_example": {"before": "if currency == 'USD': validate(amount)", "after": "if currency in SUPPORTED_CURRENCIES: validate(amount, currency)"}, "validation_steps": ["Re-test with multiple international currency codes.", "Confirm checkout succeeds for previously failing locales.", "Verify no regression for USD/default-locale transactions."], "prevention": "Add international currency test cases to the payment validation test suite to catch locale-specific gaps earlier.", "confidence": 0.95, "reasoning": "An exact duplicate (BUG-b216f3db) was already found and resolved-in-progress. Reusing the existing fix avoids redundant engineering effort, consistent with the project's goal of not re-solving already-identified issues.", "references_used": [{"type": "duplicate_bug", "bug_id": "BUG-b216f3db", "summary": "Identical international payment validation failure", "match": "same", "similarity": 1.0}, {"type": "historical_bug", "bug_id": "TVT35-297", "summary": "Currency symbol placement bug, loosely related"}]}



example 3:

Input: {"bug_id": "BUG-f25343c8", "severity": "Critical", "component": "Database", "error_type": "ConnectionError", "failure_location": "db_handler.py:8", "code_path": "startup() -> connect_db()", "description": "Database connection fails on every request, entirely blocking core functionality.", "root_cause": "Likely caused by exhausted connection pool capacity or a missing timeout/retry mechanism, based on similar historical database connection bugs.", "historical_references": [{"bug_id": "APACHE-990", "summary": "Database connection pool exhausted under load"}, {"bug_id": "APACHE-1103", "summary": "Connection timeout not configured, hangs indefinitely"}], "duplicate_bug": null}

Output: {"bug_id": "BUG-f25343c8", "recommended_fix": "Add connection pool size limits and a configured timeout with retry logic to the database connection handler.", "fix_steps": ["Review current connection pool configuration for missing size limits.", "Add an explicit timeout value to the connection setup.", "Implement retry-with-backoff logic for transient connection failures.", "Add logging to distinguish pool-exhaustion failures from timeout failures."], "code_example": {"before": "conn = db.connect(host, user, password)", "after": "conn = db.connect(host, user, password, timeout=10, pool_size=20)"}, "validation_steps": ["Simulate high concurrent load and confirm connections succeed within pool limits.", "Verify timeout triggers a clean retry instead of an indefinite hang.", "Confirm no regression under normal single-user load."], "prevention": "Set up monitoring/alerting on connection pool utilization to catch exhaustion trends before they cause outages.", "confidence": 0.72, "reasoning": "No exact duplicate was found, but two historical bugs from the same knowledge base describe closely related connection-pool and timeout issues. Since it's unclear which specific cause applies here, the fix addresses both plausible causes rather than assuming one.", "references_used": [{"type": "historical_bug", "bug_id": "APACHE-990", "summary": "Connection pool exhausted under high load"}, {"type": "historical_bug", "bug_id": "APACHE-1103", "summary": "Missing timeout caused indefinite hang"}]}



example 4:

Input: {"bug_id": "BUG-fabe5064", "severity": "Medium", "component": "Search/Filtering", "error_type": "Incorrect Sort Order", "failure_location": "sort_handler.py:31", "code_path": "apply_filter() -> sort_results()", "description": "Search results occasionally show incorrect sort order when multiple filters are applied together.", "root_cause": "Possibly a sort-stability issue when multiple filter criteria are combined, though the exact trigger condition is unclear.", "historical_references": [{"bug_id": "PY-1002", "summary": "List index out of range when filter returns empty results"}], "duplicate_bug": null}

Output: {"bug_id": "BUG-fabe5064", "recommended_fix": "Review the sort function for stability when multiple filter criteria are combined, and add a deterministic secondary sort key.", "fix_steps": ["Reproduce the issue with a specific combination of filters.", "Check whether the sort function is stable across repeated calls.", "Add a secondary sort key (e.g. by ID) to guarantee deterministic ordering.", "Add regression tests covering multi-filter combinations."], "code_example": {"before": "results.sort(key=lambda x: x.relevance)", "after": "results.sort(key=lambda x: (x.relevance, x.id))"}, "validation_steps": ["Apply multiple filters together and verify consistent ordering across repeated runs.", "Test edge cases with tied relevance scores.", "Confirm single-filter searches remain unaffected."], "prevention": "Always use a deterministic tiebreaker key when sorting by a non-unique field like relevance score.", "confidence": 0.58, "reasoning": "The only historical reference found (PY-1002) is only loosely related - it concerns empty filter results, not sort ordering. Without a closely matching precedent, this recommendation is based on a common general pattern (unstable sort without a tiebreaker) rather than strong historical evidence.", "references_used": [{"type": "historical_bug", "bug_id": "PY-1002", "summary": "Related to filtering, but different root issue"}]}



example 5:

Input: {"bug_id": "BUG-173ed07b", "severity": "Low", "component": "UI/Rendering", "error_type": "Cosmetic Typo", "failure_location": "checkout_form.html:52", "code_path": "renderCheckoutForm() -> button label", "description": "Button label says 'Sumbit' instead of 'Submit' on the checkout form.", "root_cause": "Simple text typo in the static UI label, unrelated to any logic or data-handling issue.", "historical_references": [], "duplicate_bug": null}

Output: {"bug_id": "BUG-173ed07b", "recommended_fix": "Correct the button label text from 'Sumbit' to 'Submit'.", "fix_steps": ["Locate the button label string in checkout_form.html.", "Correct the spelling.", "Verify the change renders correctly on the page."], "code_example": {"before": "<button>Sumbit</button>", "after": "<button>Submit</button>"}, "validation_steps": ["Visually confirm the corrected label on the checkout page.", "Check for the same typo elsewhere in the codebase."], "prevention": "Run a spell-checker or linting tool over UI text strings as part of the review process.", "confidence": 0.99, "reasoning": "This is an unambiguous, single-word spelling correction with no logic involved - no historical grounding is needed for a fix this simple and certain.", "references_used": []}



example 6:

Input: {"bug_id": "BUG-9931aa02", "severity": "High", "component": "Backend/Runtime", "error_type": "Go Runtime Panic: Index Out of Range", "failure_location": "/go/src/app/main_2.go:96", "code_path": "main.main() -> slice/array index access", "description": "Program panics with index out of range when accessing a slice element.", "root_cause": "The program attempted to access an index beyond the slice's actual length, likely due to an assumption that the slice always has a minimum number of elements.", "historical_references": [], "duplicate_bug": null}

Output: {"bug_id": "BUG-9931aa02", "recommended_fix": "Add a bounds check before accessing the slice index, and handle the case where the slice has fewer elements than expected.", "fix_steps": ["Identify the slice being accessed at main_2.go:96.", "Add a length check before the index access.", "Decide on safe fallback behavior when the slice is shorter than expected.", "Add a test case with an undersized slice."], "code_example": {"before": "value := items[7]", "after": "if len(items) > 7 {\n    value := items[7]\n}"}, "validation_steps": ["Run with a deliberately short slice and confirm no panic occurs.", "Confirm normal-length inputs still behave correctly."], "prevention": "Always validate slice/array length before fixed-index access, especially when the length is not guaranteed by an earlier step.", "confidence": 0.65, "reasoning": "No historical bug or duplicate was found for this specific case; the recommendation is based on general best practice for Go slice-bounds errors rather than a specific precedent, so confidence is moderate rather than high.", "references_used": []}



example 7:



Input: {"bug_id": "BUG-77aa10ff", "severity": "Medium", "component": "Notifications", "error_type": "Timeout", "failure_location": "notify_service.py:19", "code_path": "sendNotification() -> external_api_call()", "description": "Notification delivery occasionally times out with no clear pattern.", "root_cause": "Unclear - could be an intermittent external API issue, a network condition, or a misconfigured timeout value; no strong signal points to one specific cause.", "historical_references": [], "duplicate_bug": null}

Output: {"bug_id": "BUG-77aa10ff", "recommended_fix": "Add retry-with-backoff around the external API call, and add structured logging to capture timing details for future diagnosis.", "fix_steps": ["Add a retry mechanism with exponential backoff around the external call.", "Log request duration and failure details on every timeout.", "Set an explicit, documented timeout value rather than relying on a default.", "Monitor logs over the next several occurrences to identify a pattern."], "code_example": {"before": "response = external_api_call(payload)", "after": "response = retry_with_backoff(lambda: external_api_call(payload, timeout=5), max_retries=3)"}, "validation_steps": ["Confirm retries trigger correctly on simulated timeout.", "Review logs after deployment to check for a recurring pattern.", "Confirm normal notification delivery is unaffected."], "prevention": "Add alerting on notification timeout rate so intermittent issues are caught early rather than discovered only when reported.", "confidence": 0.5, "reasoning": "No historical bug, duplicate, or clear pattern was found. Given the intermittent, unclear nature of the issue, this recommendation focuses on resilience (retries, logging) to both mitigate the symptom and gather better evidence, rather than claiming to know the exact root cause.", "references_used": []}



example 8 :

Input: {"bug_id": "BUG-c81f9e02", "severity": "High", "component": "File Upload", "error_type": "MemoryError", "failure_location": "upload_handler.js:67", "code_path": "uploadFile() -> allocateBuffer()", "description": "Large file uploads occasionally fail with a memory allocation error.", "root_cause": "Likely caused by allocating a fixed-size buffer without checking available memory for large files.", "historical_references": [{"bug_id": "AXIS-1741", "summary": "LogHandler can only work in GlobalConfiguration"}], "duplicate_bug": null}

Output: {"bug_id": "BUG-c81f9e02", "recommended_fix": "Stream the file upload in chunks instead of allocating one large buffer, and add a file-size check before upload begins.", "fix_steps": ["Identify the fixed-size buffer allocation in uploadFile().", "Replace it with chunked/streaming upload handling.", "Add a maximum file-size validation before processing begins.", "Add a clear error message when a file exceeds the allowed size."], "code_example": {"before": "const buffer = allocateBuffer(file.size);", "after": "const stream = createUploadStream(file, { chunkSize: 1024 * 1024 });"}, "validation_steps": ["Test uploads with very large files and confirm no memory error occurs.", "Confirm normal-size uploads still work unchanged.", "Verify the size-limit error message displays correctly for oversized files."], "prevention": "Always stream large file uploads rather than loading them fully into memory, and enforce explicit size limits at the API boundary.", "confidence": 0.68, "reasoning": "No directly matching precedent was found - the only historical reference (AXIS-1741) is only superficially related (a configuration bug, not a memory issue). This recommendation is based on the general best practice for handling large file uploads, not a specific proven fix from history, so confidence is moderate rather than high.", "references_used": [{"type": "historical_bug", "bug_id": "AXIS-1741", "summary": "Unrelated configuration bug, weak match only"}]}



example 9 :

Input: {"bug_id": "BUG-e410a7c5", "severity": "Medium", "component": "Authentication", "error_type": "TokenExpiredError", "failure_location": "auth_middleware.py:29", "code_path": "verifyRequest() -> checkToken()", "description": "Users are occasionally logged out mid-session with a token expired error, even during active use.", "root_cause": "Unclear - could be an overly short token expiry window, a clock synchronization issue between services, or a token refresh mechanism failing silently.", "historical_references": [], "duplicate_bug": null}

Output: {"bug_id": "BUG-e410a7c5", "recommended_fix": "Add a silent token-refresh mechanism before expiry, and add logging to capture expiry timing versus actual session activity.", "fix_steps": ["Review the current token expiry duration and refresh logic.", "Implement a background refresh that triggers before the token actually expires.", "Add logging around token issuance, refresh attempts, and expiry checks.", "Monitor logs to identify whether this is a timing, clock-sync, or refresh-logic issue."], "code_example": {"before": "if token.expired: raise TokenExpiredError()", "after": "if token.expires_soon(): token = refresh_token(token)"}, "validation_steps": ["Simulate an active session spanning the token's expiry window and confirm no forced logout occurs.", "Review captured logs after deployment to identify the actual failure pattern.", "Confirm normal token expiry still logs out genuinely inactive sessions."], "prevention": "Always implement proactive token refresh for active sessions rather than relying solely on hard expiry checks.", "confidence": 0.55, "reasoning": "No historical bug or duplicate was found for this issue, and the root cause itself is genuinely uncertain among several plausible explanations. This recommendation focuses on a generally safe mitigation (proactive refresh + logging) rather than claiming to know the exact cause, so confidence is kept low and honest.", "references_used": []}




"""

# %%
def remediation_agent(bug_id, severity, component, error_type, failure_location, code_path, description, root_cause, historical_references, duplicate_bug):
    input_data = {
        "bug_id": bug_id,
        "severity": severity,
        "component": component,
        "error_type": error_type,
        "failure_location": failure_location,
        "code_path": code_path,
        "description": description,
        "root_cause": root_cause,
        "historical_references": historical_references,
        "duplicate_bug": duplicate_bug
    }

    user_message = json.dumps(input_data)

    result = call_llm_with_retry(remediation_agent_prompt, user_message)

    if result is None:
        result = {
            "bug_id": bug_id,
            "recommended_fix": "Unable to generate a recommendation due to a processing error.",
            "fix_steps": [],
            "code_example": {},
            "validation_steps": [],
            "prevention": "",
            "confidence": 0.0,
            "reasoning": "LLM call failed after retries",
            "references_used": []
        }

    return result

# %%
# Reuse the same NullPointerException test case throughout
retrieved = retrieve_similar_bugs(
    "App crashes on login with NullPointerException",
    model, kb_embeddings, kb_metadata, top_n=5
)

root_cause_result = root_cause_agent(
    bug_id="TEST-RC-001",
    severity="Critical",
    component="Login",
    error_type="NullPointerException",
    failure_location="Api_2.java:110",
    code_path="main thread -> updateCache_2() -> String.indexOf()",
    retrieved_bugs=retrieved
)

duplicate_result = duplicate_detection_agent(
    new_description="App crashes on login with NullPointerException",
    error_type="NullPointerException",
    component="Login",
    reasoning="Object accessed before initialization",
    model=model,
    top_n=5
)

remediation_result = remediation_agent(
    bug_id="TEST-RC-001",
    severity="Critical",
    component="Login",
    error_type="NullPointerException",
    failure_location="Api_2.java:110",
    code_path="main thread -> updateCache_2() -> String.indexOf()",
    description="App crashes on login with NullPointerException",
    root_cause=root_cause_result["root_cause_hypothesis"],
    historical_references=root_cause_result["supporting_evidence"],
    duplicate_bug=duplicate_result if duplicate_result else None
)

print(remediation_result)
# Out:
# Non-rate-limit error: Expecting value: line 1 column 1 (char 0)
# {'bug_id': 'TEST-RC-001', 'recommended_fix': 'Unable to generate a recommendation due to a processing error.', 'fix_steps': [], 'code_example': {}, 'validation_steps': [], 'prevention': '', 'confidence': 0.0, 'reasoning': 'LLM call failed after retries', 'references_used': []}

# %%
def call_llm_debug(system_prompt, user_message):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message}
        ],
        temperature=0.2
    )
    raw = response.choices[0].message.content
    print("RAW RESPONSE (repr):")
    print(repr(raw))
    print("finish_reason:", response.choices[0].finish_reason)
    return raw

# %%
input_data = {
    "bug_id": "TEST-RC-001",
    "severity": "Critical",
    "component": "Login",
    "error_type": "NullPointerException",
    "failure_location": "Api_2.java:110",
    "code_path": "main thread -> updateCache_2() -> String.indexOf()",
    "description": "App crashes on login with NullPointerException",
    "root_cause": root_cause_result["root_cause_hypothesis"],
    "historical_references": root_cause_result["supporting_evidence"],
    "duplicate_bug": duplicate_result if duplicate_result else None
}

raw = call_llm_debug(remediation_agent_prompt, json.dumps(input_data))
# Out:
# RAW RESPONSE (repr):
# '```json\n{\n  "bug_id": "TEST-RC-001",\n  "recommended_fix": "Initialize the object before accessing it, and add null checks before method calls to prevent NullPointerExceptions.",\n  "fix_steps": [\n    "Identify the object being accessed at Api_2.java:110.",\n    "Check if the object is properly initialized before being used.",\n    "Add null checks before method calls to prevent NullPointerExceptions.",\n    "Review the code for any missing configuration or setup steps that could be causing the NullPointerException."\n  ],\n  "code_example": {\n    "before": "String result = object.getString();",\n    "after": "if (object != null) { String result = object.getString(); } else { // handle null case }"\n  },\n  "validation_steps": [\n    "Run the app with the fix and confirm that the NullPointerException no longer occurs.",\n    "Test the app with different input scenarios to ensure that the fix does not introduce any new issues.",\n    "Verify that the app behaves as expected when the object is null."\n  ],\n  "prevention": "Always initialize objects before using them, and add null checks to prevent NullPointerExceptions.",\n  "confidence": 0.85,\n  "reasoning": "The NullPointerException is likely caused by an object being accessed before being properly initialized, a pattern consistent with similar historical NPEs. The recommended fix is based on this analysis and the retrieved historical bugs related to missing connections or configurations.",\n  "references_used": [\n    {\n      "type": "historical_bug",\n      "bug_id": "GMF-RUNTIME-282380",\n      "summary": "NPE from missing null check before method call",\n      "match": "similar",\n      "similarity": 0.8\n    },\n    {\n      "type": "historical_bug",\n      "bug_id": "JCR-71",\n      "summary": "NPE from missing required configuration on init",\n      "match": "similar",\n      "similarity": 0.7\n    },\n    {\n      "type": "historical_bug",\n      "bug_id": "FIREFOX_FOR_ANDROID-804926",\n      "summary": "NPE from missing initialization in requestRender",\n      "match": "similar",\n      "similarity": 0.6\n    },\n    {\n      "type": "duplicate_bug",\n      "bug_id": "BUG-3b0fe790",\n      "summary": "Similar NullPointerException issue",\n      "match": "similar",\n      "similarity": 0.7651175260543823\n    },\n    {\n      "type": "duplicate_bug",\n      "bug_id": "BUG-1f12378b",\n      "summary": "Similar NullPointerException issue",\n      "match": "similar",\n      "similarity": 0.7651175260543823\n    },\n    {\n      "type": "duplicate_bug",\n      "bug_id": "BUG-c53ac751",\n      "summary": "Similar NullPointerException issue",\n      "match": "similar",\n      "similarity": 0.7651175260543823\n    },\n    {\n      "type": "duplicate_bug",\n      "bug_id": "BUG-09e0269c",\n      "summary": "Similar NullPointerException issue",\n      "match": "similar",\n      "similarity": 0.7651175260543823\n    },\n    {\n      "type": "duplicate_bug",\n      "bug_id": "BUG-a5336770",\n      "summary": "Similar NullPointerException issue",\n      "match": "similar",\n      "similarity": 0.7651175260543823\n    }\n  ]\n}\n```'
# finish_reason: stop

# %%
def call_llm_with_retry(system_prompt, user_message, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_message}
                ],
                temperature=0.2
            )
            raw = response.choices[0].message.content.strip()

            # Strip markdown code fences if the model added them despite instructions
            if raw.startswith("```"):
                raw = raw.split("```")[1]
                if raw.startswith("json"):
                    raw = raw[4:]
                raw = raw.strip()

            return json.loads(raw)
        except Exception as e:
            if "rate_limit" in str(e).lower() or "429" in str(e):
                wait_time = (attempt + 1) * 3
                print(f"Rate limited, waiting {wait_time}s...")
                time.sleep(wait_time)
            else:
                print(f"Non-rate-limit error: {e}")
                break
    return None

# %%
remediation_result = remediation_agent(
    bug_id="TEST-RC-001",
    severity="Critical",
    component="Login",
    error_type="NullPointerException",
    failure_location="Api_2.java:110",
    code_path="main thread -> updateCache_2() -> String.indexOf()",
    description="App crashes on login with NullPointerException",
    root_cause=root_cause_result["root_cause_hypothesis"],
    historical_references=root_cause_result["supporting_evidence"],
    duplicate_bug=duplicate_result if duplicate_result else None
)

print(remediation_result)
# Out:
# {'bug_id': 'TEST-RC-001', 'recommended_fix': 'Ensure all objects are properly initialized before use, and add null checks before method calls to prevent NullPointerExceptions.', 'fix_steps': ['Review the code at Api_2.java:110 to identify the null object being accessed.', 'Check for missing configuration or setup steps that could lead to the object being null.', 'Add null checks before method calls to prevent NullPointerExceptions.', 'Verify that all objects are properly initialized before use, especially in concurrent request handling scenarios.'], 'code_example': {'before': 'String result = someString.indexOf("pattern");', 'after': 'if (someString != null) { String result = someString.indexOf("pattern"); }'}, 'validation_steps': ['Test the login functionality with different input scenarios to ensure the NullPointerException is resolved.', 'Verify that the app no longer crashes on login.', 'Confirm that the fix does not introduce any new issues or regressions.'], 'prevention': 'Regularly review code for potential null pointer exceptions and ensure that all objects are properly initialized before use.', 'confidence': 0.85, 'reasoning': 'The NullPointerException is a common issue that can be caused by missing configuration or setup steps. The historical references and duplicate bugs suggest that this issue is similar to others that have been resolved by adding null checks and ensuring proper object initialization. The recommended fix is based on this pattern and is likely to resolve the issue.', 'references_used': [{'type': 'historical_bug', 'bug_id': 'GMF-RUNTIME-282380', 'summary': 'NPE from missing null check before method call', 'match': 'similar', 'similarity': 0.8}, {'type': 'historical_bug', 'bug_id': 'JCR-71', 'summary': 'NPE from missing required configuration on init', 'match': 'similar', 'similarity': 0.7}, {'type': 'historical_bug', 'bug_id': 'FIREFOX_FOR_ANDROID-804926', 'summary': 'NPE from improper request handling', 'match': 'similar', 'similarity': 0.6}, {'type': 'historical_bug', 'bug_id': 'AXIS-1261', 'summary': 'NPE from missing engine config factory for concurrent requests', 'match': 'similar', 'similarity': 0.5}, {'type': 'duplicate_bug', 'bug_id': 'BUG-3b0fe790', 'summary': 'Similar NullPointerException issue', 'match': 'similar', 'similarity': 0.7651175856590271}, {'type': 'duplicate_bug', 'bug_id': 'BUG-1f12378b', 'summary': 'Similar NullPointerException issue', 'match': 'similar', 'similarity': 0.7651175260543823}]}

# %%
def call_llm_debug(system_prompt, user_message):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message}
        ],
        temperature=0.2
    )
    raw = response.choices[0].message.content
    print("RAW RESPONSE (repr):")
    print(repr(raw))
    print("finish_reason:", response.choices[0].finish_reason)
    return raw

# %%
import json
input_data = {
    "bug_id": "BUG-1a9af3a8",
    "severity": "Low",
    "component": "UI/Preferences",
    "error_type": "Not an Error Message",
    "failure_location": "None",
    "code_path": "No code execution or parsing occurred",
    "description": "Feature request: add a dark mode toggle to the user preferences panel.",
    "root_cause": "The issue is likely related to a problem with the UI/Preferences component, possibly involving a misconfiguration or a bug in the preferences system, given the similarities with historical bugs related to preferences and UI settings.",
    "historical_references": [
        {"bug_id": "CORE-397373", "summary": "Preferences state not working as expected"},
        {"bug_id": "WTP_COMMON_TOOLS-264471", "summary": "Validator filter settings not persisted"},
        {"bug_id": "CDT-367403", "summary": "Editor not respecting high contrast settings"},
        {"bug_id": "PLATFORM-253060", "summary": "Preference dialog flickering issue"},
        {"bug_id": "JSDT-443995", "summary": "Dark theme support implementation"}
    ],
    "duplicate_bug": None
}

raw = call_llm_debug(remediation_agent_prompt, json.dumps(input_data))
# Out:
# RAW RESPONSE (repr):
# '```json\n{\n  "bug_id": "BUG-1a9af3a8",\n  "recommended_fix": "Implement a dark mode toggle in the user preferences panel, ensuring it persists across sessions and respects user preferences.",\n  "fix_steps": [\n    "Review existing UI/Preferences component code for similar toggle implementations.",\n    "Design and implement the dark mode toggle, considering accessibility and user experience.",\n    "Integrate the toggle with the existing preferences system, ensuring persistence and correct behavior.",\n    "Test the dark mode toggle with various user scenarios, including different platforms and accessibility settings."\n  ],\n  "code_example": {\n    "before": "No existing code for dark mode toggle",\n    "after": "Example code for dark mode toggle implementation:\n// Pseudocode example, actual implementation may vary\nif (userPrefersDarkMode) {\n  applyDarkModeStyles();\n} else {\n  applyLightModeStyles();\n}"\n  },\n  "validation_steps": [\n    "Verify the dark mode toggle is visible and functional in the user preferences panel.",\n    "Test that the toggle persists user preferences across sessions and platform restarts.",\n    "Confirm the dark mode toggle respects user preferences and applies the correct visual theme.",\n    "Test the toggle with different accessibility settings, such as high contrast mode."\n  ],\n  "prevention": "Regularly review and update the UI/Preferences component to ensure it remains consistent with user expectations and platform standards.",\n  "confidence": 0.8,\n  "reasoning": "Although this is a feature request rather than a traditional bug, the historical references provided suggest that the UI/Preferences component has had issues with preferences and UI settings in the past. Implementing a dark mode toggle requires careful consideration of these factors to ensure a seamless user experience.",\n  "references_used": [\n    {\n      "type": "historical_bug",\n      "bug_id": "CORE-397373",\n      "summary": "Preferences state not working as expected",\n      "match": "similar",\n      "similarity": 0.6\n    },\n    {\n      "type": "historical_bug",\n      "bug_id": "WTP_COMMON_TOOLS-264471",\n      "summary": "Validator filter settings not persisted",\n      "match": "similar",\n      "similarity": 0.5\n    },\n    {\n      "type": "historical_bug",\n      "bug_id": "CDT-367403",\n      "summary": "Editor not respecting high contrast settings",\n      "match": "similar",\n      "similarity": 0.7\n    },\n    {\n      "type": "historical_bug",\n      "bug_id": "PLATFORM-253060",\n      "summary": "Preference dialog flickering issue",\n      "match": "similar",\n      "similarity": 0.4\n    },\n    {\n      "type": "historical_bug",\n      "bug_id": "JSDT-443995",\n      "summary": "Dark theme support implementation",\n      "match": "similar",\n      "similarity": 0.8\n    }\n  ]\n}\n```'
# finish_reason: stop
