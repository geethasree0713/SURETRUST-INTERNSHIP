# %%
import os
import sys
import numpy as np

 # 1. Provide the actual absolute path starting with your drive letter
src_path = r"C:/Users/famil/OneDrive/Desktop/AI_Smart_Bug_Analyzer_-_Fix-_Advisor-/src"
sys.path.append(src_path)

# %%
from agents import client

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "You are a bug triage assistant. Reply ONLY in valid JSON: {\"test\": \"ok\"}"},
        {"role": "user", "content": "test"}
    ],
    temperature=0.2
)
print(repr(response.choices[0].message.content))
# Out:
# '{"test":"ok"}'
